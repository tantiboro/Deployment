# %% [markdown]
# <a href="https://colab.research.google.com/github/tantiboro/Deployment/blob/main/Copy_of_Using_Rake_for_keyword_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Using Rake-NLTK for Keywork Analysis
#
# If you have collected some job data, but you need to extract some keywords from the description in order to obtain skills or industry data, you can use the rake-nltk Python module.
#
# First you should download and import the rake package as follows:

# %%
# !pip install rake-nltk
from rake_nltk import Metric, Rake
import nltk
nltk.download('stopwords')
nltk.download('punkt')
from nltk.tokenize import sent_tokenize, word_tokenize
# Out:
# ...
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %% [markdown]
# The final line should say
# `Successfully installed rake-nltk-x.x.x` where x is the latest version available.
#
# Now lets instantiate Rake and use it to extract keywords from a simple text example.

# %%
r = Rake()

mtext = '''company,title,location,posted,href,description,skills,industry\n"Systems Planning and Analysis, Inc.",Data Scientist - CWMD,"Reston, VA",,https://www.linkedin.com/jobs/view/2719087133/?eBP=CwEAAAF8A9ofOs3Q1pRDNomWkKq8WZKKrxzVFph6K2D4ymCmOH1h4zujhf7yBWfSjCtGRdbAe9Qx1ZFnDclUFpBrbo8MAanx6IoSd6oeFzDujMeur4dsRn-KObiuVvRuoE8jax4zNaj2cL0qgNswrocbKDKdYn82E7vixG1bp6oL35Xs1t4QTILoMHsFU_wTZqMgC7fCMPF3UzzYVoZ7UpLI2jutAFhJUtKKFD94vE5WkDbZOlxsnkXaN96-uctzECAJaz-JWJTbMRDHUek1yOdijC16J7HeR8V1Snd1B3f-lHcwkIyohdLJUUsi0dDpOWpoQNpv7XWOgAXT-NzCdHsRY99xfHcFFJK5r9UEJvFy__j3f60gUpWxie9aT8NO&recommendedFlavor=ACTIVELY_HIRING_COMPANY&refId=uAGrvRCfo9q5%2BNk5EGGm4Q%3D%3D&trackingId=sCAmjQEN8DY8a6u7bP7Yfg%3D%3D&trk=flagship3_search_srp_jobs,"About the job\nOverview\n\nSystems Planning and Analysis, Inc. (SPA) is a well-established and progressive defense contracting company in the DC Metro area. We are a professional services firm established in 1972 that has a long-standing reputation for unrivaled technical and analytical support to some of the top decision makers in the Federal Sector. We do state of the art work and have a cadre of outstanding professionals on our team.\n\nSPA assists the Defense Threat Reduction Agency (DTRA) in developing leading edge technologies to counter WMD in support of CCMDs and transitioning these technologies to services and SOCOM. SPA provides expertise across the full range of chemical, biological, radiological, nuclear and high-yield explosives (CBRNE) WMD, Counter Improvised Threat and Countering Threat Network technologies to support understanding, detection, identification, characterization, denial, control, disabling, defeating, disposing, safeguarding the force, managing consequences, and test and evaluation in support of military and civilian operations. #CJ #IN123\n\n\n\nProvides critical decision and analytic support to the Urgent Solutions Division in the Counter WMD Technologies Department of the Defense Threat Reduction Agency (DTRA). Conducts assessments, demonstrations, analysis, scientific codes, and other decision making in evaluating systems to counter WMD – biological and chemical threats, and counter threat networks. Develops knowledge regarding a stipulated issue through analysis of complex data sets, identifying actionable trends and problems. Uses appropriate methods to creatively explore, mine, analyze and manipulate data sets ranging in size from sparse to petabytes and type (e.g. small number of .pdf text reports, Excel spreadsheets and .csv files to repositories of image or audio data). Interprets results from multiple sources using a variety of techniques, ranging from simple data aggregation via statistical analysis to complex data mining, sensor analysis and learning techniques. Designs, develops, and implements technical solutions in support of concurrent analysis. Supports data models and defines the structure, attributes, and nomenclature of data elements. May evaluate new data sources for adherence to the organization\'s quality standards and ease of integration.",[],[]\nPerficient,Data Scientist,"St Louis, MO",,https://www.linkedin.com/jobs/view/2718055481/?eBP=CwEAAAF8A9ofOhOHpkH95U2fvN9F-goU76IrWGZ2_h1PEIqUbFxqxI6w3ypUfMSWfMRpTGEJDX9iicxg3Is1hE7MJg4ixQ2ZJfmdAFAR38WMuWQ9RdnHIEX4XrSbapYsM3nhi6Iyv6rH9MEC1PpEqmZkvr8JBlfU1asVfgP3pl3rW4IS6tIVJuzERferAoB3ycE-UB94AE92MTfUPPOUagL-zhuIsIcyQ6BMfE6eFGYpZpAHbvdti7-s852GjLAxYFovRGVyerfbSKSeZm6fVVXT2EaQfKYvMN5hBZBBVncwxNfzaaMBbKZ9moxmBg76BZ3UfB6YOntWLvvf06jI4VVqLMZ_BYq4iT8Jnp-YKt2dJxnECW-9zW66IbRoeRPT&recommendedFlavor=COMPANY_RECRUIT&refId=uAGrvRCfo9q5%2BNk5EGGm4Q%3D%3D&trackingId=UE7bblhxeqWJV52%2F9JWJew%3D%3D&trk=flagship3_search_srp_jobs,"About the job\nOverview\n\nAt Perficient you’ll deliver mission-critical technology and business solutions to Fortune 500 companies and some of the most recognized brands on the planet. And you’ll do it with cutting-edge technologies, thanks to our close partnerships with the world’s biggest vendors. Our network of offices across North America, as well as locations in India and China, will give you the opportunity to spread your wings, too.\n\nWe’re proud to be publicly recognized as a “Top Workplace” year after year. This is due, in no small part, to our entrepreneurial attitude and collaborative spirit that sets us apart and keeps our colleagues impassioned, driven, and fulfilled.\n\nPerficient currently has a career opportunity for a .\n\n\n\nThe role of the Data Scientist is for individuals passionate about identifying and delivering the right Business solution for each client using AI/ML. Our Data Scientists are keen to understand our customer needs, processes and pain points to determine the success factors and evaluation criteria that will needed to measure the effectiveness of an ML model.\n\nThe Data Scientist will be involved in the strategic planning of an engagement or helping the client make decisions about their future AI/ML roadmap and vision. Once the project as begun, the Data Scientist will be responsible for the execution of our established methodology, work with customer and/or the teams data engineer to identify data ingestion and transformation needs, exploration of the data and reporting findings, modeling and evaluation of training iterations. It is a key part of the role to be able to explain in non-technical terms the chosen modeling approach and findings from data exploration or training results.\n\nThe Data Scientist will work with Senior Project Managers to assist with daily operations exercising time management, communication and collaboration in a fast-paced environment to ensure the successful delivery of projects. The Data Scientist will interface with Perficient technical and business delivery personnel, as well as vendors and customers on a regular basis. May mentor junior data scientists.\n\n\n\n\n\n\n\nPerficient full-time employees receive complete and competitive benefits. We offer a collaborative work environment, competitive compensation, generous work/life opportunities and an outstanding benefits package that includes paid time off plus holidays. In addition, all colleagues are eligible for a number of rewards and recognition programs including billable bonus opportunities. Encouraging a healthy work/life balance and providing our colleagues great benefits are just part of what makes Perficient a great place to work.\n\n\n\nPerficient is the leading digital transformation consulting firm serving Global 2000 and enterprise customers throughout North America. With unparalleled information technology, management consulting and creative capabilities, Perficient and its Perficient Digital agency deliver vision, execution and value with outstanding digital experience, business optimization and industry solutions.\n\nOur work enables clients to improve productivity and competitiveness; grow and strengthen relationships with customers, suppliers and partners; and reduce costs. Perficient\'s professionals serve clients from a network of offices across North America and offshore locations in India and China. Traded on the Nasdaq Global Select Market, Perficient is a member of the Russell 2000 index and the S&P SmallCap 600 index.\n\nPerficient is an equal opportunity employer and all qualified applicants will receive consideration for employment without regard to race, color, religion, sex, national, origin, disability status, protected veteran status, or any other characteristic protected by law.\n\nThe above statements are not intended to be a complete statement of job content, rather to act as a guide to the essential functions performed by the employee assigned to this classification. Management retains the discretion to add or change the duties of the position at any time.\n\nSelect work authorization questions to ask when applicants apply",[],[]\nSavage X Fenty: Lingerie by Rihanna,Data Scientist,"El Segundo, CA",,https://www.linkedin.com/jobs/view/2721710042/?eBP=CwEAAAF8A9ofOhPzbWsStxaNEgpMLIbvO6Vvpf-kp8RGwvYOJKGphyyakdc_4SGsjm2VeRAGjmk-vJ6l9A5H_dap2I3Kpoi5h6gKOdZGPr43fehHk5BqkiDkbvKki_to05FvWLinOBzurpjsMFG3JoeqUJ8xRReTFcidZnHYUQE6jUxh0nf-LNmAPuQp7YZEmPEps45wTFpgh1xQa_nwnLky1x-nzte_8YwEIsmHKQ5z2VTOvDevWj_NNLxyfvp4hDKsNbBNyQC_28gSNPkqkg6iN2yFOum-URpP05X-BwoG-gN9HPsuQJs-bhqDslt8i6wwag517FTdUMMYWqa29zUtuHYFUf1ei5iEh0ffOBNdGGDafvdOB4z8Oqp3hxLnHhY&recommendedFlavor=ACTIVELY_HIRING_COMPANY&refId=uAGrvRCfo9q5%2BNk5EGGm4Q%3D%3D&trackingId=WJuu5WmPKTuvZRyUdmNdtA%3D%3D&trk=flagship3_search_srp_jobs,"About the job\nJob DescriptionSavage X Fenty is looking for a Data Scientist. Co-founded by music and fashion icon Rihanna, Savage X Fenty is the first line of lingerie that celebrates and speaks to all shades and shapes of people, and celebrates fearlessness, confidence and inclusivity.\n\nHOW DO YOU FIT IN?\n\nAs the Data Scientist, you will drive innovation in our customer shopping experience by providing the algorithms that power recommendation and personalization features across our ecommerce website. You will collaborate closely with the Data Analytics organization, the Global Technology organization, and the Savage X business to develop high-impact solutions to key optimization opportunities such as ecommerce conversion & product discovery. You will watch your work come to life by partnering with dedicated product & software engineering teams to deploy your algorithms into production.\n\nProjects you are likely to own in this role include:\n\nProduct Recommendation Algorithms (e.g., product discovery & upsell algorithms)\n\nFull Funnel Customer Segmentation (e.g., algorithmically define customer segments and stream segments to other tools such as our CRM or ad networks)\n\nInternal Optimization Algorithms (e.g., attribution models, sales propensity algorithms)\n\nAt Savage X Fenty you can expect to use Python and SQL every day. For larger projects requiring scale or automation you’ll likely be working with DataBricks and Airflow. While these are our defaults, you will have the flexibility to use tools that allow you to best fulfill your role. Additionally, we strongly believe in the need for ongoing education and so will encourage you to explore new technologies and modeling methods on a regular basis.\n\n\n\nYou’re the ideal candidate if you’re incredibly curious & see opportunities for data science applications in everything you do. Working smarter, not harder, is core to your DNA. You’re invigorated by the opportunity to learn that next tool or skill, and you come up with clever solutions to difficult problems. As much as you learned in school or at work, you’ve probably learned even more during your late-night hacking sessions. You take initiative, can work without supervision, begin projects independently, and are technically capable with a deep desire to become an expert in data science applications for ecommerce. You’re seeking a collaborative environment in which you can work alongside other technology experts to find the best answer and win as a team.\n\nThis position will report to the Director of Data Analytics on the Savage X Fenty Analytics Team. The position will also have an informal reporting line to the Sr. Director of Data Science on the TechStyleOS Architecture & Sciences team. We are a creative, ambitious, & fun-loving team who believes data products should be collaboratively designed, impactful to the business, and customized for the end user. Our analytics team acts as strategic partners to the business, making an impact by merging data with a deep understanding of the Savage customer experience.\n\nThis position will be based in El Segundo, California. For the right candidate, we will consider full-time remote work.\n\nWHY WORK IN DATA SCIENCE AT SAVAGE X?\n\nWork within a community of data scientists through our parent company TechStyle Fashion Group & our sister brand Fabletics, but be the first Data Scientist dedicated to the Savage X brand. This role will design the foundation for Savage’s future data science initiatives & experience fast paced growth\n\nDedicated resources to support you – Savage X is investing heavily in data science and has staffed dedicated engineering & product management to support your initiatives\n\nIndustry leading data technology stack – Snowflake, DataBricks, Segment Customer Data Platform, Apache Airflow, modeled reporting data warehouse, & more\n\nData-driven mindset is deeply foundational to the culture at Savage X; information flows freely throughout our organization and every key decision we make is backed by analysis\n\nBe a part of the larger Data Analytics organization at TechStyle Fashion Group (60+ team members); mentor & be mentored by our architects, scientists, analysts, & engineers\n\n\n\nLeverage our advanced tech stack, your knowledge of data science methods & models, and your partnerships with our senior engineers, scientists, and architects to determine the best approaches for algorithm development and implementation\n\nOwn algorithm development projects from start-to-end: design, develop, QA, deploy, experiment, and analyze\n\nPartner with dedicated product management & software engineering teams to implement data science algorithms onto our consumer-facing ecommerce website\n\nPartner with dedicated analysts to produce data visualizations, advanced reports, measurement and statistical models that explain and track algorithm performance against business KPIs\n\nPartner with the business to identify & understand opportunities for data science applications\n\nProvide thought leadership and data support to the business & other analytics team members around design, execution, and measurement of business KPIs\n\nCollaborate with other data scientists across our organization to share best practices, learn new techniques, and foster our organizational culture where data is central to decision making\n\n\n\nHigh degree of personal integrity, strong work ethic, & a desire to learn and grow in this role\n\n2+ years of work experience as a Data Scientist or Machine Learning Engineer\n\nFluent in R or Python (Python preferred) & SQL\n\nFamiliarity with Machine Learning techniques (e.g. classification, clustering, regularization, optimization, dimension reduction, feature engineering)\n\nStrong understanding of CS fundamentals (e.g. algorithms and data structures)\n\nExperience with attribution, causal inference, experimental design, and AB testing methods\n\nGood communication skills and ability to explain complex topics to a non-technical audience\n\n\n\nExperience partnering with product management & software engineering teams to implement algorithms into a production environment\n\nDegree or Advanced Degree in Statistics, Computer Science, or related fields\n\nExperience with Git and/or Airflow\n\nExperience with data visualization tools such as Tableau\n\nExperience in e-commerce, subscription models, and/or direct-to-consumer brands\n\nFamiliarity with web analytics tools & concepts (Google Analytics, pixel tracking, Segment Customer Data Platform or comparable tools)\n\n\n\nTechStyleOS is the globally integrated Operations and Services provider behind some of the fastest growing online fashion brands in history, including Fabletics, Savage X Fenty, JustFab, ShoeDazzle, and FabKids. With capabilities spanning technology, data science, supply chain management, fulfillment, customer service, and more, we help brands launch, scale and grow—across product categories and geographically. From predictive analytics to data-driven marketing and attribution, our unique approach is powered by our proprietary, end-to-end tech platform that enables the brands we serve to deliver a level of personalization, value, and satisfaction that are unrivaled in the fashion industry.\n\nSavage X Inc.is an equal opportunity employer. We recruit, employ, compensate, develop, and promote regardless of race, national origin, religion, sex, sexual orientation, gender identity, age, disability, genetic information, veteran status, and other protected status as required by applicable. At Savage X Inc. , we champion a vibrant workplace culture that thrives on diversity law and do not tolerate discrimination or harassment. We are one team from many backgrounds, innovating through diversity of individuals, who are driven by passion for creating an inclusive space for all. Savage X Inc. will continue to champion a workplace culture that prizes diversity and inclusivity.\n\nWe encourage you to apply regardless of meeting all qualifications and/or requirements.",[],[]\nWestern Governors University,Data Scientist-2,"St Louis, MO",,https://www.linkedin.com/jobs/view/2718750842/?eBP=CwEAAAF8A9ofOjpba68ujoLXQAaOCBXYiS4C1yUTdLuyzCZe9eu8Ol6E5B1OavyEuBokToqXvI8orCg9mTa7e7zpzyV9cy10rVkKoDvZEPBDm1du-SyxnPgFICjxXnkLuO4a476oKPYJHgNsT_wxWcVM7UPEe_A4rGFK3u5Nxocz6TO1M6QF-5VfM-4C6pvZ-cryEakyxdZm6GaHw7p9zbMvWyaV6i1CvmDXy27crdTMH0Tc23b0hvt7S-fanNHX4dGjk06Is5AS7iuF-deOP1A46W0iSZPaIhLkVkBxOTTw8Wp12qn_2fxTdloxilj5f3cSIkJJSt5CyCNX3COteQXhYjO8geRyhwPGFGyDICcz7CEBCngNc2CFZt-0BfY9piw&recommendedFlavor=COMPANY_RECRUIT&refId=uAGrvRCfo9q5%2BNk5EGGm4Q%3D%3D&trackingId=nI03Xvg4nBirIwj8TRNSAQ%3D%3D&trk=flagship3_search_srp_jobs,"About the job\nIf you’re passionate about building a better future for individuals, communities, and our country—and you’re committed to working hard to play your part in building that future—consider WGU as the next step in your career.\n\nDriven by a mission to expand access to higher education through online, competency-based degree programs, WGU is also committed to being a great place to work for a diverse workforce of student-focused professionals. The university has pioneered a new way to learn in the 21st century, one that has received praise from academic, industry, government, and media leaders. Whatever your role, working for WGU gives you a part to play in helping students graduate, creating a better tomorrow for themselves and their families.\n\n\n\n\n\n:\n\n\n\n\n\nAs an equal opportunity employer, WGU recognizes that our strength lies in our people. We are committed to diversity.",[],[]\nCarShield,Data Scientist,"St Louis, MO","50 minutes ago\nWithin the past 24 hours",https://www.linkedin.com/jobs/view/2723209281/?eBP=JOB_SEARCH_ORGANIC&recommendedFlavor=COMPANY_RECRUIT&refId=uAGrvRCfo9q5%2BNk5EGGm4Q%3D%3D&trackingId=KgTMJ%2FOU15u5GSRxFma6BA%3D%3D&trk=flagship3_search_srp_jobs,"About the job\nJob Description\nResponsible for overseeing the collection, storage and interpretation of data for businesses. Their duties include sifting through data points to create organized categories, comparing data points to current company processes and writing reports outlining business predictions or proposals.",[],[]\nAmerican Express Global Business Travel,Data Scientist,"Evansville, IN",6 days ago,https://www.linkedin.com/jobs/view/2716701280/?eBP=JOB_SEARCH_ORGANIC&recommendedFlavor=ACTIVELY_HIRING_COMPANY&refId=uAGrvRCfo9q5%2BNk5EGGm4Q%3D%3D&trackingId=%2FNnG2%2FT8eaQ5Auu0r1LwgQ%3D%3D&trk=flagship3_search_srp_jobs,"About the job\nThe Candidate Is Expected To Possess These Key Skills/technologies\n\nThe data science solutions engineer will be a member of the data analytics team and will lead efforts around building big data, data science, data quality, and BI/MI/AI solutions. An ideal candidate will be a The data science associate will have a growth-oriented, lean-startup mindset for building hands-on data science solutions. The ideal candidate will propose, experiment, execute, and operationalize advanced predictive, preemptive data solutions designed to help traveler, travel-manager, supplier, and client outcomes. The role will span full-scale product, enterprise, and operational data science. The candidate will focus and thrive in a hands-on applied role; he/she will demonstrate a strong penchant for quantitative, collaborative, outcome-oriented solutions-engineering.\n\n\n\n\n\n\n\nIndia>Virtual Location\n\nIt is our policy to provide equal employment opportunities to all individuals based on job-related qualifications and ability to perform a job, without regard to age, gender, gender identity, sexual orientation, race, color, religion, creed, national origin, disability, genetic information, veteran status, citizenship or marital status, and to maintain a non-discriminatory environment free from intimidation, harassment or bias based upon these grounds.\n\nPosted 6 Days Ago Full time J-46605\n\nAmerican Express Global Business Travel (GBT) is the world’s leading business partner for managed travel. We help companies and employees prosper by making sure travelers are present where and when it matters. We keep global business moving with the powerful backing of 16,000 travel professionals in more than 140 countries. Companies of all sizes, and in all places, rely on GBT to provide travel management services, organize meetings and events, and deliver business travel consulting.",[],[]\nKPMG US,"Associate, Data Scientist","Chicago, IL",,https://www.linkedin.com/jobs/view/2715182807/?eBP=CwEAAAF8A9ofOnXwJUuycM2gGRL1mcgrhKEvGOAPq7WvcuqVfhF3v31fFIUXMUZTB2_KdQBZae-zIVr4TaQH32qoMce5QiuRkyz35Qe4NunBDe1tO5oIPM_jRd0DRVV1Q2RE2NsRab1c65uetiOURFT5UacwF26coAIsRg_OLs_YoY_77ZEEy1w6kTyWThm4DdS0MF9eZsoLFRxcEZjVZPeHkjucUMmMlgDkGFolStofkAtovBw2_NeONzmFwJOWVe1GKQ1XqLioi_MqRW4kb3iJnvdR5E8PAb5PCjiNjJEfuIXO63QpyODR7y7X0dEhMCCkj_x1tLu5T0PQeNlCeZkpp7nWdyWZQtRzOXNNpH9yPYBeaNL_b3b8W8FSewL2XfI&recommendedFlavor=COMPANY_RECRUIT&refId=uAGrvRCfo9q5%2BNk5EGGm4Q%3D%3D&trackingId=tWMAG1KeTQs1iil6CAtrmQ%3D%3D&trk=flagship3_search_srp_jobs,"About the job\nRequisition Number: 70881 - 31\n\nDescription\n\nInnovate. Collaborate. Build. Create. Solve. The KPMG Digital Lighthouse is KPMG\'s award-winning Analytics & AI Center of Excellence recognized by clients and leading analyst firms in the US and globally. The KPMG Lighthouse is a curation of specialized technical capabilities and domain experts working across the digital landscape: applied data science, AI, data engineering and insights, software engineering, automation, and big data. Here, you\'ll work with a diverse team of professionals to explore and build solutions for clients in a multiplatform environment.\n\nYou\'ll be an important part of our high-energy, unique, fast-paced, and innovative culture that delivers with the agility of a tech startup and the backing of a leading global consulting firm. In this particular role, you\'ll work specifically in the AI Analytics & Engineering Community within the Digital Lighthouse, on a wide range of projects. From applied AI to optimization to big data platform engineering, your analytical and technical skills will drive real impact in the business world. At KPMG, our commitment to your career development helps to set us apart as an employer. We want to enhance your potential, both for yourself and as a contributor to our firm. That\'s why we provide every opportunity to expand your skills, knowledge and experiences through formal education and training programs, leadership development opportunities, and, as well as informal one-on-one coaching and mentoring from your KPMG colleagues.\n\nKPMG is currently seeking an Associate to join our KPMG Lighthouse - Center of Excellence for Advanced Analytics.\n\n\n\n\n\nKPMG LLP (the U.S. member firm of KPMG International) offers a comprehensive compensation and benefits package. KPMG is an affirmative action-equal opportunity employer. KPMG complies with all applicable federal, state and local laws regarding recruitment and hiring. All qualified applicants are considered for employment without regard to race, color, religion, age, sex, sexual orientation, gender identity, national origin, disability, protected veteran status, or any other category protected by applicable federal, state or local laws. The attached link contains further information regarding the firm\'s compliance with federal, state and local recruitment and hiring laws. No phone calls or agencies please.",[],[]\n"Systems Planning and Analysis, Inc.",Data Scientist - CWMD,"Reston, VA",,https://www.linkedin.com/jobs/view/2719087133/?eBP=CwEAAAF8A9ofOs3Q1pRDNomWkKq8WZKKrxzVFph6K2D4ymCmOH1h4zujhf7yBWfSjCtGRdbAe9Qx1ZFnDclUFpBrbo8MAanx6IoSd6oeFzDujMeur4dsRn-KObiuVvRuoE8jax4zNaj2cL0qgNswrocbKDKdYn82E7vixG1bp6oL35Xs1t4QTILoMHsFU_wTZqMgC7fCMPF3UzzYVoZ7UpLI2jutAFhJUtKKFD94vE5WkDbZOlxsnkXaN96-uctzECAJaz-JWJTbMRDHUek1yOdijC16J7HeR8V1Snd1B3f-lHcwkIyohdLJUUsi0dDpOWpoQNpv7XWOgAXT-NzCdHsRY99xfHcFFJK5r9UEJvFy__j3f60gUpWxie9aT8NO&recommendedFlavor=ACTIVELY_HIRING_COMPANY&refId=uAGrvRCfo9q5%2BNk5EGGm4Q%3D%3D&trackingId=sCAmjQEN8DY8a6u7bP7Yfg%3D%3D&trk=flagship3_search_srp_jobs,"About the job\nOverview\n\nSystems Planning and Analysis, Inc. (SPA) is a well-established and progressive defense contracting company in the DC Metro area. We are a professional services firm established in 1972 that has a long-standing reputation for unrivaled technical and analytical support to some of the top decision makers in the Federal Sector. We do state of the art work and have a cadre of outstanding professionals on our team.\n\nSPA assists the Defense Threat Reduction Agency (DTRA) in developing leading edge technologies to counter WMD in support of CCMDs and transitioning these technologies to services and SOCOM. SPA provides expertise across the full range of chemical, biological, radiological, nuclear and high-yield explosives (CBRNE) WMD, Counter Improvised Threat and Countering Threat Network technologies to support understanding, detection, identification, characterization, denial, control, disabling, defeating, disposing, safeguarding the force, managing consequences, and test and evaluation in support of military and civilian operations. #CJ #IN123\n\n\n\nProvides critical decision and analytic support to the Urgent Solutions Division in the Counter WMD Technologies Department of the Defense Threat Reduction Agency (DTRA). Conducts assessments, demonstrations, analysis, scientific codes, and other decision making in evaluating systems to counter WMD – biological and chemical threats, and counter threat networks. Develops knowledge regarding a stipulated issue through analysis of complex data sets, identifying actionable trends and problems. Uses appropriate methods to creatively explore, mine, analyze and manipulate data sets ranging in size from sparse to petabytes and type (e.g. small number of .pdf text reports, Excel spreadsheets and .csv files to repositories of image or audio data). Interprets results from multiple sources using a variety of techniques, ranging from simple data aggregation via statistical analysis to complex data mining, sensor analysis and learning techniques. Designs, develops, and implements technical solutions in support of concurrent analysis. Supports data models and defines the structure, attributes, and nomenclature of data elements. May evaluate new data sources for adherence to the organization\'s quality standards and ease of integration.",[],[]\nPerficient,Data Scientist,"St Louis, MO",,https://www.linkedin.com/jobs/view/2718055481/?eBP=CwEAAAF8A9ofOhOHpkH95U2fvN9F-goU76IrWGZ2_h1PEIqUbFxqxI6w3ypUfMSWfMRpTGEJDX9iicxg3Is1hE7MJg4ixQ2ZJfmdAFAR38WMuWQ9RdnHIEX4XrSbapYsM3nhi6Iyv6rH9MEC1PpEqmZkvr8JBlfU1asVfgP3pl3rW4IS6tIVJuzERferAoB3ycE-UB94AE92MTfUPPOUagL-zhuIsIcyQ6BMfE6eFGYpZpAHbvdti7-s852GjLAxYFovRGVyerfbSKSeZm6fVVXT2EaQfKYvMN5hBZBBVncwxNfzaaMBbKZ9moxmBg76BZ3UfB6YOntWLvvf06jI4VVqLMZ_BYq4iT8Jnp-YKt2dJxnECW-9zW66IbRoeRPT&recommendedFlavor=COMPANY_RECRUIT&refId=uAGrvRCfo9q5%2BNk5EGGm4Q%3D%3D&trackingId=UE7bblhxeqWJV52%2F9JWJew%3D%3D&trk=flagship3_search_srp_jobs,"About the job\nOverview\n\nAt Perficient you’ll deliver mission-critical technology and business solutions to Fortune 500 companies and some of the most recognized brands on the planet. And you’ll do it with cutting-edge technologies, thanks to our close partnerships with the world’s biggest vendors. Our network of offices across North America, as well as locations in India and China, will give you the opportunity to spread your wings, too.\n\nWe’re proud to be publicly recognized as a “Top Workplace” year after year. This is due, in no small part, to our entrepreneurial attitude and collaborative spirit that sets us apart and keeps our colleagues impassioned, driven, and fulfilled.\n\nPerficient currently has a career opportunity for a .\n\n\n\nThe role of the Data Scientist is for individuals passionate about identifying and delivering the right Business solution for each client using AI/ML. Our Data Scientists are keen to understand our customer needs, processes and pain points to determine the success factors and evaluation criteria that will needed to measure the effectiveness of an ML model.\n\nThe Data Scientist will be involved in the strategic planning of an engagement or helping the client make decisions about their future AI/ML roadmap and vision. Once the project as begun, the Data Scientist will be responsible for the execution of our established methodology, work with customer and/or the teams data engineer to identify data ingestion and transformation needs, exploration of the data and reporting findings, modeling and evaluation of training iterations. It is a key part of the role to be able to explain in non-technical terms the chosen modeling approach and findings from data exploration or training results.\n\nThe Data Scientist will work with Senior Project Managers to assist with daily operations exercising time management, communication and collaboration in a fast-paced environment to ensure the successful delivery of projects. The Data Scientist will interface with Perficient technical and business delivery personnel, as well as vendors and customers on a regular basis. May mentor junior data scientists.\n\n\n\n\n\n\n\nPerficient full-time employees receive complete and competitive benefits. We offer a collaborative work environment, competitive compensation, generous work/life opportunities and an outstanding benefits package that includes paid time off plus holidays. In addition, all colleagues are eligible for a number of rewards and recognition programs including billable bonus opportunities. Encouraging a healthy work/life balance and providing our colleagues great benefits are just part of what makes Perficient a great place to work.\n\n\n\nPerficient is the leading digital transformation consulting firm serving Global 2000 and enterprise customers throughout North America. With unparalleled information technology, management consulting and creative capabilities, Perficient and its Perficient Digital agency deliver vision, execution and value with outstanding digital experience, business optimization and industry solutions.\n\nOur work enables clients to improve productivity and competitiveness; grow and strengthen relationships with customers, suppliers and partners; and reduce costs. Perficient\'s professionals serve clients from a network of offices across North America and offshore locations in India and China. Traded on the Nasdaq Global Select Market, Perficient is a member of the Russell 2000 index and the S&P SmallCap 600 index.\n\nPerficient is an equal opportunity employer and all qualified applicants will receive consideration for employment without regard to race, color, religion, sex, national, origin, disability status, protected veteran status, or any other characteristic protected by law.\n\nThe above statements are not intended to be a complete statement of job content, rather to act as a guide to the essential functions performed by the employee assigned to this classification. Management retains the discretion to add or change the duties of the position at any time.\n\nSelect work authorization questions to ask when applicants apply",[],[]\nSavage X Fenty: Lingerie by Rihanna,Data Scientist,"El Segundo, CA",,https://www.linkedin.com/jobs/view/2721710042/?eBP=CwEAAAF8A9ofOhPzbWsStxaNEgpMLIbvO6Vvpf-kp8RGwvYOJKGphyyakdc_4SGsjm2VeRAGjmk-vJ6l9A5H_dap2I3Kpoi5h6gKOdZGPr43fehHk5BqkiDkbvKki_to05FvWLinOBzurpjsMFG3JoeqUJ8xRReTFcidZnHYUQE6jUxh0nf-LNmAPuQp7YZEmPEps45wTFpgh1xQa_nwnLky1x-nzte_8YwEIsmHKQ5z2VTOvDevWj_NNLxyfvp4hDKsNbBNyQC_28gSNPkqkg6iN2yFOum-URpP05X-BwoG-gN9HPsuQJs-bhqDslt8i6wwag517FTdUMMYWqa29zUtuHYFUf1ei5iEh0ffOBNdGGDafvdOB4z8Oqp3hxLnHhY&recommendedFlavor=ACTIVELY_HIRING_COMPANY&refId=uAGrvRCfo9q5%2BNk5EGGm4Q%3D%3D&trackingId=WJuu5WmPKTuvZRyUdmNdtA%3D%3D&trk=flagship3_search_srp_jobs,"About the job\nJob DescriptionSavage X Fenty is looking for a Data Scientist. Co-founded by music and fashion icon Rihanna, Savage X Fenty is the first line of lingerie that celebrates and speaks to all shades and shapes of people, and celebrates fearlessness, confidence and inclusivity.\n\nHOW DO YOU FIT IN?\n\nAs the Data Scientist, you will drive innovation in our customer shopping experience by providing the algorithms that power recommendation and personalization features across our ecommerce website. You will collaborate closely with the Data Analytics organization, the Global Technology organization, and the Savage X business to develop high-impact solutions to key optimization opportunities such as ecommerce conversion & product discovery. You will watch your work come to life by partnering with dedicated product & software engineering teams to deploy your algorithms into production.\n\nProjects you are likely to own in this role include:\n\nProduct Recommendation Algorithms (e.g., product discovery & upsell algorithms)\n\nFull Funnel Customer Segmentation (e.g., algorithmically define customer segments and stream segments to other tools such as our CRM or ad networks)\n\nInternal Optimization Algorithms (e.g., attribution models, sales propensity algorithms)\n\nAt Savage X Fenty you can expect to use Python and SQL every day. For larger projects requiring scale or automation you’ll likely be working with DataBricks and Airflow. While these are our defaults, you will have the flexibility to use tools that allow you to best fulfill your role. Additionally, we strongly believe in the need for ongoing education and so will encourage you to explore new technologies and modeling methods on a regular basis.\n\n\n\nYou’re the ideal candidate if you’re incredibly curious & see opportunities for data science applications in everything you do. Working smarter, not harder, is core to your DNA. You’re invigorated by the opportunity to learn that next tool or skill, and you come up with clever solutions to difficult problems. As much as you learned in school or at work, you’ve probably learned even more during your late-night hacking sessions. You take initiative, can work without supervision, begin projects independently, and are technically capable with a deep desire to become an expert in data science applications for ecommerce. You’re seeking a collaborative environment in which you can work alongside other technology experts to find the best answer and win as a team.\n\nThis position will report to the Director of Data Analytics on the Savage X Fenty Analytics Team. The position will also have an informal reporting line to the Sr. Director of Data Science on the TechStyleOS Architecture & Sciences team. We are a creative, ambitious, & fun-loving team who believes data products should be collaboratively designed, impactful to the business, and customized for the end user. Our analytics team acts as strategic partners to the business, making an impact by merging data with a deep understanding of the Savage customer experience.\n\nThis position will be based in El Segundo, California. For the right candidate, we will consider full-time remote work.\n\nWHY WORK IN DATA SCIENCE AT SAVAGE X?\n\nWork within a community of data scientists through our parent company TechStyle Fashion Group & our sister brand Fabletics, but be the first Data Scientist dedicated to the Savage X brand. This role will design the foundation for Savage’s future data science initiatives & experience fast paced growth\n\nDedicated resources to support you – Savage X is investing heavily in data science and has staffed dedicated engineering & product management to support your initiatives\n\nIndustry leading data technology stack – Snowflake, DataBricks, Segment Customer Data Platform, Apache Airflow, modeled reporting data warehouse, & more\n\nData-driven mindset is deeply foundational to the culture at Savage X; information flows freely throughout our organization and every key decision we make is backed by analysis\n\nBe a part of the larger Data Analytics organization at TechStyle Fashion Group (60+ team members); mentor & be mentored by our architects, scientists, analysts, & engineers\n\n\n\nLeverage our advanced tech stack, your knowledge of data science methods & models, and your partnerships with our senior engineers, scientists, and architects to determine the best approaches for algorithm development and implementation\n\nOwn algorithm development projects from start-to-end: design, develop, QA, deploy, experiment, and analyze\n\nPartner with dedicated product management & software engineering teams to implement data science algorithms onto our consumer-facing ecommerce website\n\nPartner with dedicated analysts to produce data visualizations, advanced reports, measurement and statistical models that explain and track algorithm performance against business KPIs\n\nPartner with the business to identify & understand opportunities for data science applications\n\nProvide thought leadership and data support to the business & other analytics team members around design, execution, and measurement of business KPIs\n\nCollaborate with other data scientists across our organization to share best practices, learn new techniques, and foster our organizational culture where data is central to decision making\n\n\n\nHigh degree of personal integrity, strong work ethic, & a desire to learn and grow in this role\n\n2+ years of work experience as a Data Scientist or Machine Learning Engineer\n\nFluent in R or Python (Python preferred) & SQL\n\nFamiliarity with Machine Learning techniques (e.g. classification, clustering, regularization, optimization, dimension reduction, feature engineering)\n\nStrong understanding of CS fundamentals (e.g. algorithms and data structures)\n\nExperience with attribution, causal inference, experimental design, and AB testing methods\n\nGood communication skills and ability to explain complex topics to a non-technical audience\n\n\n\nExperience partnering with product management & software engineering teams to implement algorithms into a production environment\n\nDegree or Advanced Degree in Statistics, Computer Science, or related fields\n\nExperience with Git and/or Airflow\n\nExperience with data visualization tools such as Tableau\n\nExperience in e-commerce, subscription models, and/or direct-to-consumer brands\n\nFamiliarity with web analytics tools & concepts (Google Analytics, pixel tracking, Segment Customer Data Platform or comparable tools)\n\n\n\nTechStyleOS is the globally integrated Operations and Services provider behind some of the fastest growing online fashion brands in history, including Fabletics, Savage X Fenty, JustFab, ShoeDazzle, and FabKids. With capabilities spanning technology, data science, supply chain management, fulfillment, customer service, and more, we help brands launch, scale and grow—across product categories and geographically. From predictive analytics to data-driven marketing and attribution, our unique approach is powered by our proprietary, end-to-end tech platform that enables the brands we serve to deliver a level of personalization, value, and satisfaction that are unrivaled in the fashion industry.\n\nSavage X Inc.is an equal opportunity employer. We recruit, employ, compensate, develop, and promote regardless of race, national origin, religion, sex, sexual orientation, gender identity, age, disability, genetic information, veteran status, and other protected status as required by applicable. At Savage X Inc. , we champion a vibrant workplace culture that thrives on diversity law and do not tolerate discrimination or harassment. We are one team from many backgrounds, innovating through diversity of individuals, who are driven by passion for creating an inclusive space for all. Savage X Inc. will continue to champion a workplace culture that prizes diversity and inclusivity.\n\nWe encourage you to apply regardless of meeting all qualifications and/or requirements.",[],[]\nWestern Governors University,Data Scientist-2,"St Louis, MO",,https://www.linkedin.com/jobs/view/2718750842/?eBP=CwEAAAF8A9ofOjpba68ujoLXQAaOCBXYiS4C1yUTdLuyzCZe9eu8Ol6E5B1OavyEuBokToqXvI8orCg9mTa7e7zpzyV9cy10rVkKoDvZEPBDm1du-SyxnPgFICjxXnkLuO4a476oKPYJHgNsT_wxWcVM7UPEe_A4rGFK3u5Nxocz6TO1M6QF-5VfM-4C6pvZ-cryEakyxdZm6GaHw7p9zbMvWyaV6i1CvmDXy27crdTMH0Tc23b0hvt7S-fanNHX4dGjk06Is5AS7iuF-deOP1A46W0iSZPaIhLkVkBxOTTw8Wp12qn_2fxTdloxilj5f3cSIkJJSt5CyCNX3COteQXhYjO8geRyhwPGFGyDICcz7CEBCngNc2CFZt-0BfY9piw&recommendedFlavor=COMPANY_RECRUIT&refId=uAGrvRCfo9q5%2BNk5EGGm4Q%3D%3D&trackingId=nI03Xvg4nBirIwj8TRNSAQ%3D%3D&trk=flagship3_search_srp_jobs,"About the job\nIf you’re passionate about building a better future for individuals, communities, and our country—and you’re committed to working hard to play your part in building that future—consider WGU as the next step in your career.\n\nDriven by a mission to expand access to higher education through online, competency-based degree programs, WGU is also committed to being a great place to work for a diverse workforce of student-focused professionals. The university has pioneered a new way to learn in the 21st century, one that has received praise from academic, industry, government, and media leaders. Whatever your role, working for WGU gives you a part to play in helping students graduate, creating a better tomorrow for themselves and their families.\n\n\n\n\n\n:\n\n\n\n\n\nAs an equal opportunity employer, WGU recognizes that our strength lies in our people. We are committed to diversity.",[],[]\nCarShield,Data Scientist,"St Louis, MO","50 minutes ago\nWithin the past 24 hours",https://www.linkedin.com/jobs/view/2723209281/?eBP=JOB_SEARCH_ORGANIC&recommendedFlavor=COMPANY_RECRUIT&refId=uAGrvRCfo9q5%2BNk5EGGm4Q%3D%3D&trackingId=KgTMJ%2FOU15u5GSRxFma6BA%3D%3D&trk=flagship3_search_srp_jobs,"About the job\nJob Description\nResponsible for overseeing the collection, storage and interpretation of data for businesses. Their duties include sifting through data points to create organized categories, comparing data points to current company processes and writing reports outlining business predictions or proposals.",[],[]\nAmerican Express Global Business Travel,Data Scientist,"Evansville, IN",6 days ago,https://www.linkedin.com/jobs/view/2716701280/?eBP=JOB_SEARCH_ORGANIC&recommendedFlavor=ACTIVELY_HIRING_COMPANY&refId=uAGrvRCfo9q5%2BNk5EGGm4Q%3D%3D&trackingId=%2FNnG2%2FT8eaQ5Auu0r1LwgQ%3D%3D&trk=flagship3_search_srp_jobs,"About the job\nThe Candidate Is Expected To Possess These Key Skills/technologies\n\nThe data science solutions engineer will be a member of the data analytics team and will lead efforts around building big data, data science, data quality, and BI/MI/AI solutions. An ideal candidate will be a The data science associate will have a growth-oriented, lean-startup mindset for building hands-on data science solutions. The ideal candidate will propose, experiment, execute, and operationalize advanced predictive, preemptive data solutions designed to help traveler, travel-manager, supplier, and client outcomes. The role will span full-scale product, enterprise, and operational data science. The candidate will focus and thrive in a hands-on applied role; he/she will demonstrate a strong penchant for quantitative, collaborative, outcome-oriented solutions-engineering.\n\n\n\n\n\n\n\nIndia>Virtual Location\n\nIt is our policy to provide equal employment opportunities to all individuals based on job-related qualifications and ability to perform a job, without regard to age, gender, gender identity, sexual orientation, race, color, religion, creed, national origin, disability, genetic information, veteran status, citizenship or marital status, and to maintain a non-discriminatory environment free from intimidation, harassment or bias based upon these grounds.\n\nPosted 6 Days Ago Full time J-46605\n\nAmerican Express Global Business Travel (GBT) is the world’s leading business partner for managed travel. We help companies and employees prosper by making sure travelers are present where and when it matters. We keep global business moving with the powerful backing of 16,000 travel professionals in more than 140 countries. Companies of all sizes, and in all places, rely on GBT to provide travel management services, organize meetings and events, and deliver business travel consulting.",[],[]\nKPMG US,"Associate, Data Scientist","Chicago, IL",,https://www.linkedin.com/jobs/view/2715182807/?eBP=CwEAAAF8A9ofOnXwJUuycM2gGRL1mcgrhKEvGOAPq7WvcuqVfhF3v31fFIUXMUZTB2_KdQBZae-zIVr4TaQH32qoMce5QiuRkyz35Qe4NunBDe1tO5oIPM_jRd0DRVV1Q2RE2NsRab1c65uetiOURFT5UacwF26coAIsRg_OLs_YoY_77ZEEy1w6kTyWThm4DdS0MF9eZsoLFRxcEZjVZPeHkjucUMmMlgDkGFolStofkAtovBw2_NeONzmFwJOWVe1GKQ1XqLioi_MqRW4kb3iJnvdR5E8PAb5PCjiNjJEfuIXO63QpyODR7y7X0dEhMCCkj_x1tLu5T0PQeNlCeZkpp7nWdyWZQtRzOXNNpH9yPYBeaNL_b3b8W8FSewL2XfI&recommendedFlavor=COMPANY_RECRUIT&refId=uAGrvRCfo9q5%2BNk5EGGm4Q%3D%3D&trackingId=tWMAG1KeTQs1iil6CAtrmQ%3D%3D&trk=flagship3_search_srp_jobs,"About the job\nRequisition Number: 70881 - 31\n\nDescription\n\nInnovate. Collaborate. Build. Create. Solve. The KPMG Digital Lighthouse is KPMG\'s award-winning Analytics & AI Center of Excellence recognized by clients and leading analyst firms in the US and globally. The KPMG Lighthouse is a curation of specialized technical capabilities and domain experts working across the digital landscape: applied data science, AI, data engineering and insights, software engineering, automation, and big data. Here, you\'ll work with a diverse team of professionals to explore and build solutions for clients in a multiplatform environment.\n\nYou\'ll be an important part of our high-energy, unique, fast-paced, and innovative culture that delivers with the agility of a tech startup and the backing of a leading global consulting firm. In this particular role, you\'ll work specifically in the AI Analytics & Engineering Community within the Digital Lighthouse, on a wide range of projects. From applied AI to optimization to big data platform engineering, your analytical and technical skills will drive real impact in the business world. At KPMG, our commitment to your career development helps to set us apart as an employer. We want to enhance your potential, both for yourself and as a contributor to our firm. That\'s why we provide every opportunity to expand your skills, knowledge and experiences through formal education and training programs, leadership development opportunities, and, as well as informal one-on-one coaching and mentoring from your KPMG colleagues.\n\nKPMG is currently seeking an Associate to join our KPMG Lighthouse - Center of Excellence for Advanced Analytics.\n\n\n\n\n\nKPMG LLP (the U.S. member firm of KPMG International) offers a comprehensive compensation and benefits package. KPMG is an affirmative action-equal opportunity employer. KPMG complies with all applicable federal, state and local laws regarding recruitment and hiring. All qualified applicants are considered for employment without regard to race, color, religion, age, sex, sexual orientation, gender identity, national origin, disability, protected veteran status, or any other category protected by applicable federal, state or local laws. The attached link contains further information regarding the firm\'s compliance with federal, state and local recruitment and hiring laws. No phone calls or agencies please.",[],[]\n"Systems Planning and Analysis, Inc.",Data Scientist - CWMD,"Reston, VA",,https://www.linkedin.com/jobs/view/2719087133/?eBP=CwEAAAF8A9ofOs3Q1pRDNomWkKq8WZKKrxzVFph6K2D4ymCmOH1h4zujhf7yBWfSjCtGRdbAe9Qx1ZFnDclUFpBrbo8MAanx6IoSd6oeFzDujMeur4dsRn-KObiuVvRuoE8jax4zNaj2cL0qgNswrocbKDKdYn82E7vixG1bp6oL35Xs1t4QTILoMHsFU_wTZqMgC7fCMPF3UzzYVoZ7UpLI2jutAFhJUtKKFD94vE5WkDbZOlxsnkXaN96-uctzECAJaz-JWJTbMRDHUek1yOdijC16J7HeR8V1Snd1B3f-lHcwkIyohdLJUUsi0dDpOWpoQNpv7XWOgAXT-NzCdHsRY99xfHcFFJK5r9UEJvFy__j3f60gUpWxie9aT8NO&recommendedFlavor=ACTIVELY_HIRING_COMPANY&refId=uAGrvRCfo9q5%2BNk5EGGm4Q%3D%3D&trackingId=sCAmjQEN8DY8a6u7bP7Yfg%3D%3D&trk=flagship3_search_srp_jobs,"About the job\nOverview\n\nSystems Planning and Analysis, Inc. (SPA) is a well-established and progressive defense contracting company in the DC Metro area. We are a professional services firm established in 1972 that has a long-standing reputation for unrivaled technical and analytical support to some of the top decision makers in the Federal Sector. We do state of the art work and have a cadre of outstanding professionals on our team.\n\nSPA assists the Defense Threat Reduction Agency (DTRA) in developing leading edge technologies to counter WMD in support of CCMDs and transitioning these technologies to services and SOCOM. SPA provides expertise across the full range of chemical, biological, radiological, nuclear and high-yield explosives (CBRNE) WMD, Counter Improvised Threat and Countering Threat Network technologies to support understanding, detection, identification, characterization, denial, control, disabling, defeating, disposing, safeguarding the force, managing consequences, and test and evaluation in support of military and civilian operations. #CJ #IN123\n\n\n\nProvides critical decision and analytic support to the Urgent Solutions Division in the Counter WMD Technologies Department of the Defense Threat Reduction Agency (DTRA). Conducts assessments, demonstrations, analysis, scientific codes, and other decision making in evaluating systems to counter WMD – biological and chemical threats, and counter threat networks. Develops knowledge regarding a stipulated issue through analysis of complex data sets, identifying actionable trends and problems. Uses appropriate methods to creatively explore, mine, analyze and manipulate data sets ranging in size from sparse to petabytes and type (e.g. small number of .pdf text reports, Excel spreadsheets and .csv files to repositories of image or audio data). Interprets results from multiple sources using a variety of techniques, ranging from simple data aggregation via statistical analysis to complex data mining, sensor analysis and learning techniques. Designs, develops, and implements technical solutions in support of concurrent analysis. Supports data models and defines the structure, attributes, and nomenclature of data elements. May evaluate new data sources for adherence to the organization\'s quality standards and ease of integration.",[],[]\nPerficient,Data Scientist,"St Louis, MO",,https://www.linkedin.com/jobs/view/2718055481/?eBP=CwEAAAF8A9ofOhOHpkH95U2fvN9F-goU76IrWGZ2_h1PEIqUbFxqxI6w3ypUfMSWfMRpTGEJDX9iicxg3Is1hE7MJg4ixQ2ZJfmdAFAR38WMuWQ9RdnHIEX4XrSbapYsM3nhi6Iyv6rH9MEC1PpEqmZkvr8JBlfU1asVfgP3pl3rW4IS6tIVJuzERferAoB3ycE-UB94AE92MTfUPPOUagL-zhuIsIcyQ6BMfE6eFGYpZpAHbvdti7-s852GjLAxYFovRGVyerfbSKSeZm6fVVXT2EaQfKYvMN5hBZBBVncwxNfzaaMBbKZ9moxmBg76BZ3UfB6YOntWLvvf06jI4VVqLMZ_BYq4iT8Jnp-YKt2dJxnECW-9zW66IbRoeRPT&recommendedFlavor=COMPANY_RECRUIT&refId=uAGrvRCfo9q5%2BNk5EGGm4Q%3D%3D&trackingId=UE7bblhxeqWJV52%2F9JWJew%3D%3D&trk=flagship3_search_srp_jobs,"About the job\nOverview\n\nAt Perficient you’ll deliver mission-critical technology and business solutions to Fortune 500 companies and some of the most recognized brands on the planet. And you’ll do it with cutting-edge technologies, thanks to our close partnerships with the world’s biggest vendors. Our network of offices across North America, as well as locations in India and China, will give you the opportunity to spread your wings, too.\n\nWe’re proud to be publicly recognized as a “Top Workplace” year after year. This is due, in no small part, to our entrepreneurial attitude and collaborative spirit that sets us apart and keeps our colleagues impassioned, driven, and fulfilled.\n\nPerficient currently has a career opportunity for a .\n\n\n\nThe role of the Data Scientist is for individuals passionate about identifying and delivering the right Business solution for each client using AI/ML. Our Data Scientists are keen to understand our customer needs, processes and pain points to determine the success factors and evaluation criteria that will needed to measure the effectiveness of an ML model.\n\nThe Data Scientist will be involved in the strategic planning of an engagement or helping the client make decisions about their future AI/ML roadmap and vision. Once the project as begun, the Data Scientist will be responsible for the execution of our established methodology, work with customer and/or the teams data engineer to identify data ingestion and transformation needs, exploration of the data and reporting findings, modeling and evaluation of training iterations. It is a key part of the role to be able to explain in non-technical terms the chosen modeling approach and findings from data exploration or training results.\n\nThe Data Scientist will work with Senior Project Managers to assist with daily operations exercising time management, communication and collaboration in a fast-paced environment to ensure the successful delivery of projects. The Data Scientist will interface with Perficient technical and business delivery personnel, as well as vendors and customers on a regular basis. May mentor junior data scientists.\n\n\n\n\n\n\n\nPerficient full-time employees receive complete and competitive benefits. We offer a collaborative work environment, competitive compensation, generous work/life opportunities and an outstanding benefits package that includes paid time off plus holidays. In addition, all colleagues are eligible for a number of rewards and recognition programs including billable bonus opportunities. Encouraging a healthy work/life balance and providing our colleagues great benefits are just part of what makes Perficient a great place to work.\n\n\n\nPerficient is the leading digital transformation consulting firm serving Global 2000 and enterprise customers throughout North America. With unparalleled information technology, management consulting and creative capabilities, Perficient and its Perficient Digital agency deliver vision, execution and value with outstanding digital experience, business optimization and industry solutions.\n\nOur work enables clients to improve productivity and competitiveness; grow and strengthen relationships with customers, suppliers and partners; and reduce costs. Perficient\'s professionals serve clients from a network of offices across North America and offshore locations in India and China. Traded on the Nasdaq Global Select Market, Perficient is a member of the Russell 2000 index and the S&P SmallCap 600 index.\n\nPerficient is an equal opportunity employer and all qualified applicants will receive consideration for employment without regard to race, color, religion, sex, national, origin, disability status, protected veteran status, or any other characteristic protected by law.\n\nThe above statements are not intended to be a complete statement of job content, rather to act as a guide to the essential functions performed by the employee assigned to this classification. Management retains the discretion to add or change the duties of the position at any time.\n\nSelect work authorization questions to ask when applicants apply",[],[]\nSavage X Fenty: Lingerie by Rihanna,Data Scientist,"El Segundo, CA",,https://www.linkedin.com/jobs/view/2721710042/?eBP=CwEAAAF8A9ofOhPzbWsStxaNEgpMLIbvO6Vvpf-kp8RGwvYOJKGphyyakdc_4SGsjm2VeRAGjmk-vJ6l9A5H_dap2I3Kpoi5h6gKOdZGPr43fehHk5BqkiDkbvKki_to05FvWLinOBzurpjsMFG3JoeqUJ8xRReTFcidZnHYUQE6jUxh0nf-LNmAPuQp7YZEmPEps45wTFpgh1xQa_nwnLky1x-nzte_8YwEIsmHKQ5z2VTOvDevWj_NNLxyfvp4hDKsNbBNyQC_28gSNPkqkg6iN2yFOum-URpP05X-BwoG-gN9HPsuQJs-bhqDslt8i6wwag517FTdUMMYWqa29zUtuHYFUf1ei5iEh0ffOBNdGGDafvdOB4z8Oqp3hxLnHhY&recommendedFlavor=ACTIVELY_HIRING_COMPANY&refId=uAGrvRCfo9q5%2BNk5EGGm4Q%3D%3D&trackingId=WJuu5WmPKTuvZRyUdmNdtA%3D%3D&trk=flagship3_search_srp_jobs,"About the job\nJob DescriptionSavage X Fenty is looking for a Data Scientist. Co-founded by music and fashion icon Rihanna, Savage X Fenty is the first line of lingerie that celebrates and speaks to all shades and shapes of people, and celebrates fearlessness, confidence and inclusivity.\n\nHOW DO YOU FIT IN?\n\nAs the Data Scientist, you will drive innovation in our customer shopping experience by providing the algorithms that power recommendation and personalization features across our ecommerce website. You will collaborate closely with the Data Analytics organization, the Global Technology organization, and the Savage X business to develop high-impact solutions to key optimization opportunities such as ecommerce conversion & product discovery. You will watch your work come to life by partnering with dedicated product & software engineering teams to deploy your algorithms into production.\n\nProjects you are likely to own in this role include:\n\nProduct Recommendation Algorithms (e.g., product discovery & upsell algorithms)\n\nFull Funnel Customer Segmentation (e.g., algorithmically define customer segments and stream segments to other tools such as our CRM or ad networks)\n\nInternal Optimization Algorithms (e.g., attribution models, sales propensity algorithms)\n\nAt Savage X Fenty you can expect to use Python and SQL every day. For larger projects requiring scale or automation you’ll likely be working with DataBricks and Airflow. While these are our defaults, you will have the flexibility to use tools that allow you to best fulfill your role. Additionally, we strongly believe in the need for ongoing education and so will encourage you to explore new technologies and modeling methods on a regular basis.\n\n\n\nYou’re the ideal candidate if you’re incredibly curious & see opportunities for data science applications in everything you do. Working smarter, not harder, is core to your DNA. You’re invigorated by the opportunity to learn that next tool or skill, and you come up with clever solutions to difficult problems. As much as you learned in school or at work, you’ve probably learned even more during your late-night hacking sessions. You take initiative, can work without supervision, begin projects independently, and are technically capable with a deep desire to become an expert in data science applications for ecommerce. You’re seeking a collaborative environment in which you can work alongside other technology experts to find the best answer and win as a team.\n\nThis position will report to the Director of Data Analytics on the Savage X Fenty Analytics Team. The position will also have an informal reporting line to the Sr. Director of Data Science on the TechStyleOS Architecture & Sciences team. We are a creative, ambitious, & fun-loving team who believes data products should be collaboratively designed, impactful to the business, and customized for the end user. Our analytics team acts as strategic partners to the business, making an impact by merging data with a deep understanding of the Savage customer experience.\n\nThis position will be based in El Segundo, California. For the right candidate, we will consider full-time remote work.\n\nWHY WORK IN DATA SCIENCE AT SAVAGE X?\n\nWork within a community of data scientists through our parent company TechStyle Fashion Group & our sister brand Fabletics, but be the first Data Scientist dedicated to the Savage X brand. This role will design the foundation for Savage’s future data science initiatives & experience fast paced growth\n\nDedicated resources to support you – Savage X is investing heavily in data science and has staffed dedicated engineering & product management to support your initiatives\n\nIndustry leading data technology stack – Snowflake, DataBricks, Segment Customer Data Platform, Apache Airflow, modeled reporting data warehouse, & more\n\nData-driven mindset is deeply foundational to the culture at Savage X; information flows freely throughout our organization and every key decision we make is backed by analysis\n\nBe a part of the larger Data Analytics organization at TechStyle Fashion Group (60+ team members); mentor & be mentored by our architects, scientists, analysts, & engineers\n\n\n\nLeverage our advanced tech stack, your knowledge of data science methods & models, and your partnerships with our senior engineers, scientists, and architects to determine the best approaches for algorithm development and implementation\n\nOwn algorithm development projects from start-to-end: design, develop, QA, deploy, experiment, and analyze\n\nPartner with dedicated product management & software engineering teams to implement data science algorithms onto our consumer-facing ecommerce website\n\nPartner with dedicated analysts to produce data visualizations, advanced reports, measurement and statistical models that explain and track algorithm performance against business KPIs\n\nPartner with the business to identify & understand opportunities for data science applications\n\nProvide thought leadership and data support to the business & other analytics team members around design, execution, and measurement of business KPIs\n\nCollaborate with other data scientists across our organization to share best practices, learn new techniques, and foster our organizational culture where data is central to decision making\n\n\n\nHigh degree of personal integrity, strong work ethic, & a desire to learn and grow in this role\n\n2+ years of work experience as a Data Scientist or Machine Learning Engineer\n\nFluent in R or Python (Python preferred) & SQL\n\nFamiliarity with Machine Learning techniques (e.g. classification, clustering, regularization, optimization, dimension reduction, feature engineering)\n\nStrong understanding of CS fundamentals (e.g. algorithms and data structures)\n\nExperience with attribution, causal inference, experimental design, and AB testing methods\n\nGood communication skills and ability to explain complex topics to a non-technical audience\n\n\n\nExperience partnering with product management & software engineering teams to implement algorithms into a production environment\n\nDegree or Advanced Degree in Statistics, Computer Science, or related fields\n\nExperience with Git and/or Airflow\n\nExperience with data visualization tools such as Tableau\n\nExperience in e-commerce, subscription models, and/or direct-to-consumer brands\n\nFamiliarity with web analytics tools & concepts (Google Analytics, pixel tracking, Segment Customer Data Platform or comparable tools)\n\n\n\nTechStyleOS is the globally integrated Operations and Services provider behind some of the fastest growing online fashion brands in history, including Fabletics, Savage X Fenty, JustFab, ShoeDazzle, and FabKids. With capabilities spanning technology, data science, supply chain management, fulfillment, customer service, and more, we help brands launch, scale and grow—across product categories and geographically. From predictive analytics to data-driven marketing and attribution, our unique approach is powered by our proprietary, end-to-end tech platform that enables the brands we serve to deliver a level of personalization, value, and satisfaction that are unrivaled in the fashion industry.\n\nSavage X Inc.is an equal opportunity employer. We recruit, employ, compensate, develop, and promote regardless of race, national origin, religion, sex, sexual orientation, gender identity, age, disability, genetic information, veteran status, and other protected status as required by applicable. At Savage X Inc. , we champion a vibrant workplace culture that thrives on diversity law and do not tolerate discrimination or harassment. We are one team from many backgrounds, innovating through diversity of individuals, who are driven by passion for creating an inclusive space for all. Savage X Inc. will continue to champion a workplace culture that prizes diversity and inclusivity.\n\nWe encourage you to apply regardless of meeting all qualifications and/or requirements.",[],[]\nWestern Governors University,Data Scientist-2,"St Louis, MO",,https://www.linkedin.com/jobs/view/2718750842/?eBP=CwEAAAF8A9ofOjpba68ujoLXQAaOCBXYiS4C1yUTdLuyzCZe9eu8Ol6E5B1OavyEuBokToqXvI8orCg9mTa7e7zpzyV9cy10rVkKoDvZEPBDm1du-SyxnPgFICjxXnkLuO4a476oKPYJHgNsT_wxWcVM7UPEe_A4rGFK3u5Nxocz6TO1M6QF-5VfM-4C6pvZ-cryEakyxdZm6GaHw7p9zbMvWyaV6i1CvmDXy27crdTMH0Tc23b0hvt7S-fanNHX4dGjk06Is5AS7iuF-deOP1A46W0iSZPaIhLkVkBxOTTw8Wp12qn_2fxTdloxilj5f3cSIkJJSt5CyCNX3COteQXhYjO8geRyhwPGFGyDICcz7CEBCngNc2CFZt-0BfY9piw&recommendedFlavor=COMPANY_RECRUIT&refId=uAGrvRCfo9q5%2BNk5EGGm4Q%3D%3D&trackingId=nI03Xvg4nBirIwj8TRNSAQ%3D%3D&trk=flagship3_search_srp_jobs,"About the job\nIf you’re passionate about building a better future for individuals, communities, and our country—and you’re committed to working hard to play your part in building that future—consider WGU as the next step in your career.\n\nDriven by a mission to expand access to higher education through online, competency-based degree programs, WGU is also committed to being a great place to work for a diverse workforce of student-focused professionals. The university has pioneered a new way to learn in the 21st century, one that has received praise from academic, industry, government, and media leaders. Whatever your role, working for WGU gives you a part to play in helping students graduate, creating a better tomorrow for themselves and their families.\n\n\n\n\n\n:\n\n\n\n\n\nAs an equal opportunity employer, WGU recognizes that our strength lies in our people. We are committed to diversity.",[],[]\nCarShield,Data Scientist,"St Louis, MO","50 minutes ago\nWithin the past 24 hours",https://www.linkedin.com/jobs/view/2723209281/?eBP=JOB_SEARCH_ORGANIC&recommendedFlavor=COMPANY_RECRUIT&refId=uAGrvRCfo9q5%2BNk5EGGm4Q%3D%3D&trackingId=KgTMJ%2FOU15u5GSRxFma6BA%3D%3D&trk=flagship3_search_srp_jobs,"About the job\nJob Description\nResponsible for overseeing the collection, storage and interpretation of data for businesses. Their duties include sifting through data points to create organized categories, comparing data points to current company processes and writing reports outlining business predictions or proposals.",[],[]\nAmerican Express Global Business Travel,Data Scientist,"Evansville, IN",6 days ago,https://www.linkedin.com/jobs/view/2716701280/?eBP=JOB_SEARCH_ORGANIC&recommendedFlavor=ACTIVELY_HIRING_COMPANY&refId=uAGrvRCfo9q5%2BNk5EGGm4Q%3D%3D&trackingId=%2FNnG2%2FT8eaQ5Auu0r1LwgQ%3D%3D&trk=flagship3_search_srp_jobs,"About the job\nThe Candidate Is Expected To Possess These Key Skills/technologies\n\nThe data science solutions engineer will be a member of the data analytics team and will lead efforts around building big data, data science, data quality, and BI/MI/AI solutions. An ideal candidate will be a The data science associate will have a growth-oriented, lean-startup mindset for building hands-on data science solutions. The ideal candidate will propose, experiment, execute, and operationalize advanced predictive, preemptive data solutions designed to help traveler, travel-manager, supplier, and client outcomes. The role will span full-scale product, enterprise, and operational data science. The candidate will focus and thrive in a hands-on applied role; he/she will demonstrate a strong penchant for quantitative, collaborative, outcome-oriented solutions-engineering.\n\n\n\n\n\n\n\nIndia>Virtual Location\n\nIt is our policy to provide equal employment opportunities to all individuals based on job-related qualifications and ability to perform a job, without regard to age, gender, gender identity, sexual orientation, race, color, religion, creed, national origin, disability, genetic information, veteran status, citizenship or marital status, and to maintain a non-discriminatory environment free from intimidation, harassment or bias based upon these grounds.\n\nPosted 6 Days Ago Full time J-46605\n\nAmerican Express Global Business Travel (GBT) is the world’s leading business partner for managed travel. We help companies and employees prosper by making sure travelers are present where and when it matters. We keep global business moving with the powerful backing of 16,000 travel professionals in more than 140 countries. Companies of all sizes, and in all places, rely on GBT to provide travel management services, organize meetings and events, and deliver business travel consulting.",[],[]\nKPMG US,"Associate, Data Scientist","Chicago, IL",,https://www.linkedin.com/jobs/view/2715182807/?eBP=CwEAAAF8A9ofOnXwJUuycM2gGRL1mcgrhKEvGOAPq7WvcuqVfhF3v31fFIUXMUZTB2_KdQBZae-zIVr4TaQH32qoMce5QiuRkyz35Qe4NunBDe1tO5oIPM_jRd0DRVV1Q2RE2NsRab1c65uetiOURFT5UacwF26coAIsRg_OLs_YoY_77ZEEy1w6kTyWThm4DdS0MF9eZsoLFRxcEZjVZPeHkjucUMmMlgDkGFolStofkAtovBw2_NeONzmFwJOWVe1GKQ1XqLioi_MqRW4kb3iJnvdR5E8PAb5PCjiNjJEfuIXO63QpyODR7y7X0dEhMCCkj_x1tLu5T0PQeNlCeZkpp7nWdyWZQtRzOXNNpH9yPYBeaNL_b3b8W8FSewL2XfI&recommendedFlavor=COMPANY_RECRUIT&refId=uAGrvRCfo9q5%2BNk5EGGm4Q%3D%3D&trackingId=tWMAG1KeTQs1iil6CAtrmQ%3D%3D&trk=flagship3_search_srp_jobs,"About the job\nRequisition Number: 70881 - 31\n\nDescription\n\nInnovate. Collaborate. Build. Create. Solve. The KPMG Digital Lighthouse is KPMG\'s award-winning Analytics & AI Center of Excellence recognized by clients and leading analyst firms in the US and globally. The KPMG Lighthouse is a curation of specialized technical capabilities and domain experts working across the digital landscape: applied data science, AI, data engineering and insights, software engineering, automation, and big data. Here, you\'ll work with a diverse team of professionals to explore and build solutions for clients in a multiplatform environment.\n\nYou\'ll be an important part of our high-energy, unique, fast-paced, and innovative culture that delivers with the agility of a tech startup and the backing of a leading global consulting firm. In this particular role, you\'ll work specifically in the AI Analytics & Engineering Community within the Digital Lighthouse, on a wide range of projects. From applied AI to optimization to big data platform engineering, your analytical and technical skills will drive real impact in the business world. At KPMG, our commitment to your career development helps to set us apart as an employer. We want to enhance your potential, both for yourself and as a contributor to our firm. That\'s why we provide every opportunity to expand your skills, knowledge and experiences through formal education and training programs, leadership development opportunities, and, as well as informal one-on-one coaching and mentoring from your KPMG colleagues.\n\nKPMG is currently seeking an Associate to join our KPMG Lighthouse - Center of Excellence for Advanced Analytics.\n\n\n\n\n\nKPMG LLP (the U.S. member firm of KPMG International) offers a comprehensive compensation and benefits package. KPMG is an affirmative action-equal opportunity employer. KPMG complies with all applicable federal, state and local laws regarding recruitment and hiring. All qualified applicants are considered for employment without regard to race, color, religion, age, sex, sexual orientation, gender identity, national origin, disability, protected veteran status, or any other category protected by applicable federal, state or local laws. The attached link contains further information regarding the firm\'s compliance with federal, state and local recruitment and hiring laws. No phone calls or agencies please.",[],[]\n"Systems Planning and Analysis, Inc.",Data Scientist - CWMD,"Reston, VA",,https://www.linkedin.com/jobs/view/2719087133/?eBP=CwEAAAF8A9ofOs3Q1pRDNomWkKq8WZKKrxzVFph6K2D4ymCmOH1h4zujhf7yBWfSjCtGRdbAe9Qx1ZFnDclUFpBrbo8MAanx6IoSd6oeFzDujMeur4dsRn-KObiuVvRuoE8jax4zNaj2cL0qgNswrocbKDKdYn82E7vixG1bp6oL35Xs1t4QTILoMHsFU_wTZqMgC7fCMPF3UzzYVoZ7UpLI2jutAFhJUtKKFD94vE5WkDbZOlxsnkXaN96-uctzECAJaz-JWJTbMRDHUek1yOdijC16J7HeR8V1Snd1B3f-lHcwkIyohdLJUUsi0dDpOWpoQNpv7XWOgAXT-NzCdHsRY99xfHcFFJK5r9UEJvFy__j3f60gUpWxie9aT8NO&recommendedFlavor=ACTIVELY_HIRING_COMPANY&refId=uAGrvRCfo9q5%2BNk5EGGm4Q%3D%3D&trackingId=sCAmjQEN8DY8a6u7bP7Yfg%3D%3D&trk=flagship3_search_srp_jobs,"About the job\nOverview\n\nSystems Planning and Analysis, Inc. (SPA) is a well-established and progressive defense contracting company in the DC Metro area. We are a professional services firm established in 1972 that has a long-standing reputation for unrivaled technical and analytical support to some of the top decision makers in the Federal Sector. We do state of the art work and have a cadre of outstanding professionals on our team.\n\nSPA assists the Defense Threat Reduction Agency (DTRA) in developing leading edge technologies to counter WMD in support of CCMDs and transitioning these technologies to services and SOCOM. SPA provides expertise across the full range of chemical, biological, radiological, nuclear and high-yield explosives (CBRNE) WMD, Counter Improvised Threat and Countering Threat Network technologies to support understanding, detection, identification, characterization, denial, control, disabling, defeating, disposing, safeguarding the force, managing consequences, and test and evaluation in support of military and civilian operations. #CJ #IN123\n\n\n\nProvides critical decision and analytic support to the Urgent Solutions Division in the Counter WMD Technologies Department of the Defense Threat Reduction Agency (DTRA). Conducts assessments, demonstrations, analysis, scientific codes, and other decision making in evaluating systems to counter WMD – biological and chemical threats, and counter threat networks. Develops knowledge regarding a stipulated issue through analysis of complex data sets, identifying actionable trends and problems. Uses appropriate methods to creatively explore, mine, analyze and manipulate data sets ranging in size from sparse to petabytes and type (e.g. small number of .pdf text reports, Excel spreadsheets and .csv files to repositories of image or audio data). Interprets results from multiple sources using a variety of techniques, ranging from simple data aggregation via statistical analysis to complex data mining, sensor analysis and learning techniques. Designs, develops, and implements technical solutions in support of concurrent analysis. Supports data models and defines the structure, attributes, and nomenclature of data elements. May evaluate new data sources for adherence to the organization\'s quality standards and ease of integration.",[],[]\nPerficient,Data Scientist,"St Louis, MO",,https://www.linkedin.com/jobs/view/2718055481/?eBP=CwEAAAF8A9ofOhOHpkH95U2fvN9F-goU76IrWGZ2_h1PEIqUbFxqxI6w3ypUfMSWfMRpTGEJDX9iicxg3Is1hE7MJg4ixQ2ZJfmdAFAR38WMuWQ9RdnHIEX4XrSbapYsM3nhi6Iyv6rH9MEC1PpEqmZkvr8JBlfU1asVfgP3pl3rW4IS6tIVJuzERferAoB3ycE-UB94AE92MTfUPPOUagL-zhuIsIcyQ6BMfE6eFGYpZpAHbvdti7-s852GjLAxYFovRGVyerfbSKSeZm6fVVXT2EaQfKYvMN5hBZBBVncwxNfzaaMBbKZ9moxmBg76BZ3UfB6YOntWLvvf06jI4VVqLMZ_BYq4iT8Jnp-YKt2dJxnECW-9zW66IbRoeRPT&recommendedFlavor=COMPANY_RECRUIT&refId=uAGrvRCfo9q5%2BNk5EGGm4Q%3D%3D&trackingId=UE7bblhxeqWJV52%2F9JWJew%3D%3D&trk=flagship3_search_srp_jobs,"About the job\nOverview\n\nAt Perficient you’ll deliver mission-critical technology and business solutions to Fortune 500 companies and some of the most recognized brands on the planet. And you’ll do it with cutting-edge technologies, thanks to our close partnerships with the world’s biggest vendors. Our network of offices across North America, as well as locations in India and China, will give you the opportunity to spread your wings, too.\n\nWe’re proud to be publicly recognized as a “Top Workplace” year after year. This is due, in no small part, to our entrepreneurial attitude and collaborative spirit that sets us apart and keeps our colleagues impassioned, driven, and fulfilled.\n\nPerficient currently has a career opportunity for a .\n\n\n\nThe role of the Data Scientist is for individuals passionate about identifying and delivering the right Business solution for each client using AI/ML. Our Data Scientists are keen to understand our customer needs, processes and pain points to determine the success factors and evaluation criteria that will needed to measure the effectiveness of an ML model.\n\nThe Data Scientist will be involved in the strategic planning of an engagement or helping the client make decisions about their future AI/ML roadmap and vision. Once the project as begun, the Data Scientist will be responsible for the execution of our established methodology, work with customer and/or the teams data engineer to identify data ingestion and transformation needs, exploration of the data and reporting findings, modeling and evaluation of training iterations. It is a key part of the role to be able to explain in non-technical terms the chosen modeling approach and findings from data exploration or training results.\n\nThe Data Scientist will work with Senior Project Managers to assist with daily operations exercising time management, communication and collaboration in a fast-paced environment to ensure the successful delivery of projects. The Data Scientist will interface with Perficient technical and business delivery personnel, as well as vendors and customers on a regular basis. May mentor junior data scientists.\n\n\n\n\n\n\n\nPerficient full-time employees receive complete and competitive benefits. We offer a collaborative work environment, competitive compensation, generous work/life opportunities and an outstanding benefits package that includes paid time off plus holidays. In addition, all colleagues are eligible for a number of rewards and recognition programs including billable bonus opportunities. Encouraging a healthy work/life balance and providing our colleagues great benefits are just part of what makes Perficient a great place to work.\n\n\n\nPerficient is the leading digital transformation consulting firm serving Global 2000 and enterprise customers throughout North America. With unparalleled information technology, management consulting and creative capabilities, Perficient and its Perficient Digital agency deliver vision, execution and value with outstanding digital experience, business optimization and industry solutions.\n\nOur work enables clients to improve productivity and competitiveness; grow and strengthen relationships with customers, suppliers and partners; and reduce costs. Perficient\'s professionals serve clients from a network of offices across North America and offshore locations in India and China. Traded on the Nasdaq Global Select Market, Perficient is a member of the Russell 2000 index and the S&P SmallCap 600 index.\n\nPerficient is an equal opportunity employer and all qualified applicants will receive consideration for employment without regard to race, color, religion, sex, national, origin, disability status, protected veteran status, or any other characteristic protected by law.\n\nThe above statements are not intended to be a complete statement of job content, rather to act as a guide to the essential functions performed by the employee assigned to this classification. Management retains the discretion to add or change the duties of the position at any time.\n\nSelect work authorization questions to ask when applicants apply",[],[]\nSavage X Fenty: Lingerie by Rihanna,Data Scientist,"El Segundo, CA",,https://www.linkedin.com/jobs/view/2721710042/?eBP=CwEAAAF8A9ofOhPzbWsStxaNEgpMLIbvO6Vvpf-kp8RGwvYOJKGphyyakdc_4SGsjm2VeRAGjmk-vJ6l9A5H_dap2I3Kpoi5h6gKOdZGPr43fehHk5BqkiDkbvKki_to05FvWLinOBzurpjsMFG3JoeqUJ8xRReTFcidZnHYUQE6jUxh0nf-LNmAPuQp7YZEmPEps45wTFpgh1xQa_nwnLky1x-nzte_8YwEIsmHKQ5z2VTOvDevWj_NNLxyfvp4hDKsNbBNyQC_28gSNPkqkg6iN2yFOum-URpP05X-BwoG-gN9HPsuQJs-bhqDslt8i6wwag517FTdUMMYWqa29zUtuHYFUf1ei5iEh0ffOBNdGGDafvdOB4z8Oqp3hxLnHhY&recommendedFlavor=ACTIVELY_HIRING_COMPANY&refId=uAGrvRCfo9q5%2BNk5EGGm4Q%3D%3D&trackingId=WJuu5WmPKTuvZRyUdmNdtA%3D%3D&trk=flagship3_search_srp_jobs,"About the job\nJob DescriptionSavage X Fenty is looking for a Data Scientist. Co-founded by music and fashion icon Rihanna, Savage X Fenty is the first line of lingerie that celebrates and speaks to all shades and shapes of people, and celebrates fearlessness, confidence and inclusivity.\n\nHOW DO YOU FIT IN?\n\nAs the Data Scientist, you will drive innovation in our customer shopping experience by providing the algorithms that power recommendation and personalization features across our ecommerce website. You will collaborate closely with the Data Analytics organization, the Global Technology organization, and the Savage X business to develop high-impact solutions to key optimization opportunities such as ecommerce conversion & product discovery. You will watch your work come to life by partnering with dedicated product & software engineering teams to deploy your algorithms into production.\n\nProjects you are likely to own in this role include:\n\nProduct Recommendation Algorithms (e.g., product discovery & upsell algorithms)\n\nFull Funnel Customer Segmentation (e.g., algorithmically define customer segments and stream segments to other tools such as our CRM or ad networks)\n\nInternal Optimization Algorithms (e.g., attribution models, sales propensity algorithms)\n\nAt Savage X Fenty you can expect to use Python and SQL every day. For larger projects requiring scale or automation you’ll likely be working with DataBricks and Airflow. While these are our defaults, you will have the flexibility to use tools that allow you to best fulfill your role. Additionally, we strongly believe in the need for ongoing education and so will encourage you to explore new technologies and modeling methods on a regular basis.\n\n\n\nYou’re the ideal candidate if you’re incredibly curious & see opportunities for data science applications in everything you do. Working smarter, not harder, is core to your DNA. You’re invigorated by the opportunity to learn that next tool or skill, and you come up with clever solutions to difficult problems. As much as you learned in school or at work, you’ve probably learned even more during your late-night hacking sessions. You take initiative, can work without supervision, begin projects independently, and are technically capable with a deep desire to become an expert in data science applications for ecommerce. You’re seeking a collaborative environment in which you can work alongside other technology experts to find the best answer and win as a team.\n\nThis position will report to the Director of Data Analytics on the Savage X Fenty Analytics Team. The position will also have an informal reporting line to the Sr. Director of Data Science on the TechStyleOS Architecture & Sciences team. We are a creative, ambitious, & fun-loving team who believes data products should be collaboratively designed, impactful to the business, and customized for the end user. Our analytics team acts as strategic partners to the business, making an impact by merging data with a deep understanding of the Savage customer experience.\n\nThis position will be based in El Segundo, California. For the right candidate, we will consider full-time remote work.\n\nWHY WORK IN DATA SCIENCE AT SAVAGE X?\n\nWork within a community of data scientists through our parent company TechStyle Fashion Group & our sister brand Fabletics, but be the first Data Scientist dedicated to the Savage X brand. This role will design the foundation for Savage’s future data science initiatives & experience fast paced growth\n\nDedicated resources to support you – Savage X is investing heavily in data science and has staffed dedicated engineering & product management to support your initiatives\n\nIndustry leading data technology stack – Snowflake, DataBricks, Segment Customer Data Platform, Apache Airflow, modeled reporting data warehouse, & more\n\nData-driven mindset is deeply foundational to the culture at Savage X; information flows freely throughout our organization and every key decision we make is backed by analysis\n\nBe a part of the larger Data Analytics organization at TechStyle Fashion Group (60+ team members); mentor & be mentored by our architects, scientists, analysts, & engineers\n\n\n\nLeverage our advanced tech stack, your knowledge of data science methods & models, and your partnerships with our senior engineers, scientists, and architects to determine the best approaches for algorithm development and implementation\n\nOwn algorithm development projects from start-to-end: design, develop, QA, deploy, experiment, and analyze\n\nPartner with dedicated product management & software engineering teams to implement data science algorithms onto our consumer-facing ecommerce website\n\nPartner with dedicated analysts to produce data visualizations, advanced reports, measurement and statistical models that explain and track algorithm performance against business KPIs\n\nPartner with the business to identify & understand opportunities for data science applications\n\nProvide thought leadership and data support to the business & other analytics team members around design, execution, and measurement of business KPIs\n\nCollaborate with other data scientists across our organization to share best practices, learn new techniques, and foster our organizational culture where data is central to decision making\n\n\n\nHigh degree of personal integrity, strong work ethic, & a desire to learn and grow in this role\n\n2+ years of work experience as a Data Scientist or Machine Learning Engineer\n\nFluent in R or Python (Python preferred) & SQL\n\nFamiliarity with Machine Learning techniques (e.g. classification, clustering, regularization, optimization, dimension reduction, feature engineering)\n\nStrong understanding of CS fundamentals (e.g. algorithms and data structures)\n\nExperience with attribution, causal inference, experimental design, and AB testing methods\n\nGood communication skills and ability to explain complex topics to a non-technical audience\n\n\n\nExperience partnering with product management & software engineering teams to implement algorithms into a production environment\n\nDegree or Advanced Degree in Statistics, Computer Science, or related fields\n\nExperience with Git and/or Airflow\n\nExperience with data visualization tools such as Tableau\n\nExperience in e-commerce, subscription models, and/or direct-to-consumer brands\n\nFamiliarity with web analytics tools & concepts (Google Analytics, pixel tracking, Segment Customer Data Platform or comparable tools)\n\n\n\nTechStyleOS is the globally integrated Operations and Services provider behind some of the fastest growing online fashion brands in history, including Fabletics, Savage X Fenty, JustFab, ShoeDazzle, and FabKids. With capabilities spanning technology, data science, supply chain management, fulfillment, customer service, and more, we help brands launch, scale and grow—across product categories and geographically. From predictive analytics to data-driven marketing and attribution, our unique approach is powered by our proprietary, end-to-end tech platform that enables the brands we serve to deliver a level of personalization, value, and satisfaction that are unrivaled in the fashion industry.\n\nSavage X Inc.is an equal opportunity employer. We recruit, employ, compensate, develop, and promote regardless of race, national origin, religion, sex, sexual orientation, gender identity, age, disability, genetic information, veteran status, and other protected status as required by applicable. At Savage X Inc. , we champion a vibrant workplace culture that thrives on diversity law and do not tolerate discrimination or harassment. We are one team from many backgrounds, innovating through diversity of individuals, who are driven by passion for creating an inclusive space for all. Savage X Inc. will continue to champion a workplace culture that prizes diversity and inclusivity.\n\nWe encourage you to apply regardless of meeting all qualifications and/or requirements.",[],[]\nWestern Governors University,Data Scientist-2,"St Louis, MO",,https://www.linkedin.com/jobs/view/2718750842/?eBP=CwEAAAF8A9ofOjpba68ujoLXQAaOCBXYiS4C1yUTdLuyzCZe9eu8Ol6E5B1OavyEuBokToqXvI8orCg9mTa7e7zpzyV9cy10rVkKoDvZEPBDm1du-SyxnPgFICjxXnkLuO4a476oKPYJHgNsT_wxWcVM7UPEe_A4rGFK3u5Nxocz6TO1M6QF-5VfM-4C6pvZ-cryEakyxdZm6GaHw7p9zbMvWyaV6i1CvmDXy27crdTMH0Tc23b0hvt7S-fanNHX4dGjk06Is5AS7iuF-deOP1A46W0iSZPaIhLkVkBxOTTw8Wp12qn_2fxTdloxilj5f3cSIkJJSt5CyCNX3COteQXhYjO8geRyhwPGFGyDICcz7CEBCngNc2CFZt-0BfY9piw&recommendedFlavor=COMPANY_RECRUIT&refId=uAGrvRCfo9q5%2BNk5EGGm4Q%3D%3D&trackingId=nI03Xvg4nBirIwj8TRNSAQ%3D%3D&trk=flagship3_search_srp_jobs,"About the job\nIf you’re passionate about building a better future for individuals, communities, and our country—and you’re committed to working hard to play your part in building that future—consider WGU as the next step in your career.\n\nDriven by a mission to expand access to higher education through online, competency-based degree programs, WGU is also committed to being a great place to work for a diverse workforce of student-focused professionals. The university has pioneered a new way to learn in the 21st century, one that has received praise from academic, industry, government, and media leaders. Whatever your role, working for WGU gives you a part to play in helping students graduate, creating a better tomorrow for themselves and their families.\n\n\n\n\n\n:\n\n\n\n\n\nAs an equal opportunity employer, WGU recognizes that our strength lies in our people. We are committed to diversity.",[],[]\nCarShield,Data Scientist,"St Louis, MO","50 minutes ago\nWithin the past 24 hours",https://www.linkedin.com/jobs/view/2723209281/?eBP=JOB_SEARCH_ORGANIC&recommendedFlavor=COMPANY_RECRUIT&refId=uAGrvRCfo9q5%2BNk5EGGm4Q%3D%3D&trackingId=KgTMJ%2FOU15u5GSRxFma6BA%3D%3D&trk=flagship3_search_srp_jobs,"About the job\nJob Description\nResponsible for overseeing the collection, storage and interpretation of data for businesses. Their duties include sifting through data points to create organized categories, comparing data points to current company processes and writing reports outlining business predictions or proposals.",[],[]\nAmerican Express Global Business Travel,Data Scientist,"Evansville, IN",6 days ago,https://www.linkedin.com/jobs/view/2716701280/?eBP=JOB_SEARCH_ORGANIC&recommendedFlavor=ACTIVELY_HIRING_COMPANY&refId=uAGrvRCfo9q5%2BNk5EGGm4Q%3D%3D&trackingId=%2FNnG2%2FT8eaQ5Auu0r1LwgQ%3D%3D&trk=flagship3_search_srp_jobs,"About the job\nThe Candidate Is Expected To Possess These Key Skills/technologies\n\nThe data science solutions engineer will be a member of the data analytics team and will lead efforts around building big data, data science, data quality, and BI/MI/AI solutions. An ideal candidate will be a The data science associate will have a growth-oriented, lean-startup mindset for building hands-on data science solutions. The ideal candidate will propose, experiment, execute, and operationalize advanced predictive, preemptive data solutions designed to help traveler, travel-manager, supplier, and client outcomes. The role will span full-scale product, enterprise, and operational data science. The candidate will focus and thrive in a hands-on applied role; he/she will demonstrate a strong penchant for quantitative, collaborative, outcome-oriented solutions-engineering.\n\n\n\n\n\n\n\nIndia>Virtual Location\n\nIt is our policy to provide equal employment opportunities to all individuals based on job-related qualifications and ability to perform a job, without regard to age, gender, gender identity, sexual orientation, race, color, religion, creed, national origin, disability, genetic information, veteran status, citizenship or marital status, and to maintain a non-discriminatory environment free from intimidation, harassment or bias based upon these grounds.\n\nPosted 6 Days Ago Full time J-46605\n\nAmerican Express Global Business Travel (GBT) is the world’s leading business partner for managed travel. We help companies and employees prosper by making sure travelers are present where and when it matters. We keep global business moving with the powerful backing of 16,000 travel professionals in more than 140 countries. Companies of all sizes, and in all places, rely on GBT to provide travel management services, organize meetings and events, and deliver business travel consulting.",[],[]\nKPMG US,"Associate, Data Scientist","Chicago, IL",,https://www.linkedin.com/jobs/view/2715182807/?eBP=CwEAAAF8A9ofOnXwJUuycM2gGRL1mcgrhKEvGOAPq7WvcuqVfhF3v31fFIUXMUZTB2_KdQBZae-zIVr4TaQH32qoMce5QiuRkyz35Qe4NunBDe1tO5oIPM_jRd0DRVV1Q2RE2NsRab1c65uetiOURFT5UacwF26coAIsRg_OLs_YoY_77ZEEy1w6kTyWThm4DdS0MF9eZsoLFRxcEZjVZPeHkjucUMmMlgDkGFolStofkAtovBw2_NeONzmFwJOWVe1GKQ1XqLioi_MqRW4kb3iJnvdR5E8PAb5PCjiNjJEfuIXO63QpyODR7y7X0dEhMCCkj_x1tLu5T0PQeNlCeZkpp7nWdyWZQtRzOXNNpH9yPYBeaNL_b3b8W8FSewL2XfI&recommendedFlavor=COMPANY_RECRUIT&refId=uAGrvRCfo9q5%2BNk5EGGm4Q%3D%3D&trackingId=tWMAG1KeTQs1iil6CAtrmQ%3D%3D&trk=flagship3_search_srp_jobs,"About the job\nRequisition Number: 70881 - 31\n\nDescription\n\nInnovate. Collaborate. Build. Create. Solve. The KPMG Digital Lighthouse is KPMG\'s award-winning Analytics & AI Center of Excellence recognized by clients and leading analyst firms in the US and globally. The KPMG Lighthouse is a curation of specialized technical capabilities and domain experts working across the digital landscape: applied data science, AI, data engineering and insights, software engineering, automation, and big data. Here, you\'ll work with a diverse team of professionals to explore and build solutions for clients in a multiplatform environment.\n\nYou\'ll be an important part of our high-energy, unique, fast-paced, and innovative culture that delivers with the agility of a tech startup and the backing of a leading global consulting firm. In this particular role, you\'ll work specifically in the AI Analytics & Engineering Community within the Digital Lighthouse, on a wide range of projects. From applied AI to optimization to big data platform engineering, your analytical and technical skills will drive real impact in the business world. At KPMG, our commitment to your career development helps to set us apart as an employer. We want to enhance your potential, both for yourself and as a contributor to our firm. That\'s why we provide every opportunity to expand your skills, knowledge and experiences through formal education and training programs, leadership development opportunities, and, as well as informal one-on-one coaching and mentoring from your KPMG colleagues.\n\nKPMG is currently seeking an Associate to join our KPMG Lighthouse - Center of Excellence for Advanced Analytics.\n\n\n\n\n\nKPMG LLP (the U.S. member firm of KPMG International) offers a comprehensive compensation and benefits package. KPMG is an affirmative action-equal opportunity employer. KPMG complies with all applicable federal, state and local laws regarding recruitment and hiring. All qualified applicants are considered for employment without regard to race, color, religion, age, sex, sexual orientation, gender identity, national origin, disability, protected veteran status, or any other category protected by applicable federal, state or local laws. The attached link contains further information regarding the firm\'s compliance with federal, state and local recruitment and hiring laws. No phone calls or agencies please.",[],[]\n"Systems Planning and Analysis, Inc.",Data Scientist - CWMD,"Reston, VA",,https://www.linkedin.com/jobs/view/2719087133/?eBP=CwEAAAF8A9ofOs3Q1pRDNomWkKq8WZKKrxzVFph6K2D4ymCmOH1h4zujhf7yBWfSjCtGRdbAe9Qx1ZFnDclUFpBrbo8MAanx6IoSd6oeFzDujMeur4dsRn-KObiuVvRuoE8jax4zNaj2cL0qgNswrocbKDKdYn82E7vixG1bp6oL35Xs1t4QTILoMHsFU_wTZqMgC7fCMPF3UzzYVoZ7UpLI2jutAFhJUtKKFD94vE5WkDbZOlxsnkXaN96-uctzECAJaz-JWJTbMRDHUek1yOdijC16J7HeR8V1Snd1B3f-lHcwkIyohdLJUUsi0dDpOWpoQNpv7XWOgAXT-NzCdHsRY99xfHcFFJK5r9UEJvFy__j3f60gUpWxie9aT8NO&recommendedFlavor=ACTIVELY_HIRING_COMPANY&refId=uAGrvRCfo9q5%2BNk5EGGm4Q%3D%3D&trackingId=sCAmjQEN8DY8a6u7bP7Yfg%3D%3D&trk=flagship3_search_srp_jobs,"About the job\nOverview\n\nSystems Planning and Analysis, Inc. (SPA) is a well-established and progressive defense contracting company in the DC Metro area. We are a professional services firm established in 1972 that has a long-standing reputation for unrivaled technical and analytical support to some of the top decision makers in the Federal Sector. We do state of the art work and have a cadre of outstanding professionals on our team.\n\nSPA assists the Defense Threat Reduction Agency (DTRA) in developing leading edge technologies to counter WMD in support of CCMDs and transitioning these technologies to services and SOCOM. SPA provides expertise across the full range of chemical, biological, radiological, nuclear and high-yield explosives (CBRNE) WMD, Counter Improvised Threat and Countering Threat Network technologies to support understanding, detection, identification, characterization, denial, control, disabling, defeating, disposing, safeguarding the force, managing consequences, and test and evaluation in support of military and civilian operations. #CJ #IN123\n\n\n\nProvides critical decision and analytic support to the Urgent Solutions Division in the Counter WMD Technologies Department of the Defense Threat Reduction Agency (DTRA). Conducts assessments, demonstrations, analysis, scientific codes, and other decision making in evaluating systems to counter WMD – biological and chemical threats, and counter threat networks. Develops knowledge regarding a stipulated issue through analysis of complex data sets, identifying actionable trends and problems. Uses appropriate methods to creatively explore, mine, analyze and manipulate data sets ranging in size from sparse to petabytes and type (e.g. small number of .pdf text reports, Excel spreadsheets and .csv files to repositories of image or audio data). Interprets results from multiple sources using a variety of techniques, ranging from simple data aggregation via statistical analysis to complex data mining, sensor analysis and learning techniques. Designs, develops, and implements technical solutions in support of concurrent analysis. Supports data models and defines the structure, attributes, and nomenclature of data elements. May evaluate new data sources for adherence to the organization\'s quality standards and ease of integration.",[],[]\nPerficient,Data Scientist,"St Louis, MO",,https://www.linkedin.com/jobs/view/2718055481/?eBP=CwEAAAF8A9ofOhOHpkH95U2fvN9F-goU76IrWGZ2_h1PEIqUbFxqxI6w3ypUfMSWfMRpTGEJDX9iicxg3Is1hE7MJg4ixQ2ZJfmdAFAR38WMuWQ9RdnHIEX4XrSbapYsM3nhi6Iyv6rH9MEC1PpEqmZkvr8JBlfU1asVfgP3pl3rW4IS6tIVJuzERferAoB3ycE-UB94AE92MTfUPPOUagL-zhuIsIcyQ6BMfE6eFGYpZpAHbvdti7-s852GjLAxYFovRGVyerfbSKSeZm6fVVXT2EaQfKYvMN5hBZBBVncwxNfzaaMBbKZ9moxmBg76BZ3UfB6YOntWLvvf06jI4VVqLMZ_BYq4iT8Jnp-YKt2dJxnECW-9zW66IbRoeRPT&recommendedFlavor=COMPANY_RECRUIT&refId=uAGrvRCfo9q5%2BNk5EGGm4Q%3D%3D&trackingId=UE7bblhxeqWJV52%2F9JWJew%3D%3D&trk=flagship3_search_srp_jobs,"About the job\nOverview\n\nAt Perficient you’ll deliver mission-critical technology and business solutions to Fortune 500 companies and some of the most recognized brands on the planet. And you’ll do it with cutting-edge technologies, thanks to our close partnerships with the world’s biggest vendors. Our network of offices across North America, as well as locations in India and China, will give you the opportunity to spread your wings, too.\n\nWe’re proud to be publicly recognized as a “Top Workplace” year after year. This is due, in no small part, to our entrepreneurial attitude and collaborative spirit that sets us apart and keeps our colleagues impassioned, driven, and fulfilled.\n\nPerficient currently has a career opportunity for a .\n\n\n\nThe role of the Data Scientist is for individuals passionate about identifying and delivering the right Business solution for each client using AI/ML. Our Data Scientists are keen to understand our customer needs, processes and pain points to determine the success factors and evaluation criteria that will needed to measure the effectiveness of an ML model.\n\nThe Data Scientist will be involved in the strategic planning of an engagement or helping the client make decisions about their future AI/ML roadmap and vision. Once the project as begun, the Data Scientist will be responsible for the execution of our established methodology, work with customer and/or the teams data engineer to identify data ingestion and transformation needs, exploration of the data and reporting findings, modeling and evaluation of training iterations. It is a key part of the role to be able to explain in non-technical terms the chosen modeling approach and findings from data exploration or training results.\n\nThe Data Scientist will work with Senior Project Managers to assist with daily operations exercising time management, communication and collaboration in a fast-paced environment to ensure the successful delivery of projects. The Data Scientist will interface with Perficient technical and business delivery personnel, as well as vendors and customers on a regular basis. May mentor junior data scientists.\n\n\n\n\n\n\n\nPerficient full-time employees receive complete and competitive benefits. We offer a collaborative work environment, competitive compensation, generous work/life opportunities and an outstanding benefits package that includes paid time off plus holidays. In addition, all colleagues are eligible for a number of rewards and recognition programs including billable bonus opportunities. Encouraging a healthy work/life balance and providing our colleagues great benefits are just part of what makes Perficient a great place to work.\n\n\n\nPerficient is the leading digital transformation consulting firm serving Global 2000 and enterprise customers throughout North America. With unparalleled information technology, management consulting and creative capabilities, Perficient and its Perficient Digital agency deliver vision, execution and value with outstanding digital experience, business optimization and industry solutions.\n\nOur work enables clients to improve productivity and competitiveness; grow and strengthen relationships with customers, suppliers and partners; and reduce costs. Perficient\'s professionals serve clients from a network of offices across North America and offshore locations in India and China. Traded on the Nasdaq Global Select Market, Perficient is a member of the Russell 2000 index and the S&P SmallCap 600 index.\n\nPerficient is an equal opportunity employer and all qualified applicants will receive consideration for employment without regard to race, color, religion, sex, national, origin, disability status, protected veteran status, or any other characteristic protected by law.\n\nThe above statements are not intended to be a complete statement of job content, rather to act as a guide to the essential functions performed by the employee assigned to this classification. Management retains the discretion to add or change the duties of the position at any time.\n\nSelect work authorization questions to ask when applicants apply",[],[]\nSavage X Fenty: Lingerie by Rihanna,Data Scientist,"El Segundo, CA",,https://www.linkedin.com/jobs/view/2721710042/?eBP=CwEAAAF8A9ofOhPzbWsStxaNEgpMLIbvO6Vvpf-kp8RGwvYOJKGphyyakdc_4SGsjm2VeRAGjmk-vJ6l9A5H_dap2I3Kpoi5h6gKOdZGPr43fehHk5BqkiDkbvKki_to05FvWLinOBzurpjsMFG3JoeqUJ8xRReTFcidZnHYUQE6jUxh0nf-LNmAPuQp7YZEmPEps45wTFpgh1xQa_nwnLky1x-nzte_8YwEIsmHKQ5z2VTOvDevWj_NNLxyfvp4hDKsNbBNyQC_28gSNPkqkg6iN2yFOum-URpP05X-BwoG-gN9HPsuQJs-bhqDslt8i6wwag517FTdUMMYWqa29zUtuHYFUf1ei5iEh0ffOBNdGGDafvdOB4z8Oqp3hxLnHhY&recommendedFlavor=ACTIVELY_HIRING_COMPANY&refId=uAGrvRCfo9q5%2BNk5EGGm4Q%3D%3D&trackingId=WJuu5WmPKTuvZRyUdmNdtA%3D%3D&trk=flagship3_search_srp_jobs,"About the job\nJob DescriptionSavage X Fenty is looking for a Data Scientist. Co-founded by music and fashion icon Rihanna, Savage X Fenty is the first line of lingerie that celebrates and speaks to all shades and shapes of people, and celebrates fearlessness, confidence and inclusivity.\n\nHOW DO YOU FIT IN?\n\nAs the Data Scientist, you will drive innovation in our customer shopping experience by providing the algorithms that power recommendation and personalization features across our ecommerce website. You will collaborate closely with the Data Analytics organization, the Global Technology organization, and the Savage X business to develop high-impact solutions to key optimization opportunities such as ecommerce conversion & product discovery. You will watch your work come to life by partnering with dedicated product & software engineering teams to deploy your algorithms into production.\n\nProjects you are likely to own in this role include:\n\nProduct Recommendation Algorithms (e.g., product discovery & upsell algorithms)\n\nFull Funnel Customer Segmentation (e.g., algorithmically define customer segments and stream segments to other tools such as our CRM or ad networks)\n\nInternal Optimization Algorithms (e.g., attribution models, sales propensity algorithms)\n\nAt Savage X Fenty you can expect to use Python and SQL every day. For larger projects requiring scale or automation you’ll likely be working with DataBricks and Airflow. While these are our defaults, you will have the flexibility to use tools that allow you to best fulfill your role. Additionally, we strongly believe in the need for ongoing education and so will encourage you to explore new technologies and modeling methods on a regular basis.\n\n\n\nYou’re the ideal candidate if you’re incredibly curious & see opportunities for data science applications in everything you do. Working smarter, not harder, is core to your DNA. You’re invigorated by the opportunity to learn that next tool or skill, and you come up with clever solutions to difficult problems. As much as you learned in school or at work, you’ve probably learned even more during your late-night hacking sessions. You take initiative, can work without supervision, begin projects independently, and are technically capable with a deep desire to become an expert in data science applications for ecommerce. You’re seeking a collaborative environment in which you can work alongside other technology experts to find the best answer and win as a team.\n\nThis position will report to the Director of Data Analytics on the Savage X Fenty Analytics Team. The position will also have an informal reporting line to the Sr. Director of Data Science on the TechStyleOS Architecture & Sciences team. We are a creative, ambitious, & fun-loving team who believes data products should be collaboratively designed, impactful to the business, and customized for the end user. Our analytics team acts as strategic partners to the business, making an impact by merging data with a deep understanding of the Savage customer experience.\n\nThis position will be based in El Segundo, California. For the right candidate, we will consider full-time remote work.\n\nWHY WORK IN DATA SCIENCE AT SAVAGE X?\n\nWork within a community of data scientists through our parent company TechStyle Fashion Group & our sister brand Fabletics, but be the first Data Scientist dedicated to the Savage X brand. This role will design the foundation for Savage’s future data science initiatives & experience fast paced growth\n\nDedicated resources to support you – Savage X is investing heavily in data science and has staffed dedicated engineering & product management to support your initiatives\n\nIndustry leading data technology stack – Snowflake, DataBricks, Segment Customer Data Platform, Apache Airflow, modeled reporting data warehouse, & more\n\nData-driven mindset is deeply foundational to the culture at Savage X; information flows freely throughout our organization and every key decision we make is backed by analysis\n\nBe a part of the larger Data Analytics organization at TechStyle Fashion Group (60+ team members); mentor & be mentored by our architects, scientists, analysts, & engineers\n\n\n\nLeverage our advanced tech stack, your knowledge of data science methods & models, and your partnerships with our senior engineers, scientists, and architects to determine the best approaches for algorithm development and implementation\n\nOwn algorithm development projects from start-to-end: design, develop, QA, deploy, experiment, and analyze\n\nPartner with dedicated product management & software engineering teams to implement data science algorithms onto our consumer-facing ecommerce website\n\nPartner with dedicated analysts to produce data visualizations, advanced reports, measurement and statistical models that explain and track algorithm performance against business KPIs\n\nPartner with the business to identify & understand opportunities for data science applications\n\nProvide thought leadership and data support to the business & other analytics team members around design, execution, and measurement of business KPIs\n\nCollaborate with other data scientists across our organization to share best practices, learn new techniques, and foster our organizational culture where data is central to decision making\n\n\n\nHigh degree of personal integrity, strong work ethic, & a desire to learn and grow in this role\n\n2+ years of work experience as a Data Scientist or Machine Learning Engineer\n\nFluent in R or Python (Python preferred) & SQL\n\nFamiliarity with Machine Learning techniques (e.g. classification, clustering, regularization, optimization, dimension reduction, feature engineering)\n\nStrong understanding of CS fundamentals (e.g. algorithms and data structures)\n\nExperience with attribution, causal inference, experimental design, and AB testing methods\n\nGood communication skills and ability to explain complex topics to a non-technical audience\n\n\n\nExperience partnering with product management & software engineering teams to implement algorithms into a production environment\n\nDegree or Advanced Degree in Statistics, Computer Science, or related fields\n\nExperience with Git and/or Airflow\n\nExperience with data visualization tools such as Tableau\n\nExperience in e-commerce, subscription models, and/or direct-to-consumer brands\n\nFamiliarity with web analytics tools & concepts (Google Analytics, pixel tracking, Segment Customer Data Platform or comparable tools)\n\n\n\nTechStyleOS is the globally integrated Operations and Services provider behind some of the fastest growing online fashion brands in history, including Fabletics, Savage X Fenty, JustFab, ShoeDazzle, and FabKids. With capabilities spanning technology, data science, supply chain management, fulfillment, customer service, and more, we help brands launch, scale and grow—across product categories and geographically. From predictive analytics to data-driven marketing and attribution, our unique approach is powered by our proprietary, end-to-end tech platform that enables the brands we serve to deliver a level of personalization, value, and satisfaction that are unrivaled in the fashion industry.\n\nSavage X Inc.is an equal opportunity employer. We recruit, employ, compensate, develop, and promote regardless of race, national origin, religion, sex, sexual orientation, gender identity, age, disability, genetic information, veteran status, and other protected status as required by applicable. At Savage X Inc. , we champion a vibrant workplace culture that thrives on diversity law and do not tolerate discrimination or harassment. We are one team from many backgrounds, innovating through diversity of individuals, who are driven by passion for creating an inclusive space for all. Savage X Inc. will continue to champion a workplace culture that prizes diversity and inclusivity.\n\nWe encourage you to apply regardless of meeting all qualifications and/or requirements.",[],[]\nWestern Governors University,Data Scientist-2,"St Louis, MO",,https://www.linkedin.com/jobs/view/2718750842/?eBP=CwEAAAF8A9ofOjpba68ujoLXQAaOCBXYiS4C1yUTdLuyzCZe9eu8Ol6E5B1OavyEuBokToqXvI8orCg9mTa7e7zpzyV9cy10rVkKoDvZEPBDm1du-SyxnPgFICjxXnkLuO4a476oKPYJHgNsT_wxWcVM7UPEe_A4rGFK3u5Nxocz6TO1M6QF-5VfM-4C6pvZ-cryEakyxdZm6GaHw7p9zbMvWyaV6i1CvmDXy27crdTMH0Tc23b0hvt7S-fanNHX4dGjk06Is5AS7iuF-deOP1A46W0iSZPaIhLkVkBxOTTw8Wp12qn_2fxTdloxilj5f3cSIkJJSt5CyCNX3COteQXhYjO8geRyhwPGFGyDICcz7CEBCngNc2CFZt-0BfY9piw&recommendedFlavor=COMPANY_RECRUIT&refId=uAGrvRCfo9q5%2BNk5EGGm4Q%3D%3D&trackingId=nI03Xvg4nBirIwj8TRNSAQ%3D%3D&trk=flagship3_search_srp_jobs,"About the job\nIf you’re passionate about building a better future for individuals, communities, and our country—and you’re committed to working hard to play your part in building that future—consider WGU as the next step in your career.\n\nDriven by a mission to expand access to higher education through online, competency-based degree programs, WGU is also committed to being a great place to work for a diverse workforce of student-focused professionals. The university has pioneered a new way to learn in the 21st century, one that has received praise from academic, industry, government, and media leaders. Whatever your role, working for WGU gives you a part to play in helping students graduate, creating a better tomorrow for themselves and their families.\n\n\n\n\n\n:\n\n\n\n\n\nAs an equal opportunity employer, WGU recognizes that our strength lies in our people. We are committed to diversity.",[],[]\nCarShield,Data Scientist,"St Louis, MO","50 minutes ago\nWithin the past 24 hours",https://www.linkedin.com/jobs/view/2723209281/?eBP=JOB_SEARCH_ORGANIC&recommendedFlavor=COMPANY_RECRUIT&refId=uAGrvRCfo9q5%2BNk5EGGm4Q%3D%3D&trackingId=KgTMJ%2FOU15u5GSRxFma6BA%3D%3D&trk=flagship3_search_srp_jobs,"About the job\nJob Description\nResponsible for overseeing the collection, storage and interpretation of data for businesses. Their duties include sifting through data points to create organized categories, comparing data points to current company processes and writing reports outlining business predictions or proposals.",[],[]\nAmerican Express Global Business Travel,Data Scientist,"Evansville, IN",6 days ago,https://www.linkedin.com/jobs/view/2716701280/?eBP=JOB_SEARCH_ORGANIC&recommendedFlavor=ACTIVELY_HIRING_COMPANY&refId=uAGrvRCfo9q5%2BNk5EGGm4Q%3D%3D&trackingId=%2FNnG2%2FT8eaQ5Auu0r1LwgQ%3D%3D&trk=flagship3_search_srp_jobs,"About the job\nThe Candidate Is Expected To Possess These Key Skills/technologies\n\nThe data science solutions engineer will be a member of the data analytics team and will lead efforts around building big data, data science, data quality, and BI/MI/AI solutions. An ideal candidate will be a The data science associate will have a growth-oriented, lean-startup mindset for building hands-on data science solutions. The ideal candidate will propose, experiment, execute, and operationalize advanced predictive, preemptive data solutions designed to help traveler, travel-manager, supplier, and client outcomes. The role will span full-scale product, enterprise, and operational data science. The candidate will focus and thrive in a hands-on applied role; he/she will demonstrate a strong penchant for quantitative, collaborative, outcome-oriented solutions-engineering.\n\n\n\n\n\n\n\nIndia>Virtual Location\n\nIt is our policy to provide equal employment opportunities to all individuals based on job-related qualifications and ability to perform a job, without regard to age, gender, gender identity, sexual orientation, race, color, religion, creed, national origin, disability, genetic information, veteran status, citizenship or marital status, and to maintain a non-discriminatory environment free from intimidation, harassment or bias based upon these grounds.\n\nPosted 6 Days Ago Full time J-46605\n\nAmerican Express Global Business Travel (GBT) is the world’s leading business partner for managed travel. We help companies and employees prosper by making sure travelers are present where and when it matters. We keep global business moving with the powerful backing of 16,000 travel professionals in more than 140 countries. Companies of all sizes, and in all places, rely on GBT to provide travel management services, organize meetings and events, and deliver business travel consulting.",[],[]\nKPMG US,"Associate, Data Scientist","Chicago, IL",,https://www.linkedin.com/jobs/view/2715182807/?eBP=CwEAAAF8A9ofOnXwJUuycM2gGRL1mcgrhKEvGOAPq7WvcuqVfhF3v31fFIUXMUZTB2_KdQBZae-zIVr4TaQH32qoMce5QiuRkyz35Qe4NunBDe1tO5oIPM_jRd0DRVV1Q2RE2NsRab1c65uetiOURFT5UacwF26coAIsRg_OLs_YoY_77ZEEy1w6kTyWThm4DdS0MF9eZsoLFRxcEZjVZPeHkjucUMmMlgDkGFolStofkAtovBw2_NeONzmFwJOWVe1GKQ1XqLioi_MqRW4kb3iJnvdR5E8PAb5PCjiNjJEfuIXO63QpyODR7y7X0dEhMCCkj_x1tLu5T0PQeNlCeZkpp7nWdyWZQtRzOXNNpH9yPYBeaNL_b3b8W8FSewL2XfI&recommendedFlavor=COMPANY_RECRUIT&refId=uAGrvRCfo9q5%2BNk5EGGm4Q%3D%3D&trackingId=tWMAG1KeTQs1iil6CAtrmQ%3D%3D&trk=flagship3_search_srp_jobs,"About the job\nRequisition Number: 70881 - 31\n\nDescription\n\nInnovate. Collaborate. Build. Create. Solve. The KPMG Digital Lighthouse is KPMG\'s award-winning Analytics & AI Center of Excellence recognized by clients and leading analyst firms in the US and globally. The KPMG Lighthouse is a curation of specialized technical capabilities and domain experts working across the digital landscape: applied data science, AI, data engineering and insights, software engineering, automation, and big data. Here, you\'ll work with a diverse team of professionals to explore and build solutions for clients in a multiplatform environment.\n\nYou\'ll be an important part of our high-energy, unique, fast-paced, and innovative culture that delivers with the agility of a tech startup and the backing of a leading global consulting firm. In this particular role, you\'ll work specifically in the AI Analytics & Engineering Community within the Digital Lighthouse, on a wide range of projects. From applied AI to optimization to big data platform engineering, your analytical and technical skills will drive real impact in the business world. At KPMG, our commitment to your career development helps to set us apart as an employer. We want to enhance your potential, both for yourself and as a contributor to our firm. That\'s why we provide every opportunity to expand your skills, knowledge and experiences through formal education and training programs, leadership development opportunities, and, as well as informal one-on-one coaching and mentoring from your KPMG colleagues.\n\nKPMG is currently seeking an Associate to join our KPMG Lighthouse - Center of Excellence for Advanced Analytics.\n\n\n\n\n\nKPMG LLP (the U.S. member firm of KPMG International) offers a comprehensive compensation and benefits package. KPMG is an affirmative action-equal opportunity employer. KPMG complies with all applicable federal, state and local laws regarding recruitment and hiring. All qualified applicants are considered for employment without regard to race, color, religion, age, sex, sexual orientation, gender identity, national origin, disability, protected veteran status, or any other category protected by applicable federal, state or local laws. The attached link contains further information regarding the firm\'s compliance with federal, state and local recruitment and hiring laws. No phone calls or agencies please.",[],[]\n"Systems Planning and Analysis, Inc.",Data Scientist - CWMD,"Reston, VA",,https://www.linkedin.com/jobs/view/2719087133/?eBP=CwEAAAF8A9ofOs3Q1pRDNomWkKq8WZKKrxzVFph6K2D4ymCmOH1h4zujhf7yBWfSjCtGRdbAe9Qx1ZFnDclUFpBrbo8MAanx6IoSd6oeFzDujMeur4dsRn-KObiuVvRuoE8jax4zNaj2cL0qgNswrocbKDKdYn82E7vixG1bp6oL35Xs1t4QTILoMHsFU_wTZqMgC7fCMPF3UzzYVoZ7UpLI2jutAFhJUtKKFD94vE5WkDbZOlxsnkXaN96-uctzECAJaz-JWJTbMRDHUek1yOdijC16J7HeR8V1Snd1B3f-lHcwkIyohdLJUUsi0dDpOWpoQNpv7XWOgAXT-NzCdHsRY99xfHcFFJK5r9UEJvFy__j3f60gUpWxie9aT8NO&recommendedFlavor=ACTIVELY_HIRING_COMPANY&refId=uAGrvRCfo9q5%2BNk5EGGm4Q%3D%3D&trackingId=sCAmjQEN8DY8a6u7bP7Yfg%3D%3D&trk=flagship3_search_srp_jobs,"About the job\nOverview\n\nSystems Planning and Analysis, Inc. (SPA) is a well-established and progressive defense contracting company in the DC Metro area. We are a professional services firm established in 1972 that has a long-standing reputation for unrivaled technical and analytical support to some of the top decision makers in the Federal Sector. We do state of the art work and have a cadre of outstanding professionals on our team.\n\nSPA assists the Defense Threat Reduction Agency (DTRA) in developing leading edge technologies to counter WMD in support of CCMDs and transitioning these technologies to services and SOCOM. SPA provides expertise across the full range of chemical, biological, radiological, nuclear and high-yield explosives (CBRNE) WMD, Counter Improvised Threat and Countering Threat Network technologies to support understanding, detection, identification, characterization, denial, control, disabling, defeating, disposing, safeguarding the force, managing consequences, and test and evaluation in support of military and civilian operations. #CJ #IN123\n\n\n\nProvides critical decision and analytic support to the Urgent Solutions Division in the Counter WMD Technologies Department of the Defense Threat Reduction Agency (DTRA). Conducts assessments, demonstrations, analysis, scientific codes, and other decision making in evaluating systems to counter WMD – biological and chemical threats, and counter threat networks. Develops knowledge regarding a stipulated issue through analysis of complex data sets, identifying actionable trends and problems. Uses appropriate methods to creatively explore, mine, analyze and manipulate data sets ranging in size from sparse to petabytes and type (e.g. small number of .pdf text reports, Excel spreadsheets and .csv files to repositories of image or audio data). Interprets results from multiple sources using a variety of techniques, ranging from simple data aggregation via statistical analysis to complex data mining, sensor analysis and learning techniques. Designs, develops, and implements technical solutions in support of concurrent analysis. Supports data models and defines the structure, attributes, and nomenclature of data elements. May evaluate new data sources for adherence to the organization\'s quality standards and ease of integration.",[],[]\nPerficient,Data Scientist,"St Louis, MO",,https://www.linkedin.com/jobs/view/2718055481/?eBP=CwEAAAF8A9ofOhOHpkH95U2fvN9F-goU76IrWGZ2_h1PEIqUbFxqxI6w3ypUfMSWfMRpTGEJDX9iicxg3Is1hE7MJg4ixQ2ZJfmdAFAR38WMuWQ9RdnHIEX4XrSbapYsM3nhi6Iyv6rH9MEC1PpEqmZkvr8JBlfU1asVfgP3pl3rW4IS6tIVJuzERferAoB3ycE-UB94AE92MTfUPPOUagL-zhuIsIcyQ6BMfE6eFGYpZpAHbvdti7-s852GjLAxYFovRGVyerfbSKSeZm6fVVXT2EaQfKYvMN5hBZBBVncwxNfzaaMBbKZ9moxmBg76BZ3UfB6YOntWLvvf06jI4VVqLMZ_BYq4iT8Jnp-YKt2dJxnECW-9zW66IbRoeRPT&recommendedFlavor=COMPANY_RECRUIT&refId=uAGrvRCfo9q5%2BNk5EGGm4Q%3D%3D&trackingId=UE7bblhxeqWJV52%2F9JWJew%3D%3D&trk=flagship3_search_srp_jobs,"About the job\nOverview\n\nAt Perficient you’ll deliver mission-critical technology and business solutions to Fortune 500 companies and some of the most recognized brands on the planet. And you’ll do it with cutting-edge technologies, thanks to our close partnerships with the world’s biggest vendors. Our network of offices across North America, as well as locations in India and China, will give you the opportunity to spread your wings, too.\n\nWe’re proud to be publicly recognized as a “Top Workplace” year after year. This is due, in no small part, to our entrepreneurial attitude and collaborative spirit that sets us apart and keeps our colleagues impassioned, driven, and fulfilled.\n\nPerficient currently has a career opportunity for a .\n\n\n\nThe role of the Data Scientist is for individuals passionate about identifying and delivering the right Business solution for each client using AI/ML. Our Data Scientists are keen to understand our customer needs, processes and pain points to determine the success factors and evaluation criteria that will needed to measure the effectiveness of an ML model.\n\nThe Data Scientist will be involved in the strategic planning of an engagement or helping the client make decisions about their future AI/ML roadmap and vision. Once the project as begun, the Data Scientist will be responsible for the execution of our established methodology, work with customer and/or the teams data engineer to identify data ingestion and transformation needs, exploration of the data and reporting findings, modeling and evaluation of training iterations. It is a key part of the role to be able to explain in non-technical terms the chosen modeling approach and findings from data exploration or training results.\n\nThe Data Scientist will work with Senior Project Managers to assist with daily operations exercising time management, communication and collaboration in a fast-paced environment to ensure the successful delivery of projects. The Data Scientist will interface with Perficient technical and business delivery personnel, as well as vendors and customers on a regular basis. May mentor junior data scientists.\n\n\n\n\n\n\n\nPerficient full-time employees receive complete and competitive benefits. We offer a collaborative work environment, competitive compensation, generous work/life opportunities and an outstanding benefits package that includes paid time off plus holidays. In addition, all colleagues are eligible for a number of rewards and recognition programs including billable bonus opportunities. Encouraging a healthy work/life balance and providing our colleagues great benefits are just part of what makes Perficient a great place to work.\n\n\n\nPerficient is the leading digital transformation consulting firm serving Global 2000 and enterprise customers throughout North America. With unparalleled information technology, management consulting and creative capabilities, Perficient and its Perficient Digital agency deliver vision, execution and value with outstanding digital experience, business optimization and industry solutions.\n\nOur work enables clients to improve productivity and competitiveness; grow and strengthen relationships with customers, suppliers and partners; and reduce costs. Perficient\'s professionals serve clients from a network of offices across North America and offshore locations in India and China. Traded on the Nasdaq Global Select Market, Perficient is a member of the Russell 2000 index and the S&P SmallCap 600 index.\n\nPerficient is an equal opportunity employer and all qualified applicants will receive consideration for employment without regard to race, color, religion, sex, national, origin, disability status, protected veteran status, or any other characteristic protected by law.\n\nThe above statements are not intended to be a complete statement of job content, rather to act as a guide to the essential functions performed by the employee assigned to this classification. Management retains the discretion to add or change the duties of the position at any time.\n\nSelect work authorization questions to ask when applicants apply",[],[]\nSavage X Fenty: Lingerie by Rihanna,Data Scientist,"El Segundo, CA",,https://www.linkedin.com/jobs/view/2721710042/?eBP=CwEAAAF8A9ofOhPzbWsStxaNEgpMLIbvO6Vvpf-kp8RGwvYOJKGphyyakdc_4SGsjm2VeRAGjmk-vJ6l9A5H_dap2I3Kpoi5h6gKOdZGPr43fehHk5BqkiDkbvKki_to05FvWLinOBzurpjsMFG3JoeqUJ8xRReTFcidZnHYUQE6jUxh0nf-LNmAPuQp7YZEmPEps45wTFpgh1xQa_nwnLky1x-nzte_8YwEIsmHKQ5z2VTOvDevWj_NNLxyfvp4hDKsNbBNyQC_28gSNPkqkg6iN2yFOum-URpP05X-BwoG-gN9HPsuQJs-bhqDslt8i6wwag517FTdUMMYWqa29zUtuHYFUf1ei5iEh0ffOBNdGGDafvdOB4z8Oqp3hxLnHhY&recommendedFlavor=ACTIVELY_HIRING_COMPANY&refId=uAGrvRCfo9q5%2BNk5EGGm4Q%3D%3D&trackingId=WJuu5WmPKTuvZRyUdmNdtA%3D%3D&trk=flagship3_search_srp_jobs,"About the job\nJob DescriptionSavage X Fenty is looking for a Data Scientist. Co-founded by music and fashion icon Rihanna, Savage X Fenty is the first line of lingerie that celebrates and speaks to all shades and shapes of people, and celebrates fearlessness, confidence and inclusivity.\n\nHOW DO YOU FIT IN?\n\nAs the Data Scientist, you will drive innovation in our customer shopping experience by providing the algorithms that power recommendation and personalization features across our ecommerce website. You will collaborate closely with the Data Analytics organization, the Global Technology organization, and the Savage X business to develop high-impact solutions to key optimization opportunities such as ecommerce conversion & product discovery. You will watch your work come to life by partnering with dedicated product & software engineering teams to deploy your algorithms into production.\n\nProjects you are likely to own in this role include:\n\nProduct Recommendation Algorithms (e.g., product discovery & upsell algorithms)\n\nFull Funnel Customer Segmentation (e.g., algorithmically define customer segments and stream segments to other tools such as our CRM or ad networks)\n\nInternal Optimization Algorithms (e.g., attribution models, sales propensity algorithms)\n\nAt Savage X Fenty you can expect to use Python and SQL every day. For larger projects requiring scale or automation you’ll likely be working with DataBricks and Airflow. While these are our defaults, you will have the flexibility to use tools that allow you to best fulfill your role. Additionally, we strongly believe in the need for ongoing education and so will encourage you to explore new technologies and modeling methods on a regular basis.\n\n\n\nYou’re the ideal candidate if you’re incredibly curious & see opportunities for data science applications in everything you do. Working smarter, not harder, is core to your DNA. You’re invigorated by the opportunity to learn that next tool or skill, and you come up with clever solutions to difficult problems. As much as you learned in school or at work, you’ve probably learned even more during your late-night hacking sessions. You take initiative, can work without supervision, begin projects independently, and are technically capable with a deep desire to become an expert in data science applications for ecommerce. You’re seeking a collaborative environment in which you can work alongside other technology experts to find the best answer and win as a team.\n\nThis position will report to the Director of Data Analytics on the Savage X Fenty Analytics Team. The position will also have an informal reporting line to the Sr. Director of Data Science on the TechStyleOS Architecture & Sciences team. We are a creative, ambitious, & fun-loving team who believes data products should be collaboratively designed, impactful to the business, and customized for the end user. Our analytics team acts as strategic partners to the business, making an impact by merging data with a deep understanding of the Savage customer experience.\n\nThis position will be based in El Segundo, California. For the right candidate, we will consider full-time remote work.\n\nWHY WORK IN DATA SCIENCE AT SAVAGE X?\n\nWork within a community of data scientists through our parent company TechStyle Fashion Group & our sister brand Fabletics, but be the first Data Scientist dedicated to the Savage X brand. This role will design the foundation for Savage’s future data science initiatives & experience fast paced growth\n\nDedicated resources to support you – Savage X is investing heavily in data science and has staffed dedicated engineering & product management to support your initiatives\n\nIndustry leading data technology stack – Snowflake, DataBricks, Segment Customer Data Platform, Apache Airflow, modeled reporting data warehouse, & more\n\nData-driven mindset is deeply foundational to the culture at Savage X; information flows freely throughout our organization and every key decision we make is backed by analysis\n\nBe a part of the larger Data Analytics organization at TechStyle Fashion Group (60+ team members); mentor & be mentored by our architects, scientists, analysts, & engineers\n\n\n\nLeverage our advanced tech stack, your knowledge of data science methods & models, and your partnerships with our senior engineers, scientists, and architects to determine the best approaches for algorithm development and implementation\n\nOwn algorithm development projects from start-to-end: design, develop, QA, deploy, experiment, and analyze\n\nPartner with dedicated product management & software engineering teams to implement data science algorithms onto our consumer-facing ecommerce website\n\nPartner with dedicated analysts to produce data visualizations, advanced reports, measurement and statistical models that explain and track algorithm performance against business KPIs\n\nPartner with the business to identify & understand opportunities for data science applications\n\nProvide thought leadership and data support to the business & other analytics team members around design, execution, and measurement of business KPIs\n\nCollaborate with other data scientists across our organization to share best practices, learn new techniques, and foster our organizational culture where data is central to decision making\n\n\n\nHigh degree of personal integrity, strong work ethic, & a desire to learn and grow in this role\n\n2+ years of work experience as a Data Scientist or Machine Learning Engineer\n\nFluent in R or Python (Python preferred) & SQL\n\nFamiliarity with Machine Learning techniques (e.g. classification, clustering, regularization, optimization, dimension reduction, feature engineering)\n\nStrong understanding of CS fundamentals (e.g. algorithms and data structures)\n\nExperience with attribution, causal inference, experimental design, and AB testing methods\n\nGood communication skills and ability to explain complex topics to a non-technical audience\n\n\n\nExperience partnering with product management & software engineering teams to implement algorithms into a production environment\n\nDegree or Advanced Degree in Statistics, Computer Science, or related fields\n\nExperience with Git and/or Airflow\n\nExperience with data visualization tools such as Tableau\n\nExperience in e-commerce, subscription models, and/or direct-to-consumer brands\n\nFamiliarity with web analytics tools & concepts (Google Analytics, pixel tracking, Segment Customer Data Platform or comparable tools)\n\n\n\nTechStyleOS is the globally integrated Operations and Services provider behind some of the fastest growing online fashion brands in history, including Fabletics, Savage X Fenty, JustFab, ShoeDazzle, and FabKids. With capabilities spanning technology, data science, supply chain management, fulfillment, customer service, and more, we help brands launch, scale and grow—across product categories and geographically. From predictive analytics to data-driven marketing and attribution, our unique approach is powered by our proprietary, end-to-end tech platform that enables the brands we serve to deliver a level of personalization, value, and satisfaction that are unrivaled in the fashion industry.\n\nSavage X Inc.is an equal opportunity employer. We recruit, employ, compensate, develop, and promote regardless of race, national origin, religion, sex, sexual orientation, gender identity, age, disability, genetic information, veteran status, and other protected status as required by applicable. At Savage X Inc. , we champion a vibrant workplace culture that thrives on diversity law and do not tolerate discrimination or harassment. We are one team from many backgrounds, innovating through diversity of individuals, who are driven by passion for creating an inclusive space for all. Savage X Inc. will continue to champion a workplace culture that prizes diversity and inclusivity.\n\nWe encourage you to apply regardless of meeting all qualifications and/or requirements.",[],[]\nWestern Governors University,Data Scientist-2,"St Louis, MO",,https://www.linkedin.com/jobs/view/2718750842/?eBP=CwEAAAF8A9ofOjpba68ujoLXQAaOCBXYiS4C1yUTdLuyzCZe9eu8Ol6E5B1OavyEuBokToqXvI8orCg9mTa7e7zpzyV9cy10rVkKoDvZEPBDm1du-SyxnPgFICjxXnkLuO4a476oKPYJHgNsT_wxWcVM7UPEe_A4rGFK3u5Nxocz6TO1M6QF-5VfM-4C6pvZ-cryEakyxdZm6GaHw7p9zbMvWyaV6i1CvmDXy27crdTMH0Tc23b0hvt7S-fanNHX4dGjk06Is5AS7iuF-deOP1A46W0iSZPaIhLkVkBxOTTw8Wp12qn_2fxTdloxilj5f3cSIkJJSt5CyCNX3COteQXhYjO8geRyhwPGFGyDICcz7CEBCngNc2CFZt-0BfY9piw&recommendedFlavor=COMPANY_RECRUIT&refId=uAGrvRCfo9q5%2BNk5EGGm4Q%3D%3D&trackingId=nI03Xvg4nBirIwj8TRNSAQ%3D%3D&trk=flagship3_search_srp_jobs,"About the job\nIf you’re passionate about building a better future for individuals, communities, and our country—and you’re committed to working hard to play your part in building that future—consider WGU as the next step in your career.\n\nDriven by a mission to expand access to higher education through online, competency-based degree programs, WGU is also committed to being a great place to work for a diverse workforce of student-focused professionals. The university has pioneered a new way to learn in the 21st century, one that has received praise from academic, industry, government, and media leaders. Whatever your role, working for WGU gives you a part to play in helping students graduate, creating a better tomorrow for themselves and their families.\n\n\n\n\n\n:\n\n\n\n\n\nAs an equal opportunity employer, WGU recognizes that our strength lies in our people. We are committed to diversity.",[],[]\nCarShield,Data Scientist,"St Louis, MO","50 minutes ago\nWithin the past 24 hours",https://www.linkedin.com/jobs/view/2723209281/?eBP=JOB_SEARCH_ORGANIC&recommendedFlavor=COMPANY_RECRUIT&refId=uAGrvRCfo9q5%2BNk5EGGm4Q%3D%3D&trackingId=KgTMJ%2FOU15u5GSRxFma6BA%3D%3D&trk=flagship3_search_srp_jobs,"About the job\nJob Description\nResponsible for overseeing the collection, storage and interpretation of data for businesses. Their duties include sifting through data points to create organized categories, comparing data points to current company processes and writing reports outlining business predictions or proposals.",[],[]\nAmerican Express Global Business Travel,Data Scientist,"Evansville, IN",6 days ago,https://www.linkedin.com/jobs/view/2716701280/?eBP=JOB_SEARCH_ORGANIC&recommendedFlavor=ACTIVELY_HIRING_COMPANY&refId=uAGrvRCfo9q5%2BNk5EGGm4Q%3D%3D&trackingId=%2FNnG2%2FT8eaQ5Auu0r1LwgQ%3D%3D&trk=flagship3_search_srp_jobs,"About the job\nThe Candidate Is Expected To Possess These Key Skills/technologies\n\nThe data science solutions engineer will be a member of the data analytics team and will lead efforts around building big data, data science, data quality, and BI/MI/AI solutions. An ideal candidate will be a The data science associate will have a growth-oriented, lean-startup mindset for building hands-on data science solutions. The ideal candidate will propose, experiment, execute, and operationalize advanced predictive, preemptive data solutions designed to help traveler, travel-manager, supplier, and client outcomes. The role will span full-scale product, enterprise, and operational data science. The candidate will focus and thrive in a hands-on applied role; he/she will demonstrate a strong penchant for quantitative, collaborative, outcome-oriented solutions-engineering.\n\n\n\n\n\n\n\nIndia>Virtual Location\n\nIt is our policy to provide equal employment opportunities to all individuals based on job-related qualifications and ability to perform a job, without regard to age, gender, gender identity, sexual orientation, race, color, religion, creed, national origin, disability, genetic information, veteran status, citizenship or marital status, and to maintain a non-discriminatory environment free from intimidation, harassment or bias based upon these grounds.\n\nPosted 6 Days Ago Full time J-46605\n\nAmerican Express Global Business Travel (GBT) is the world’s leading business partner for managed travel. We help companies and employees prosper by making sure travelers are present where and when it matters. We keep global business moving with the powerful backing of 16,000 travel professionals in more than 140 countries. Companies of all sizes, and in all places, rely on GBT to provide travel management services, organize meetings and events, and deliver business travel consulting.",[],[]\nKPMG US,"Associate, Data Scientist","Chicago, IL",,https://www.linkedin.com/jobs/view/2715182807/?eBP=CwEAAAF8A9ofOnXwJUuycM2gGRL1mcgrhKEvGOAPq7WvcuqVfhF3v31fFIUXMUZTB2_KdQBZae-zIVr4TaQH32qoMce5QiuRkyz35Qe4NunBDe1tO5oIPM_jRd0DRVV1Q2RE2NsRab1c65uetiOURFT5UacwF26coAIsRg_OLs_YoY_77ZEEy1w6kTyWThm4DdS0MF9eZsoLFRxcEZjVZPeHkjucUMmMlgDkGFolStofkAtovBw2_NeONzmFwJOWVe1GKQ1XqLioi_MqRW4kb3iJnvdR5E8PAb5PCjiNjJEfuIXO63QpyODR7y7X0dEhMCCkj_x1tLu5T0PQeNlCeZkpp7nWdyWZQtRzOXNNpH9yPYBeaNL_b3b8W8FSewL2XfI&recommendedFlavor=COMPANY_RECRUIT&refId=uAGrvRCfo9q5%2BNk5EGGm4Q%3D%3D&trackingId=tWMAG1KeTQs1iil6CAtrmQ%3D%3D&trk=flagship3_search_srp_jobs,"About the job\nRequisition Number: 70881 - 31\n\nDescription\n\nInnovate. Collaborate. Build. Create. Solve. The KPMG Digital Lighthouse is KPMG\'s award-winning Analytics & AI Center of Excellence recognized by clients and leading analyst firms in the US and globally. The KPMG Lighthouse is a curation of specialized technical capabilities and domain experts working across the digital landscape: applied data science, AI, data engineering and insights, software engineering, automation, and big data. Here, you\'ll work with a diverse team of professionals to explore and build solutions for clients in a multiplatform environment.\n\nYou\'ll be an important part of our high-energy, unique, fast-paced, and innovative culture that delivers with the agility of a tech startup and the backing of a leading global consulting firm. In this particular role, you\'ll work specifically in the AI Analytics & Engineering Community within the Digital Lighthouse, on a wide range of projects. From applied AI to optimization to big data platform engineering, your analytical and technical skills will drive real impact in the business world. At KPMG, our commitment to your career development helps to set us apart as an employer. We want to enhance your potential, both for yourself and as a contributor to our firm. That\'s why we provide every opportunity to expand your skills, knowledge and experiences through formal education and training programs, leadership development opportunities, and, as well as informal one-on-one coaching and mentoring from your KPMG colleagues.\n\nKPMG is currently seeking an Associate to join our KPMG Lighthouse - Center of Excellence for Advanced Analytics.\n\n\n\n\n\nKPMG LLP (the U.S. member firm of KPMG International) offers a comprehensive compensation and benefits package. KPMG is an affirmative action-equal opportunity employer. KPMG complies with all applicable federal, state and local laws regarding recruitment and hiring. All qualified applicants are considered for employment without regard to race, color, religion, age, sex, sexual orientation, gender identity, national origin, disability, protected veteran status, or any other category protected by applicable federal, state or local laws. The attached link contains further information regarding the firm\'s compliance with federal, state and local recruitment and hiring laws. No phone calls or agencies please.",[],[]\n"Systems Planning and Analysis, Inc.",Data Scientist - CWMD,"Reston, VA",,https://www.linkedin.com/jobs/view/2719087133/?eBP=CwEAAAF8A9ofOs3Q1pRDNomWkKq8WZKKrxzVFph6K2D4ymCmOH1h4zujhf7yBWfSjCtGRdbAe9Qx1ZFnDclUFpBrbo8MAanx6IoSd6oeFzDujMeur4dsRn-KObiuVvRuoE8jax4zNaj2cL0qgNswrocbKDKdYn82E7vixG1bp6oL35Xs1t4QTILoMHsFU_wTZqMgC7fCMPF3UzzYVoZ7UpLI2jutAFhJUtKKFD94vE5WkDbZOlxsnkXaN96-uctzECAJaz-JWJTbMRDHUek1yOdijC16J7HeR8V1Snd1B3f-lHcwkIyohdLJUUsi0dDpOWpoQNpv7XWOgAXT-NzCdHsRY99xfHcFFJK5r9UEJvFy__j3f60gUpWxie9aT8NO&recommendedFlavor=ACTIVELY_HIRING_COMPANY&refId=uAGrvRCfo9q5%2BNk5EGGm4Q%3D%3D&trackingId=sCAmjQEN8DY8a6u7bP7Yfg%3D%3D&trk=flagship3_search_srp_jobs,"About the job\nOverview\n\nSystems Planning and Analysis, Inc. (SPA) is a well-established and progressive defense contracting company in the DC Metro area. We are a professional services firm established in 1972 that has a long-standing reputation for unrivaled technical and analytical support to some of the top decision makers in the Federal Sector. We do state of the art work and have a cadre of outstanding professionals on our team.\n\nSPA assists the Defense Threat Reduction Agency (DTRA) in developing leading edge technologies to counter WMD in support of CCMDs and transitioning these technologies to services and SOCOM. SPA provides expertise across the full range of chemical, biological, radiological, nuclear and high-yield explosives (CBRNE) WMD, Counter Improvised Threat and Countering Threat Network technologies to support understanding, detection, identification, characterization, denial, control, disabling, defeating, disposing, safeguarding the force, managing consequences, and test and evaluation in support of military and civilian operations. #CJ #IN123\n\n\n\nProvides critical decision and analytic support to the Urgent Solutions Division in the Counter WMD Technologies Department of the Defense Threat Reduction Agency (DTRA). Conducts assessments, demonstrations, analysis, scientific codes, and other decision making in evaluating systems to counter WMD – biological and chemical threats, and counter threat networks. Develops knowledge regarding a stipulated issue through analysis of complex data sets, identifying actionable trends and problems. Uses appropriate methods to creatively explore, mine, analyze and manipulate data sets ranging in size from sparse to petabytes and type (e.g. small number of .pdf text reports, Excel spreadsheets and .csv files to repositories of image or audio data). Interprets results from multiple sources using a variety of techniques, ranging from simple data aggregation via statistical analysis to complex data mining, sensor analysis and learning techniques. Designs, develops, and implements technical solutions in support of concurrent analysis. Supports data models and defines the structure, attributes, and nomenclature of data elements. May evaluate new data sources for adherence to the organization\'s quality standards and ease of integration.",[],[]\nPerficient,Data Scientist,"St Louis, MO",,https://www.linkedin.com/jobs/view/2718055481/?eBP=CwEAAAF8A9ofOhOHpkH95U2fvN9F-goU76IrWGZ2_h1PEIqUbFxqxI6w3ypUfMSWfMRpTGEJDX9iicxg3Is1hE7MJg4ixQ2ZJfmdAFAR38WMuWQ9RdnHIEX4XrSbapYsM3nhi6Iyv6rH9MEC1PpEqmZkvr8JBlfU1asVfgP3pl3rW4IS6tIVJuzERferAoB3ycE-UB94AE92MTfUPPOUagL-zhuIsIcyQ6BMfE6eFGYpZpAHbvdti7-s852GjLAxYFovRGVyerfbSKSeZm6fVVXT2EaQfKYvMN5hBZBBVncwxNfzaaMBbKZ9moxmBg76BZ3UfB6YOntWLvvf06jI4VVqLMZ_BYq4iT8Jnp-YKt2dJxnECW-9zW66IbRoeRPT&recommendedFlavor=COMPANY_RECRUIT&refId=uAGrvRCfo9q5%2BNk5EGGm4Q%3D%3D&trackingId=UE7bblhxeqWJV52%2F9JWJew%3D%3D&trk=flagship3_search_srp_jobs,"About the job\nOverview\n\nAt Perficient you’ll deliver mission-critical technology and business solutions to Fortune 500 companies and some of the most recognized brands on the planet. And you’ll do it with cutting-edge technologies, thanks to our close partnerships with the world’s biggest vendors. Our network of offices across North America, as well as locations in India and China, will give you the opportunity to spread your wings, too.\n\nWe’re proud to be publicly recognized as a “Top Workplace” year after year. This is due, in no small part, to our entrepreneurial attitude and collaborative spirit that sets us apart and keeps our colleagues impassioned, driven, and fulfilled.\n\nPerficient currently has a career opportunity for a .\n\n\n\nThe role of the Data Scientist is for individuals passionate about identifying and delivering the right Business solution for each client using AI/ML. Our Data Scientists are keen to understand our customer needs, processes and pain points to determine the success factors and evaluation criteria that will needed to measure the effectiveness of an ML model.\n\nThe Data Scientist will be involved in the strategic planning of an engagement or helping the client make decisions about their future AI/ML roadmap and vision. Once the project as begun, the Data Scientist will be responsible for the execution of our established methodology, work with customer and/or the teams data engineer to identify data ingestion and transformation needs, exploration of the data and reporting findings, modeling and evaluation of training iterations. It is a key part of the role to be able to explain in non-technical terms the chosen modeling approach and findings from data exploration or training results.\n\nThe Data Scientist will work with Senior Project Managers to assist with daily operations exercising time management, communication and collaboration in a fast-paced environment to ensure the successful delivery of projects. The Data Scientist will interface with Perficient technical and business delivery personnel, as well as vendors and customers on a regular basis. May mentor junior data scientists.\n\n\n\n\n\n\n\nPerficient full-time employees receive complete and competitive benefits. We offer a collaborative work environment, competitive compensation, generous work/life opportunities and an outstanding benefits package that includes paid time off plus holidays. In addition, all colleagues are eligible for a number of rewards and recognition programs including billable bonus opportunities. Encouraging a healthy work/life balance and providing our colleagues great benefits are just part of what makes Perficient a great place to work.\n\n\n\nPerficient is the leading digital transformation consulting firm serving Global 2000 and enterprise customers throughout North America. With unparalleled information technology, management consulting and creative capabilities, Perficient and its Perficient Digital agency deliver vision, execution and value with outstanding digital experience, business optimization and industry solutions.\n\nOur work enables clients to improve productivity and competitiveness; grow and strengthen relationships with customers, suppliers and partners; and reduce costs. Perficient\'s professionals serve clients from a network of offices across North America and offshore locations in India and China. Traded on the Nasdaq Global Select Market, Perficient is a member of the Russell 2000 index and the S&P SmallCap 600 index.\n\nPerficient is an equal opportunity employer and all qualified applicants will receive consideration for employment without regard to race, color, religion, sex, national, origin, disability status, protected veteran status, or any other characteristic protected by law.\n\nThe above statements are not intended to be a complete statement of job content, rather to act as a guide to the essential functions performed by the employee assigned to this classification. Management retains the discretion to add or change the duties of the position at any time.\n\nSelect work authorization questions to ask when applicants apply",[],[]\nSavage X Fenty: Lingerie by Rihanna,Data Scientist,"El Segundo, CA",,https://www.linkedin.com/jobs/view/2721710042/?eBP=CwEAAAF8A9ofOhPzbWsStxaNEgpMLIbvO6Vvpf-kp8RGwvYOJKGphyyakdc_4SGsjm2VeRAGjmk-vJ6l9A5H_dap2I3Kpoi5h6gKOdZGPr43fehHk5BqkiDkbvKki_to05FvWLinOBzurpjsMFG3JoeqUJ8xRReTFcidZnHYUQE6jUxh0nf-LNmAPuQp7YZEmPEps45wTFpgh1xQa_nwnLky1x-nzte_8YwEIsmHKQ5z2VTOvDevWj_NNLxyfvp4hDKsNbBNyQC_28gSNPkqkg6iN2yFOum-URpP05X-BwoG-gN9HPsuQJs-bhqDslt8i6wwag517FTdUMMYWqa29zUtuHYFUf1ei5iEh0ffOBNdGGDafvdOB4z8Oqp3hxLnHhY&recommendedFlavor=ACTIVELY_HIRING_COMPANY&refId=uAGrvRCfo9q5%2BNk5EGGm4Q%3D%3D&trackingId=WJuu5WmPKTuvZRyUdmNdtA%3D%3D&trk=flagship3_search_srp_jobs,"About the job\nJob DescriptionSavage X Fenty is looking for a Data Scientist. Co-founded by music and fashion icon Rihanna, Savage X Fenty is the first line of lingerie that celebrates and speaks to all shades and shapes of people, and celebrates fearlessness, confidence and inclusivity.\n\nHOW DO YOU FIT IN?\n\nAs the Data Scientist, you will drive innovation in our customer shopping experience by providing the algorithms that power recommendation and personalization features across our ecommerce website. You will collaborate closely with the Data Analytics organization, the Global Technology organization, and the Savage X business to develop high-impact solutions to key optimization opportunities such as ecommerce conversion & product discovery. You will watch your work come to life by partnering with dedicated product & software engineering teams to deploy your algorithms into production.\n\nProjects you are likely to own in this role include:\n\nProduct Recommendation Algorithms (e.g., product discovery & upsell algorithms)\n\nFull Funnel Customer Segmentation (e.g., algorithmically define customer segments and stream segments to other tools such as our CRM or ad networks)\n\nInternal Optimization Algorithms (e.g., attribution models, sales propensity algorithms)\n\nAt Savage X Fenty you can expect to use Python and SQL every day. For larger projects requiring scale or automation you’ll likely be working with DataBricks and Airflow. While these are our defaults, you will have the flexibility to use tools that allow you to best fulfill your role. Additionally, we strongly believe in the need for ongoing education and so will encourage you to explore new technologies and modeling methods on a regular basis.\n\n\n\nYou’re the ideal candidate if you’re incredibly curious & see opportunities for data science applications in everything you do. Working smarter, not harder, is core to your DNA. You’re invigorated by the opportunity to learn that next tool or skill, and you come up with clever solutions to difficult problems. As much as you learned in school or at work, you’ve probably learned even more during your late-night hacking sessions. You take initiative, can work without supervision, begin projects independently, and are technically capable with a deep desire to become an expert in data science applications for ecommerce. You’re seeking a collaborative environment in which you can work alongside other technology experts to find the best answer and win as a team.\n\nThis position will report to the Director of Data Analytics on the Savage X Fenty Analytics Team. The position will also have an informal reporting line to the Sr. Director of Data Science on the TechStyleOS Architecture & Sciences team. We are a creative, ambitious, & fun-loving team who believes data products should be collaboratively designed, impactful to the business, and customized for the end user. Our analytics team acts as strategic partners to the business, making an impact by merging data with a deep understanding of the Savage customer experience.\n\nThis position will be based in El Segundo, California. For the right candidate, we will consider full-time remote work.\n\nWHY WORK IN DATA SCIENCE AT SAVAGE X?\n\nWork within a community of data scientists through our parent company TechStyle Fashion Group & our sister brand Fabletics, but be the first Data Scientist dedicated to the Savage X brand. This role will design the foundation for Savage’s future data science initiatives & experience fast paced growth\n\nDedicated resources to support you – Savage X is investing heavily in data science and has staffed dedicated engineering & product management to support your initiatives\n\nIndustry leading data technology stack – Snowflake, DataBricks, Segment Customer Data Platform, Apache Airflow, modeled reporting data warehouse, & more\n\nData-driven mindset is deeply foundational to the culture at Savage X; information flows freely throughout our organization and every key decision we make is backed by analysis\n\nBe a part of the larger Data Analytics organization at TechStyle Fashion Group (60+ team members); mentor & be mentored by our architects, scientists, analysts, & engineers\n\n\n\nLeverage our advanced tech stack, your knowledge of data science methods & models, and your partnerships with our senior engineers, scientists, and architects to determine the best approaches for algorithm development and implementation\n\nOwn algorithm development projects from start-to-end: design, develop, QA, deploy, experiment, and analyze\n\nPartner with dedicated product management & software engineering teams to implement data science algorithms onto our consumer-facing ecommerce website\n\nPartner with dedicated analysts to produce data visualizations, advanced reports, measurement and statistical models that explain and track algorithm performance against business KPIs\n\nPartner with the business to identify & understand opportunities for data science applications\n\nProvide thought leadership and data support to the business & other analytics team members around design, execution, and measurement of business KPIs\n\nCollaborate with other data scientists across our organization to share best practices, learn new techniques, and foster our organizational culture where data is central to decision making\n\n\n\nHigh degree of personal integrity, strong work ethic, & a desire to learn and grow in this role\n\n2+ years of work experience as a Data Scientist or Machine Learning Engineer\n\nFluent in R or Python (Python preferred) & SQL\n\nFamiliarity with Machine Learning techniques (e.g. classification, clustering, regularization, optimization, dimension reduction, feature engineering)\n\nStrong understanding of CS fundamentals (e.g. algorithms and data structures)\n\nExperience with attribution, causal inference, experimental design, and AB testing methods\n\nGood communication skills and ability to explain complex topics to a non-technical audience\n\n\n\nExperience partnering with product management & software engineering teams to implement algorithms into a production environment\n\nDegree or Advanced Degree in Statistics, Computer Science, or related fields\n\nExperience with Git and/or Airflow\n\nExperience with data visualization tools such as Tableau\n\nExperience in e-commerce, subscription models, and/or direct-to-consumer brands\n\nFamiliarity with web analytics tools & concepts (Google Analytics, pixel tracking, Segment Customer Data Platform or comparable tools)\n\n\n\nTechStyleOS is the globally integrated Operations and Services provider behind some of the fastest growing online fashion brands in history, including Fabletics, Savage X Fenty, JustFab, ShoeDazzle, and FabKids. With capabilities spanning technology, data science, supply chain management, fulfillment, customer service, and more, we help brands launch, scale and grow—across product categories and geographically. From predictive analytics to data-driven marketing and attribution, our unique approach is powered by our proprietary, end-to-end tech platform that enables the brands we serve to deliver a level of personalization, value, and satisfaction that are unrivaled in the fashion industry.\n\nSavage X Inc.is an equal opportunity employer. We recruit, employ, compensate, develop, and promote regardless of race, national origin, religion, sex, sexual orientation, gender identity, age, disability, genetic information, veteran status, and other protected status as required by applicable. At Savage X Inc. , we champion a vibrant workplace culture that thrives on diversity law and do not tolerate discrimination or harassment. We are one team from many backgrounds, innovating through diversity of individuals, who are driven by passion for creating an inclusive space for all. Savage X Inc. will continue to champion a workplace culture that prizes diversity and inclusivity.\n\nWe encourage you to apply regardless of meeting all qualifications and/or requirements.",[],[]\nWestern Governors University,Data Scientist-2,"St Louis, MO",,https://www.linkedin.com/jobs/view/2718750842/?eBP=CwEAAAF8A9ofOjpba68ujoLXQAaOCBXYiS4C1yUTdLuyzCZe9eu8Ol6E5B1OavyEuBokToqXvI8orCg9mTa7e7zpzyV9cy10rVkKoDvZEPBDm1du-SyxnPgFICjxXnkLuO4a476oKPYJHgNsT_wxWcVM7UPEe_A4rGFK3u5Nxocz6TO1M6QF-5VfM-4C6pvZ-cryEakyxdZm6GaHw7p9zbMvWyaV6i1CvmDXy27crdTMH0Tc23b0hvt7S-fanNHX4dGjk06Is5AS7iuF-deOP1A46W0iSZPaIhLkVkBxOTTw8Wp12qn_2fxTdloxilj5f3cSIkJJSt5CyCNX3COteQXhYjO8geRyhwPGFGyDICcz7CEBCngNc2CFZt-0BfY9piw&recommendedFlavor=COMPANY_RECRUIT&refId=uAGrvRCfo9q5%2BNk5EGGm4Q%3D%3D&trackingId=nI03Xvg4nBirIwj8TRNSAQ%3D%3D&trk=flagship3_search_srp_jobs,"About the job\nIf you’re passionate about building a better future for individuals, communities, and our country—and you’re committed to working hard to play your part in building that future—consider WGU as the next step in your career.\n\nDriven by a mission to expand access to higher education through online, competency-based degree programs, WGU is also committed to being a great place to work for a diverse workforce of student-focused professionals. The university has pioneered a new way to learn in the 21st century, one that has received praise from academic, industry, government, and media leaders. Whatever your role, working for WGU gives you a part to play in helping students graduate, creating a better tomorrow for themselves and their families.\n\n\n\n\n\n:\n\n\n\n\n\nAs an equal opportunity employer, WGU recognizes that our strength lies in our people. We are committed to diversity.",[],[]\nCarShield,Data Scientist,"St Louis, MO","50 minutes ago\nWithin the past 24 hours",https://www.linkedin.com/jobs/view/2723209281/?eBP=JOB_SEARCH_ORGANIC&recommendedFlavor=COMPANY_RECRUIT&refId=uAGrvRCfo9q5%2BNk5EGGm4Q%3D%3D&trackingId=KgTMJ%2FOU15u5GSRxFma6BA%3D%3D&trk=flagship3_search_srp_jobs,"About the job\nJob Description\nResponsible for overseeing the collection, storage and interpretation of data for businesses. Their duties include sifting through data points to create organized categories, comparing data points to current company processes and writing reports outlining business predictions or proposals.",[],[]\nAmerican Express Global Business Travel,Data Scientist,"Evansville, IN",6 days ago,https://www.linkedin.com/jobs/view/2716701280/?eBP=JOB_SEARCH_ORGANIC&recommendedFlavor=ACTIVELY_HIRING_COMPANY&refId=uAGrvRCfo9q5%2BNk5EGGm4Q%3D%3D&trackingId=%2FNnG2%2FT8eaQ5Auu0r1LwgQ%3D%3D&trk=flagship3_search_srp_jobs,"About the job\nThe Candidate Is Expected To Possess These Key Skills/technologies\n\nThe data science solutions engineer will be a member of the data analytics team and will lead efforts around building big data, data science, data quality, and BI/MI/AI solutions. An ideal candidate will be a The data science associate will have a growth-oriented, lean-startup mindset for building hands-on data science solutions. The ideal candidate will propose, experiment, execute, and operationalize advanced predictive, preemptive data solutions designed to help traveler, travel-manager, supplier, and client outcomes. The role will span full-scale product, enterprise, and operational data science. The candidate will focus and thrive in a hands-on applied role; he/she will demonstrate a strong penchant for quantitative, collaborative, outcome-oriented solutions-engineering.\n\n\n\n\n\n\n\nIndia>Virtual Location\n\nIt is our policy to provide equal employment opportunities to all individuals based on job-related qualifications and ability to perform a job, without regard to age, gender, gender identity, sexual orientation, race, color, religion, creed, national origin, disability, genetic information, veteran status, citizenship or marital status, and to maintain a non-discriminatory environment free from intimidation, harassment or bias based upon these grounds.\n\nPosted 6 Days Ago Full time J-46605\n\nAmerican Express Global Business Travel (GBT) is the world’s leading business partner for managed travel. We help companies and employees prosper by making sure travelers are present where and when it matters. We keep global business moving with the powerful backing of 16,000 travel professionals in more than 140 countries. Companies of all sizes, and in all places, rely on GBT to provide travel management services, organize meetings and events, and deliver business travel consulting.",[],[]\nKPMG US,"Associate, Data Scientist","Chicago, IL",,https://www.linkedin.com/jobs/view/2715182807/?eBP=CwEAAAF8A9ofOnXwJUuycM2gGRL1mcgrhKEvGOAPq7WvcuqVfhF3v31fFIUXMUZTB2_KdQBZae-zIVr4TaQH32qoMce5QiuRkyz35Qe4NunBDe1tO5oIPM_jRd0DRVV1Q2RE2NsRab1c65uetiOURFT5UacwF26coAIsRg_OLs_YoY_77ZEEy1w6kTyWThm4DdS0MF9eZsoLFRxcEZjVZPeHkjucUMmMlgDkGFolStofkAtovBw2_NeONzmFwJOWVe1GKQ1XqLioi_MqRW4kb3iJnvdR5E8PAb5PCjiNjJEfuIXO63QpyODR7y7X0dEhMCCkj_x1tLu5T0PQeNlCeZkpp7nWdyWZQtRzOXNNpH9yPYBeaNL_b3b8W8FSewL2XfI&recommendedFlavor=COMPANY_RECRUIT&refId=uAGrvRCfo9q5%2BNk5EGGm4Q%3D%3D&trackingId=tWMAG1KeTQs1iil6CAtrmQ%3D%3D&trk=flagship3_search_srp_jobs,"About the job\nRequisition Number: 70881 - 31\n\nDescription\n\nInnovate. Collaborate. Build. Create. Solve. The KPMG Digital Lighthouse is KPMG\'s award-winning Analytics & AI Center of Excellence recognized by clients and leading analyst firms in the US and globally. The KPMG Lighthouse is a curation of specialized technical capabilities and domain experts working across the digital landscape: applied data science, AI, data engineering and insights, software engineering, automation, and big data. Here, you\'ll work with a diverse team of professionals to explore and build solutions for clients in a multiplatform environment.\n\nYou\'ll be an important part of our high-energy, unique, fast-paced, and innovative culture that delivers with the agility of a tech startup and the backing of a leading global consulting firm. In this particular role, you\'ll work specifically in the AI Analytics & Engineering Community within the Digital Lighthouse, on a wide range of projects. From applied AI to optimization to big data platform engineering, your analytical and technical skills will drive real impact in the business world. At KPMG, our commitment to your career development helps to set us apart as an employer. We want to enhance your potential, both for yourself and as a contributor to our firm. That\'s why we provide every opportunity to expand your skills, knowledge and experiences through formal education and training programs, leadership development opportunities, and, as well as informal one-on-one coaching and mentoring from your KPMG colleagues.\n\nKPMG is currently seeking an Associate to join our KPMG Lighthouse - Center of Excellence for Advanced Analytics.\n\n\n\n\n\nKPMG LLP (the U.S. member firm of KPMG International) offers a comprehensive compensation and benefits package. KPMG is an affirmative action-equal opportunity employer. KPMG complies with all applicable federal, state and local laws regarding recruitment and hiring. All qualified applicants are considered for employment without regard to race, color, religion, age, sex, sexual orientation, gender identity, national origin, disability, protected veteran status, or any other category protected by applicable federal, state or local laws. The attached link contains further information regarding the firm\'s compliance with federal, state and local recruitment and hiring laws. No phone calls or agencies please.",[],[]\n"Systems Planning and Analysis, Inc.",Data Scientist - CWMD,"Reston, VA",,https://www.linkedin.com/jobs/view/2719087133/?eBP=CwEAAAF8A9ofOs3Q1pRDNomWkKq8WZKKrxzVFph6K2D4ymCmOH1h4zujhf7yBWfSjCtGRdbAe9Qx1ZFnDclUFpBrbo8MAanx6IoSd6oeFzDujMeur4dsRn-KObiuVvRuoE8jax4zNaj2cL0qgNswrocbKDKdYn82E7vixG1bp6oL35Xs1t4QTILoMHsFU_wTZqMgC7fCMPF3UzzYVoZ7UpLI2jutAFhJUtKKFD94vE5WkDbZOlxsnkXaN96-uctzECAJaz-JWJTbMRDHUek1yOdijC16J7HeR8V1Snd1B3f-lHcwkIyohdLJUUsi0dDpOWpoQNpv7XWOgAXT-NzCdHsRY99xfHcFFJK5r9UEJvFy__j3f60gUpWxie9aT8NO&recommendedFlavor=ACTIVELY_HIRING_COMPANY&refId=uAGrvRCfo9q5%2BNk5EGGm4Q%3D%3D&trackingId=sCAmjQEN8DY8a6u7bP7Yfg%3D%3D&trk=flagship3_search_srp_jobs,"About the job\nOverview\n\nSystems Planning and Analysis, Inc. (SPA) is a well-established and progressive defense contracting company in the DC Metro area. We are a professional services firm established in 1972 that has a long-standing reputation for unrivaled technical and analytical support to some of the top decision makers in the Federal Sector. We do state of the art work and have a cadre of outstanding professionals on our team.\n\nSPA assists the Defense Threat Reduction Agency (DTRA) in developing leading edge technologies to counter WMD in support of CCMDs and transitioning these technologies to services and SOCOM. SPA provides expertise across the full range of chemical, biological, radiological, nuclear and high-yield explosives (CBRNE) WMD, Counter Improvised Threat and Countering Threat Network technologies to support understanding, detection, identification, characterization, denial, control, disabling, defeating, disposing, safeguarding the force, managing consequences, and test and evaluation in support of military and civilian operations. #CJ #IN123\n\n\n\nProvides critical decision and analytic support to the Urgent Solutions Division in the Counter WMD Technologies Department of the Defense Threat Reduction Agency (DTRA). Conducts assessments, demonstrations, analysis, scientific codes, and other decision making in evaluating systems to counter WMD – biological and chemical threats, and counter threat networks. Develops knowledge regarding a stipulated issue through analysis of complex data sets, identifying actionable trends and problems. Uses appropriate methods to creatively explore, mine, analyze and manipulate data sets ranging in size from sparse to petabytes and type (e.g. small number of .pdf text reports, Excel spreadsheets and .csv files to repositories of image or audio data). Interprets results from multiple sources using a variety of techniques, ranging from simple data aggregation via statistical analysis to complex data mining, sensor analysis and learning techniques. Designs, develops, and implements technical solutions in support of concurrent analysis. Supports data models and defines the structure, attributes, and nomenclature of data elements. May evaluate new data sources for adherence to the organization\'s quality standards and ease of integration.",[],[]\nPerficient,Data Scientist,"St Louis, MO",,https://www.linkedin.com/jobs/view/2718055481/?eBP=CwEAAAF8A9ofOhOHpkH95U2fvN9F-goU76IrWGZ2_h1PEIqUbFxqxI6w3ypUfMSWfMRpTGEJDX9iicxg3Is1hE7MJg4ixQ2ZJfmdAFAR38WMuWQ9RdnHIEX4XrSbapYsM3nhi6Iyv6rH9MEC1PpEqmZkvr8JBlfU1asVfgP3pl3rW4IS6tIVJuzERferAoB3ycE-UB94AE92MTfUPPOUagL-zhuIsIcyQ6BMfE6eFGYpZpAHbvdti7-s852GjLAxYFovRGVyerfbSKSeZm6fVVXT2EaQfKYvMN5hBZBBVncwxNfzaaMBbKZ9moxmBg76BZ3UfB6YOntWLvvf06jI4VVqLMZ_BYq4iT8Jnp-YKt2dJxnECW-9zW66IbRoeRPT&recommendedFlavor=COMPANY_RECRUIT&refId=uAGrvRCfo9q5%2BNk5EGGm4Q%3D%3D&trackingId=UE7bblhxeqWJV52%2F9JWJew%3D%3D&trk=flagship3_search_srp_jobs,"About the job\nOverview\n\nAt Perficient you’ll deliver mission-critical technology and business solutions to Fortune 500 companies and some of the most recognized brands on the planet. And you’ll do it with cutting-edge technologies, thanks to our close partnerships with the world’s biggest vendors. Our network of offices across North America, as well as locations in India and China, will give you the opportunity to spread your wings, too.\n\nWe’re proud to be publicly recognized as a “Top Workplace” year after year. This is due, in no small part, to our entrepreneurial attitude and collaborative spirit that sets us apart and keeps our colleagues impassioned, driven, and fulfilled.\n\nPerficient currently has a career opportunity for a .\n\n\n\nThe role of the Data Scientist is for individuals passionate about identifying and delivering the right Business solution for each client using AI/ML. Our Data Scientists are keen to understand our customer needs, processes and pain points to determine the success factors and evaluation criteria that will needed to measure the effectiveness of an ML model.\n\nThe Data Scientist will be involved in the strategic planning of an engagement or helping the client make decisions about their future AI/ML roadmap and vision. Once the project as begun, the Data Scientist will be responsible for the execution of our established methodology, work with customer and/or the teams data engineer to identify data ingestion and transformation needs, exploration of the data and reporting findings, modeling and evaluation of training iterations. It is a key part of the role to be able to explain in non-technical terms the chosen modeling approach and findings from data exploration or training results.\n\nThe Data Scientist will work with Senior Project Managers to assist with daily operations exercising time management, communication and collaboration in a fast-paced environment to ensure the successful delivery of projects. The Data Scientist will interface with Perficient technical and business delivery personnel, as well as vendors and customers on a regular basis. May mentor junior data scientists.\n\n\n\n\n\n\n\nPerficient full-time employees receive complete and competitive benefits. We offer a collaborative work environment, competitive compensation, generous work/life opportunities and an outstanding benefits package that includes paid time off plus holidays. In addition, all colleagues are eligible for a number of rewards and recognition programs including billable bonus opportunities. Encouraging a healthy work/life balance and providing our colleagues great benefits are just part of what makes Perficient a great place to work.\n\n\n\nPerficient is the leading digital transformation consulting firm serving Global 2000 and enterprise customers throughout North America. With unparalleled information technology, management consulting and creative capabilities, Perficient and its Perficient Digital agency deliver vision, execution and value with outstanding digital experience, business optimization and industry solutions.\n\nOur work enables clients to improve productivity and competitiveness; grow and strengthen relationships with customers, suppliers and partners; and reduce costs. Perficient\'s professionals serve clients from a network of offices across North America and offshore locations in India and China. Traded on the Nasdaq Global Select Market, Perficient is a member of the Russell 2000 index and the S&P SmallCap 600 index.\n\nPerficient is an equal opportunity employer and all qualified applicants will receive consideration for employment without regard to race, color, religion, sex, national, origin, disability status, protected veteran status, or any other characteristic protected by law.\n\nThe above statements are not intended to be a complete statement of job content, rather to act as a guide to the essential functions performed by the employee assigned to this classification. Management retains the discretion to add or change the duties of the position at any time.\n\nSelect work authorization questions to ask when applicants apply",[],[]\nSavage X Fenty: Lingerie by Rihanna,Data Scientist,"El Segundo, CA",,https://www.linkedin.com/jobs/view/2721710042/?eBP=CwEAAAF8A9ofOhPzbWsStxaNEgpMLIbvO6Vvpf-kp8RGwvYOJKGphyyakdc_4SGsjm2VeRAGjmk-vJ6l9A5H_dap2I3Kpoi5h6gKOdZGPr43fehHk5BqkiDkbvKki_to05FvWLinOBzurpjsMFG3JoeqUJ8xRReTFcidZnHYUQE6jUxh0nf-LNmAPuQp7YZEmPEps45wTFpgh1xQa_nwnLky1x-nzte_8YwEIsmHKQ5z2VTOvDevWj_NNLxyfvp4hDKsNbBNyQC_28gSNPkqkg6iN2yFOum-URpP05X-BwoG-gN9HPsuQJs-bhqDslt8i6wwag517FTdUMMYWqa29zUtuHYFUf1ei5iEh0ffOBNdGGDafvdOB4z8Oqp3hxLnHhY&recommendedFlavor=ACTIVELY_HIRING_COMPANY&refId=uAGrvRCfo9q5%2BNk5EGGm4Q%3D%3D&trackingId=WJuu5WmPKTuvZRyUdmNdtA%3D%3D&trk=flagship3_search_srp_jobs,"About the job\nJob DescriptionSavage X Fenty is looking for a Data Scientist. Co-founded by music and fashion icon Rihanna, Savage X Fenty is the first line of lingerie that celebrates and speaks to all shades and shapes of people, and celebrates fearlessness, confidence and inclusivity.\n\nHOW DO YOU FIT IN?\n\nAs the Data Scientist, you will drive innovation in our customer shopping experience by providing the algorithms that power recommendation and personalization features across our ecommerce website. You will collaborate closely with the Data Analytics organization, the Global Technology organization, and the Savage X business to develop high-impact solutions to key optimization opportunities such as ecommerce conversion & product discovery. You will watch your work come to life by partnering with dedicated product & software engineering teams to deploy your algorithms into production.\n\nProjects you are likely to own in this role include:\n\nProduct Recommendation Algorithms (e.g., product discovery & upsell algorithms)\n\nFull Funnel Customer Segmentation (e.g., algorithmically define customer segments and stream segments to other tools such as our CRM or ad networks)\n\nInternal Optimization Algorithms (e.g., attribution models, sales propensity algorithms)\n\nAt Savage X Fenty you can expect to use Python and SQL every day. For larger projects requiring scale or automation you’ll likely be working with DataBricks and Airflow. While these are our defaults, you will have the flexibility to use tools that allow you to best fulfill your role. Additionally, we strongly believe in the need for ongoing education and so will encourage you to explore new technologies and modeling methods on a regular basis.\n\n\n\nYou’re the ideal candidate if you’re incredibly curious & see opportunities for data science applications in everything you do. Working smarter, not harder, is core to your DNA. You’re invigorated by the opportunity to learn that next tool or skill, and you come up with clever solutions to difficult problems. As much as you learned in school or at work, you’ve probably learned even more during your late-night hacking sessions. You take initiative, can work without supervision, begin projects independently, and are technically capable with a deep desire to become an expert in data science applications for ecommerce. You’re seeking a collaborative environment in which you can work alongside other technology experts to find the best answer and win as a team.\n\nThis position will report to the Director of Data Analytics on the Savage X Fenty Analytics Team. The position will also have an informal reporting line to the Sr. Director of Data Science on the TechStyleOS Architecture & Sciences team. We are a creative, ambitious, & fun-loving team who believes data products should be collaboratively designed, impactful to the business, and customized for the end user. Our analytics team acts as strategic partners to the business, making an impact by merging data with a deep understanding of the Savage customer experience.\n\nThis position will be based in El Segundo, California. For the right candidate, we will consider full-time remote work.\n\nWHY WORK IN DATA SCIENCE AT SAVAGE X?\n\nWork within a community of data scientists through our parent company TechStyle Fashion Group & our sister brand Fabletics, but be the first Data Scientist dedicated to the Savage X brand. This role will design the foundation for Savage’s future data science initiatives & experience fast paced growth\n\nDedicated resources to support you – Savage X is investing heavily in data science and has staffed dedicated engineering & product management to support your initiatives\n\nIndustry leading data technology stack – Snowflake, DataBricks, Segment Customer Data Platform, Apache Airflow, modeled reporting data warehouse, & more\n\nData-driven mindset is deeply foundational to the culture at Savage X; information flows freely throughout our organization and every key decision we make is backed by analysis\n\nBe a part of the larger Data Analytics organization at TechStyle Fashion Group (60+ team members); mentor & be mentored by our architects, scientists, analysts, & engineers\n\n\n\nLeverage our advanced tech stack, your knowledge of data science methods & models, and your partnerships with our senior engineers, scientists, and architects to determine the best approaches for algorithm development and implementation\n\nOwn algorithm development projects from start-to-end: design, develop, QA, deploy, experiment, and analyze\n\nPartner with dedicated product management & software engineering teams to implement data science algorithms onto our consumer-facing ecommerce website\n\nPartner with dedicated analysts to produce data visualizations, advanced reports, measurement and statistical models that explain and track algorithm performance against business KPIs\n\nPartner with the business to identify & understand opportunities for data science applications\n\nProvide thought leadership and data support to the business & other analytics team members around design, execution, and measurement of business KPIs\n\nCollaborate with other data scientists across our organization to share best practices, learn new techniques, and foster our organizational culture where data is central to decision making\n\n\n\nHigh degree of personal integrity, strong work ethic, & a desire to learn and grow in this role\n\n2+ years of work experience as a Data Scientist or Machine Learning Engineer\n\nFluent in R or Python (Python preferred) & SQL\n\nFamiliarity with Machine Learning techniques (e.g. classification, clustering, regularization, optimization, dimension reduction, feature engineering)\n\nStrong understanding of CS fundamentals (e.g. algorithms and data structures)\n\nExperience with attribution, causal inference, experimental design, and AB testing methods\n\nGood communication skills and ability to explain complex topics to a non-technical audience\n\n\n\nExperience partnering with product management & software engineering teams to implement algorithms into a production environment\n\nDegree or Advanced Degree in Statistics, Computer Science, or related fields\n\nExperience with Git and/or Airflow\n\nExperience with data visualization tools such as Tableau\n\nExperience in e-commerce, subscription models, and/or direct-to-consumer brands\n\nFamiliarity with web analytics tools & concepts (Google Analytics, pixel tracking, Segment Customer Data Platform or comparable tools)\n\n\n\nTechStyleOS is the globally integrated Operations and Services provider behind some of the fastest growing online fashion brands in history, including Fabletics, Savage X Fenty, JustFab, ShoeDazzle, and FabKids. With capabilities spanning technology, data science, supply chain management, fulfillment, customer service, and more, we help brands launch, scale and grow—across product categories and geographically. From predictive analytics to data-driven marketing and attribution, our unique approach is powered by our proprietary, end-to-end tech platform that enables the brands we serve to deliver a level of personalization, value, and satisfaction that are unrivaled in the fashion industry.\n\nSavage X Inc.is an equal opportunity employer. We recruit, employ, compensate, develop, and promote regardless of race, national origin, religion, sex, sexual orientation, gender identity, age, disability, genetic information, veteran status, and other protected status as required by applicable. At Savage X Inc. , we champion a vibrant workplace culture that thrives on diversity law and do not tolerate discrimination or harassment. We are one team from many backgrounds, innovating through diversity of individuals, who are driven by passion for creating an inclusive space for all. Savage X Inc. will continue to champion a workplace culture that prizes diversity and inclusivity.\n\nWe encourage you to apply regardless of meeting all qualifications and/or requirements.",[],[]\nWestern Governors University,Data Scientist-2,"St Louis, MO",,https://www.linkedin.com/jobs/view/2718750842/?eBP=CwEAAAF8A9ofOjpba68ujoLXQAaOCBXYiS4C1yUTdLuyzCZe9eu8Ol6E5B1OavyEuBokToqXvI8orCg9mTa7e7zpzyV9cy10rVkKoDvZEPBDm1du-SyxnPgFICjxXnkLuO4a476oKPYJHgNsT_wxWcVM7UPEe_A4rGFK3u5Nxocz6TO1M6QF-5VfM-4C6pvZ-cryEakyxdZm6GaHw7p9zbMvWyaV6i1CvmDXy27crdTMH0Tc23b0hvt7S-fanNHX4dGjk06Is5AS7iuF-deOP1A46W0iSZPaIhLkVkBxOTTw8Wp12qn_2fxTdloxilj5f3cSIkJJSt5CyCNX3COteQXhYjO8geRyhwPGFGyDICcz7CEBCngNc2CFZt-0BfY9piw&recommendedFlavor=COMPANY_RECRUIT&refId=uAGrvRCfo9q5%2BNk5EGGm4Q%3D%3D&trackingId=nI03Xvg4nBirIwj8TRNSAQ%3D%3D&trk=flagship3_search_srp_jobs,"About the job\nIf you’re passionate about building a better future for individuals, communities, and our country—and you’re committed to working hard to play your part in building that future—consider WGU as the next step in your career.\n\nDriven by a mission to expand access to higher education through online, competency-based degree programs, WGU is also committed to being a great place to work for a diverse workforce of student-focused professionals. The university has pioneered a new way to learn in the 21st century, one that has received praise from academic, industry, government, and media leaders. Whatever your role, working for WGU gives you a part to play in helping students graduate, creating a better tomorrow for themselves and their families.\n\n\n\n\n\n:\n\n\n\n\n\nAs an equal opportunity employer, WGU recognizes that our strength lies in our people. We are committed to diversity.",[],[]\nCarShield,Data Scientist,"St Louis, MO","50 minutes ago\nWithin the past 24 hours",https://www.linkedin.com/jobs/view/2723209281/?eBP=JOB_SEARCH_ORGANIC&recommendedFlavor=COMPANY_RECRUIT&refId=uAGrvRCfo9q5%2BNk5EGGm4Q%3D%3D&trackingId=KgTMJ%2FOU15u5GSRxFma6BA%3D%3D&trk=flagship3_search_srp_jobs,"About the job\nJob Description\nResponsible for overseeing the collection, storage and interpretation of data for businesses. Their duties include sifting through data points to create organized categories, comparing data points to current company processes and writing reports outlining business predictions or proposals.",[],[]\nAmerican Express Global Business Travel,Data Scientist,"Evansville, IN",6 days ago,https://www.linkedin.com/jobs/view/2716701280/?eBP=JOB_SEARCH_ORGANIC&recommendedFlavor=ACTIVELY_HIRING_COMPANY&refId=uAGrvRCfo9q5%2BNk5EGGm4Q%3D%3D&trackingId=%2FNnG2%2FT8eaQ5Auu0r1LwgQ%3D%3D&trk=flagship3_search_srp_jobs,"About the job\nThe Candidate Is Expected To Possess These Key Skills/technologies\n\nThe data science solutions engineer will be a member of the data analytics team and will lead efforts around building big data, data science, data quality, and BI/MI/AI solutions. An ideal candidate will be a The data science associate will have a growth-oriented, lean-startup mindset for building hands-on data science solutions. The ideal candidate will propose, experiment, execute, and operationalize advanced predictive, preemptive data solutions designed to help traveler, travel-manager, supplier, and client outcomes. The role will span full-scale product, enterprise, and operational data science. The candidate will focus and thrive in a hands-on applied role; he/she will demonstrate a strong penchant for quantitative, collaborative, outcome-oriented solutions-engineering.\n\n\n\n\n\n\n\nIndia>Virtual Location\n\nIt is our policy to provide equal employment opportunities to all individuals based on job-related qualifications and ability to perform a job, without regard to age, gender, gender identity, sexual orientation, race, color, religion, creed, national origin, disability, genetic information, veteran status, citizenship or marital status, and to maintain a non-discriminatory environment free from intimidation, harassment or bias based upon these grounds.\n\nPosted 6 Days Ago Full time J-46605\n\nAmerican Express Global Business Travel (GBT) is the world’s leading business partner for managed travel. We help companies and employees prosper by making sure travelers are present where and when it matters. We keep global business moving with the powerful backing of 16,000 travel professionals in more than 140 countries. Companies of all sizes, and in all places, rely on GBT to provide travel management services, organize meetings and events, and deliver business travel consulting.",[],[]\nKPMG US,"Associate, Data Scientist","Chicago, IL",,https://www.linkedin.com/jobs/view/2715182807/?eBP=CwEAAAF8A9ofOnXwJUuycM2gGRL1mcgrhKEvGOAPq7WvcuqVfhF3v31fFIUXMUZTB2_KdQBZae-zIVr4TaQH32qoMce5QiuRkyz35Qe4NunBDe1tO5oIPM_jRd0DRVV1Q2RE2NsRab1c65uetiOURFT5UacwF26coAIsRg_OLs_YoY_77ZEEy1w6kTyWThm4DdS0MF9eZsoLFRxcEZjVZPeHkjucUMmMlgDkGFolStofkAtovBw2_NeONzmFwJOWVe1GKQ1XqLioi_MqRW4kb3iJnvdR5E8PAb5PCjiNjJEfuIXO63QpyODR7y7X0dEhMCCkj_x1tLu5T0PQeNlCeZkpp7nWdyWZQtRzOXNNpH9yPYBeaNL_b3b8W8FSewL2XfI&recommendedFlavor=COMPANY_RECRUIT&refId=uAGrvRCfo9q5%2BNk5EGGm4Q%3D%3D&trackingId=tWMAG1KeTQs1iil6CAtrmQ%3D%3D&trk=flagship3_search_srp_jobs,"About the job\nRequisition Number: 70881 - 31\n\nDescription\n\nInnovate. Collaborate. Build. Create. Solve. The KPMG Digital Lighthouse is KPMG\'s award-winning Analytics & AI Center of Excellence recognized by clients and leading analyst firms in the US and globally. The KPMG Lighthouse is a curation of specialized technical capabilities and domain experts working across the digital landscape: applied data science, AI, data engineering and insights, software engineering, automation, and big data. Here, you\'ll work with a diverse team of professionals to explore and build solutions for clients in a multiplatform environment.\n\nYou\'ll be an important part of our high-energy, unique, fast-paced, and innovative culture that delivers with the agility of a tech startup and the backing of a leading global consulting firm. In this particular role, you\'ll work specifically in the AI Analytics & Engineering Community within the Digital Lighthouse, on a wide range of projects. From applied AI to optimization to big data platform engineering, your analytical and technical skills will drive real impact in the business world. At KPMG, our commitment to your career development helps to set us apart as an employer. We want to enhance your potential, both for yourself and as a contributor to our firm. That\'s why we provide every opportunity to expand your skills, knowledge and experiences through formal education and training programs, leadership development opportunities, and, as well as informal one-on-one coaching and mentoring from your KPMG colleagues.\n\nKPMG is currently seeking an Associate to join our KPMG Lighthouse - Center of Excellence for Advanced Analytics.\n\n\n\n\n\nKPMG LLP (the U.S. member firm of KPMG International) offers a comprehensive compensation and benefits package. KPMG is an affirmative action-equal opportunity employer. KPMG complies with all applicable federal, state and local laws regarding recruitment and hiring. All qualified applicants are considered for employment without regard to race, color, religion, age, sex, sexual orientation, gender identity, national origin, disability, protected veteran status, or any other category protected by applicable federal, state or local laws. The attached link contains further information regarding the firm\'s compliance with federal, state and local recruitment and hiring laws. No phone calls or agencies please.",[],[]\n"Systems Planning and Analysis, Inc.",Data Scientist - CWMD,"Reston, VA",,https://www.linkedin.com/jobs/view/2719087133/?eBP=CwEAAAF8A9ofOs3Q1pRDNomWkKq8WZKKrxzVFph6K2D4ymCmOH1h4zujhf7yBWfSjCtGRdbAe9Qx1ZFnDclUFpBrbo8MAanx6IoSd6oeFzDujMeur4dsRn-KObiuVvRuoE8jax4zNaj2cL0qgNswrocbKDKdYn82E7vixG1bp6oL35Xs1t4QTILoMHsFU_wTZqMgC7fCMPF3UzzYVoZ7UpLI2jutAFhJUtKKFD94vE5WkDbZOlxsnkXaN96-uctzECAJaz-JWJTbMRDHUek1yOdijC16J7HeR8V1Snd1B3f-lHcwkIyohdLJUUsi0dDpOWpoQNpv7XWOgAXT-NzCdHsRY99xfHcFFJK5r9UEJvFy__j3f60gUpWxie9aT8NO&recommendedFlavor=ACTIVELY_HIRING_COMPANY&refId=uAGrvRCfo9q5%2BNk5EGGm4Q%3D%3D&trackingId=sCAmjQEN8DY8a6u7bP7Yfg%3D%3D&trk=flagship3_search_srp_jobs,"About the job\nOverview\n\nSystems Planning and Analysis, Inc. (SPA) is a well-established and progressive defense contracting company in the DC Metro area. We are a professional services firm established in 1972 that has a long-standing reputation for unrivaled technical and analytical support to some of the top decision makers in the Federal Sector. We do state of the art work and have a cadre of outstanding professionals on our team.\n\nSPA assists the Defense Threat Reduction Agency (DTRA) in developing leading edge technologies to counter WMD in support of CCMDs and transitioning these technologies to services and SOCOM. SPA provides expertise across the full range of chemical, biological, radiological, nuclear and high-yield explosives (CBRNE) WMD, Counter Improvised Threat and Countering Threat Network technologies to support understanding, detection, identification, characterization, denial, control, disabling, defeating, disposing, safeguarding the force, managing consequences, and test and evaluation in support of military and civilian operations. #CJ #IN123\n\n\n\nProvides critical decision and analytic support to the Urgent Solutions Division in the Counter WMD Technologies Department of the Defense Threat Reduction Agency (DTRA). Conducts assessments, demonstrations, analysis, scientific codes, and other decision making in evaluating systems to counter WMD – biological and chemical threats, and counter threat networks. Develops knowledge regarding a stipulated issue through analysis of complex data sets, identifying actionable trends and problems. Uses appropriate methods to creatively explore, mine, analyze and manipulate data sets ranging in size from sparse to petabytes and type (e.g. small number of .pdf text reports, Excel spreadsheets and .csv files to repositories of image or audio data). Interprets results from multiple sources using a variety of techniques, ranging from simple data aggregation via statistical analysis to complex data mining, sensor analysis and learning techniques. Designs, develops, and implements technical solutions in support of concurrent analysis. Supports data models and defines the structure, attributes, and nomenclature of data elements. May evaluate new data sources for adherence to the organization\'s quality standards and ease of integration.",[],[]\nPerficient,Data Scientist,"St Louis, MO",,https://www.linkedin.com/jobs/view/2718055481/?eBP=CwEAAAF8A9ofOhOHpkH95U2fvN9F-goU76IrWGZ2_h1PEIqUbFxqxI6w3ypUfMSWfMRpTGEJDX9iicxg3Is1hE7MJg4ixQ2ZJfmdAFAR38WMuWQ9RdnHIEX4XrSbapYsM3nhi6Iyv6rH9MEC1PpEqmZkvr8JBlfU1asVfgP3pl3rW4IS6tIVJuzERferAoB3ycE-UB94AE92MTfUPPOUagL-zhuIsIcyQ6BMfE6eFGYpZpAHbvdti7-s852GjLAxYFovRGVyerfbSKSeZm6fVVXT2EaQfKYvMN5hBZBBVncwxNfzaaMBbKZ9moxmBg76BZ3UfB6YOntWLvvf06jI4VVqLMZ_BYq4iT8Jnp-YKt2dJxnECW-9zW66IbRoeRPT&recommendedFlavor=COMPANY_RECRUIT&refId=uAGrvRCfo9q5%2BNk5EGGm4Q%3D%3D&trackingId=UE7bblhxeqWJV52%2F9JWJew%3D%3D&trk=flagship3_search_srp_jobs,"About the job\nOverview\n\nAt Perficient you’ll deliver mission-critical technology and business solutions to Fortune 500 companies and some of the most recognized brands on the planet. And you’ll do it with cutting-edge technologies, thanks to our close partnerships with the world’s biggest vendors. Our network of offices across North America, as well as locations in India and China, will give you the opportunity to spread your wings, too.\n\nWe’re proud to be publicly recognized as a “Top Workplace” year after year. This is due, in no small part, to our entrepreneurial attitude and collaborative spirit that sets us apart and keeps our colleagues impassioned, driven, and fulfilled.\n\nPerficient currently has a career opportunity for a .\n\n\n\nThe role of the Data Scientist is for individuals passionate about identifying and delivering the right Business solution for each client using AI/ML. Our Data Scientists are keen to understand our customer needs, processes and pain points to determine the success factors and evaluation criteria that will needed to measure the effectiveness of an ML model.\n\nThe Data Scientist will be involved in the strategic planning of an engagement or helping the client make decisions about their future AI/ML roadmap and vision. Once the project as begun, the Data Scientist will be responsible for the execution of our established methodology, work with customer and/or the teams data engineer to identify data ingestion and transformation needs, exploration of the data and reporting findings, modeling and evaluation of training iterations. It is a key part of the role to be able to explain in non-technical terms the chosen modeling approach and findings from data exploration or training results.\n\nThe Data Scientist will work with Senior Project Managers to assist with daily operations exercising time management, communication and collaboration in a fast-paced environment to ensure the successful delivery of projects. The Data Scientist will interface with Perficient technical and business delivery personnel, as well as vendors and customers on a regular basis. May mentor junior data scientists.\n\n\n\n\n\n\n\nPerficient full-time employees receive complete and competitive benefits. We offer a collaborative work environment, competitive compensation, generous work/life opportunities and an outstanding benefits package that includes paid time off plus holidays. In addition, all colleagues are eligible for a number of rewards and recognition programs including billable bonus opportunities. Encouraging a healthy work/life balance and providing our colleagues great benefits are just part of what makes Perficient a great place to work.\n\n\n\nPerficient is the leading digital transformation consulting firm serving Global 2000 and enterprise customers throughout North America. With unparalleled information technology, management consulting and creative capabilities, Perficient and its Perficient Digital agency deliver vision, execution and value with outstanding digital experience, business optimization and industry solutions.\n\nOur work enables clients to improve productivity and competitiveness; grow and strengthen relationships with customers, suppliers and partners; and reduce costs. Perficient\'s professionals serve clients from a network of offices across North America and offshore locations in India and China. Traded on the Nasdaq Global Select Market, Perficient is a member of the Russell 2000 index and the S&P SmallCap 600 index.\n\nPerficient is an equal opportunity employer and all qualified applicants will receive consideration for employment without regard to race, color, religion, sex, national, origin, disability status, protected veteran status, or any other characteristic protected by law.\n\nThe above statements are not intended to be a complete statement of job content, rather to act as a guide to the essential functions performed by the employee assigned to this classification. Management retains the discretion to add or change the duties of the position at any time.\n\nSelect work authorization questions to ask when applicants apply",[],[]\nSavage X Fenty: Lingerie by Rihanna,Data Scientist,"El Segundo, CA",,https://www.linkedin.com/jobs/view/2721710042/?eBP=CwEAAAF8A9ofOhPzbWsStxaNEgpMLIbvO6Vvpf-kp8RGwvYOJKGphyyakdc_4SGsjm2VeRAGjmk-vJ6l9A5H_dap2I3Kpoi5h6gKOdZGPr43fehHk5BqkiDkbvKki_to05FvWLinOBzurpjsMFG3JoeqUJ8xRReTFcidZnHYUQE6jUxh0nf-LNmAPuQp7YZEmPEps45wTFpgh1xQa_nwnLky1x-nzte_8YwEIsmHKQ5z2VTOvDevWj_NNLxyfvp4hDKsNbBNyQC_28gSNPkqkg6iN2yFOum-URpP05X-BwoG-gN9HPsuQJs-bhqDslt8i6wwag517FTdUMMYWqa29zUtuHYFUf1ei5iEh0ffOBNdGGDafvdOB4z8Oqp3hxLnHhY&recommendedFlavor=ACTIVELY_HIRING_COMPANY&refId=uAGrvRCfo9q5%2BNk5EGGm4Q%3D%3D&trackingId=WJuu5WmPKTuvZRyUdmNdtA%3D%3D&trk=flagship3_search_srp_jobs,"About the job\nJob DescriptionSavage X Fenty is looking for a Data Scientist. Co-founded by music and fashion icon Rihanna, Savage X Fenty is the first line of lingerie that celebrates and speaks to all shades and shapes of people, and celebrates fearlessness, confidence and inclusivity.\n\nHOW DO YOU FIT IN?\n\nAs the Data Scientist, you will drive innovation in our customer shopping experience by providing the algorithms that power recommendation and personalization features across our ecommerce website. You will collaborate closely with the Data Analytics organization, the Global Technology organization, and the Savage X business to develop high-impact solutions to key optimization opportunities such as ecommerce conversion & product discovery. You will watch your work come to life by partnering with dedicated product & software engineering teams to deploy your algorithms into production.\n\nProjects you are likely to own in this role include:\n\nProduct Recommendation Algorithms (e.g., product discovery & upsell algorithms)\n\nFull Funnel Customer Segmentation (e.g., algorithmically define customer segments and stream segments to other tools such as our CRM or ad networks)\n\nInternal Optimization Algorithms (e.g., attribution models, sales propensity algorithms)\n\nAt Savage X Fenty you can expect to use Python and SQL every day. For larger projects requiring scale or automation you’ll likely be working with DataBricks and Airflow. While these are our defaults, you will have the flexibility to use tools that allow you to best fulfill your role. Additionally, we strongly believe in the need for ongoing education and so will encourage you to explore new technologies and modeling methods on a regular basis.\n\n\n\nYou’re the ideal candidate if you’re incredibly curious & see opportunities for data science applications in everything you do. Working smarter, not harder, is core to your DNA. You’re invigorated by the opportunity to learn that next tool or skill, and you come up with clever solutions to difficult problems. As much as you learned in school or at work, you’ve probably learned even more during your late-night hacking sessions. You take initiative, can work without supervision, begin projects independently, and are technically capable with a deep desire to become an expert in data science applications for ecommerce. You’re seeking a collaborative environment in which you can work alongside other technology experts to find the best answer and win as a team.\n\nThis position will report to the Director of Data Analytics on the Savage X Fenty Analytics Team. The position will also have an informal reporting line to the Sr. Director of Data Science on the TechStyleOS Architecture & Sciences team. We are a creative, ambitious, & fun-loving team who believes data products should be collaboratively designed, impactful to the business, and customized for the end user. Our analytics team acts as strategic partners to the business, making an impact by merging data with a deep understanding of the Savage customer experience.\n\nThis position will be based in El Segundo, California. For the right candidate, we will consider full-time remote work.\n\nWHY WORK IN DATA SCIENCE AT SAVAGE X?\n\nWork within a community of data scientists through our parent company TechStyle Fashion Group & our sister brand Fabletics, but be the first Data Scientist dedicated to the Savage X brand. This role will design the foundation for Savage’s future data science initiatives & experience fast paced growth\n\nDedicated resources to support you – Savage X is investing heavily in data science and has staffed dedicated engineering & product management to support your initiatives\n\nIndustry leading data technology stack – Snowflake, DataBricks, Segment Customer Data Platform, Apache Airflow, modeled reporting data warehouse, & more\n\nData-driven mindset is deeply foundational to the culture at Savage X; information flows freely throughout our organization and every key decision we make is backed by analysis\n\nBe a part of the larger Data Analytics organization at TechStyle Fashion Group (60+ team members); mentor & be mentored by our architects, scientists, analysts, & engineers\n\n\n\nLeverage our advanced tech stack, your knowledge of data science methods & models, and your partnerships with our senior engineers, scientists, and architects to determine the best approaches for algorithm development and implementation\n\nOwn algorithm development projects from start-to-end: design, develop, QA, deploy, experiment, and analyze\n\nPartner with dedicated product management & software engineering teams to implement data science algorithms onto our consumer-facing ecommerce website\n\nPartner with dedicated analysts to produce data visualizations, advanced reports, measurement and statistical models that explain and track algorithm performance against business KPIs\n\nPartner with the business to identify & understand opportunities for data science applications\n\nProvide thought leadership and data support to the business & other analytics team members around design, execution, and measurement of business KPIs\n\nCollaborate with other data scientists across our organization to share best practices, learn new techniques, and foster our organizational culture where data is central to decision making\n\n\n\nHigh degree of personal integrity, strong work ethic, & a desire to learn and grow in this role\n\n2+ years of work experience as a Data Scientist or Machine Learning Engineer\n\nFluent in R or Python (Python preferred) & SQL\n\nFamiliarity with Machine Learning techniques (e.g. classification, clustering, regularization, optimization, dimension reduction, feature engineering)\n\nStrong understanding of CS fundamentals (e.g. algorithms and data structures)\n\nExperience with attribution, causal inference, experimental design, and AB testing methods\n\nGood communication skills and ability to explain complex topics to a non-technical audience\n\n\n\nExperience partnering with product management & software engineering teams to implement algorithms into a production environment\n\nDegree or Advanced Degree in Statistics, Computer Science, or related fields\n\nExperience with Git and/or Airflow\n\nExperience with data visualization tools such as Tableau\n\nExperience in e-commerce, subscription models, and/or direct-to-consumer brands\n\nFamiliarity with web analytics tools & concepts (Google Analytics, pixel tracking, Segment Customer Data Platform or comparable tools)\n\n\n\nTechStyleOS is the globally integrated Operations and Services provider behind some of the fastest growing online fashion brands in history, including Fabletics, Savage X Fenty, JustFab, ShoeDazzle, and FabKids. With capabilities spanning technology, data science, supply chain management, fulfillment, customer service, and more, we help brands launch, scale and grow—across product categories and geographically. From predictive analytics to data-driven marketing and attribution, our unique approach is powered by our proprietary, end-to-end tech platform that enables the brands we serve to deliver a level of personalization, value, and satisfaction that are unrivaled in the fashion industry.\n\nSavage X Inc.is an equal opportunity employer. We recruit, employ, compensate, develop, and promote regardless of race, national origin, religion, sex, sexual orientation, gender identity, age, disability, genetic information, veteran status, and other protected status as required by applicable. At Savage X Inc. , we champion a vibrant workplace culture that thrives on diversity law and do not tolerate discrimination or harassment. We are one team from many backgrounds, innovating through diversity of individuals, who are driven by passion for creating an inclusive space for all. Savage X Inc. will continue to champion a workplace culture that prizes diversity and inclusivity.\n\nWe encourage you to apply regardless of meeting all qualifications and/or requirements.",[],[]\nWestern Governors University,Data Scientist-2,"St Louis, MO",,https://www.linkedin.com/jobs/view/2718750842/?eBP=CwEAAAF8A9ofOjpba68ujoLXQAaOCBXYiS4C1yUTdLuyzCZe9eu8Ol6E5B1OavyEuBokToqXvI8orCg9mTa7e7zpzyV9cy10rVkKoDvZEPBDm1du-SyxnPgFICjxXnkLuO4a476oKPYJHgNsT_wxWcVM7UPEe_A4rGFK3u5Nxocz6TO1M6QF-5VfM-4C6pvZ-cryEakyxdZm6GaHw7p9zbMvWyaV6i1CvmDXy27crdTMH0Tc23b0hvt7S-fanNHX4dGjk06Is5AS7iuF-deOP1A46W0iSZPaIhLkVkBxOTTw8Wp12qn_2fxTdloxilj5f3cSIkJJSt5CyCNX3COteQXhYjO8geRyhwPGFGyDICcz7CEBCngNc2CFZt-0BfY9piw&recommendedFlavor=COMPANY_RECRUIT&refId=uAGrvRCfo9q5%2BNk5EGGm4Q%3D%3D&trackingId=nI03Xvg4nBirIwj8TRNSAQ%3D%3D&trk=flagship3_search_srp_jobs,"About the job\nIf you’re passionate about building a better future for individuals, communities, and our country—and you’re committed to working hard to play your part in building that future—consider WGU as the next step in your career.\n\nDriven by a mission to expand access to higher education through online, competency-based degree programs, WGU is also committed to being a great place to work for a diverse workforce of student-focused professionals. The university has pioneered a new way to learn in the 21st century, one that has received praise from academic, industry, government, and media leaders. Whatever your role, working for WGU gives you a part to play in helping students graduate, creating a better tomorrow for themselves and their families.\n\n\n\n\n\n:\n\n\n\n\n\nAs an equal opportunity employer, WGU recognizes that our strength lies in our people. We are committed to diversity.",[],[]\nCarShield,Data Scientist,"St Louis, MO","50 minutes ago\nWithin the past 24 hours",https://www.linkedin.com/jobs/view/2723209281/?eBP=JOB_SEARCH_ORGANIC&recommendedFlavor=COMPANY_RECRUIT&refId=uAGrvRCfo9q5%2BNk5EGGm4Q%3D%3D&trackingId=KgTMJ%2FOU15u5GSRxFma6BA%3D%3D&trk=flagship3_search_srp_jobs,"About the job\nJob Description\nResponsible for overseeing the collection, storage and interpretation of data for businesses. Their duties include sifting through data points to create organized categories, comparing data points to current company processes and writing reports outlining business predictions or proposals.",[],[]\nAmerican Express Global Business Travel,Data Scientist,"Evansville, IN",6 days ago,https://www.linkedin.com/jobs/view/2716701280/?eBP=JOB_SEARCH_ORGANIC&recommendedFlavor=ACTIVELY_HIRING_COMPANY&refId=uAGrvRCfo9q5%2BNk5EGGm4Q%3D%3D&trackingId=%2FNnG2%2FT8eaQ5Auu0r1LwgQ%3D%3D&trk=flagship3_search_srp_jobs,"About the job\nThe Candidate Is Expected To Possess These Key Skills/technologies\n\nThe data science solutions engineer will be a member of the data analytics team and will lead efforts around building big data, data science, data quality, and BI/MI/AI solutions. An ideal candidate will be a The data science associate will have a growth-oriented, lean-startup mindset for building hands-on data science solutions. The ideal candidate will propose, experiment, execute, and operationalize advanced predictive, preemptive data solutions designed to help traveler, travel-manager, supplier, and client outcomes. The role will span full-scale product, enterprise, and operational data science. The candidate will focus and thrive in a hands-on applied role; he/she will demonstrate a strong penchant for quantitative, collaborative, outcome-oriented solutions-engineering.\n\n\n\n\n\n\n\nIndia>Virtual Location\n\nIt is our policy to provide equal employment opportunities to all individuals based on job-related qualifications and ability to perform a job, without regard to age, gender, gender identity, sexual orientation, race, color, religion, creed, national origin, disability, genetic information, veteran status, citizenship or marital status, and to maintain a non-discriminatory environment free from intimidation, harassment or bias based upon these grounds.\n\nPosted 6 Days Ago Full time J-46605\n\nAmerican Express Global Business Travel (GBT) is the world’s leading business partner for managed travel. We help companies and employees prosper by making sure travelers are present where and when it matters. We keep global business moving with the powerful backing of 16,000 travel professionals in more than 140 countries. Companies of all sizes, and in all places, rely on GBT to provide travel management services, organize meetings and events, and deliver business travel consulting.",[],[]\nKPMG US,"Associate, Data Scientist","Chicago, IL",,https://www.linkedin.com/jobs/view/2715182807/?eBP=CwEAAAF8A9ofOnXwJUuycM2gGRL1mcgrhKEvGOAPq7WvcuqVfhF3v31fFIUXMUZTB2_KdQBZae-zIVr4TaQH32qoMce5QiuRkyz35Qe4NunBDe1tO5oIPM_jRd0DRVV1Q2RE2NsRab1c65uetiOURFT5UacwF26coAIsRg_OLs_YoY_77ZEEy1w6kTyWThm4DdS0MF9eZsoLFRxcEZjVZPeHkjucUMmMlgDkGFolStofkAtovBw2_NeONzmFwJOWVe1GKQ1XqLioi_MqRW4kb3iJnvdR5E8PAb5PCjiNjJEfuIXO63QpyODR7y7X0dEhMCCkj_x1tLu5T0PQeNlCeZkpp7nWdyWZQtRzOXNNpH9yPYBeaNL_b3b8W8FSewL2XfI&recommendedFlavor=COMPANY_RECRUIT&refId=uAGrvRCfo9q5%2BNk5EGGm4Q%3D%3D&trackingId=tWMAG1KeTQs1iil6CAtrmQ%3D%3D&trk=flagship3_search_srp_jobs,"About the job\nRequisition Number: 70881 - 31\n\nDescription\n\nInnovate. Collaborate. Build. Create. Solve. The KPMG Digital Lighthouse is KPMG\'s award-winning Analytics & AI Center of Excellence recognized by clients and leading analyst firms in the US and globally. The KPMG Lighthouse is a curation of specialized technical capabilities and domain experts working across the digital landscape: applied data science, AI, data engineering and insights, software engineering, automation, and big data. Here, you\'ll work with a diverse team of professionals to explore and build solutions for clients in a multiplatform environment.\n\nYou\'ll be an important part of our high-energy, unique, fast-paced, and innovative culture that delivers with the agility of a tech startup and the backing of a leading global consulting firm. In this particular role, you\'ll work specifically in the AI Analytics & Engineering Community within the Digital Lighthouse, on a wide range of projects. From applied AI to optimization to big data platform engineering, your analytical and technical skills will drive real impact in the business world. At KPMG, our commitment to your career development helps to set us apart as an employer. We want to enhance your potential, both for yourself and as a contributor to our firm. That\'s why we provide every opportunity to expand your skills, knowledge and experiences through formal education and training programs, leadership development opportunities, and, as well as informal one-on-one coaching and mentoring from your KPMG colleagues.\n\nKPMG is currently seeking an Associate to join our KPMG Lighthouse - Center of Excellence for Advanced Analytics.\n\n\n\n\n\nKPMG LLP (the U.S. member firm of KPMG International) offers a comprehensive compensation and benefits package. KPMG is an affirmative action-equal opportunity employer. KPMG complies with all applicable federal, state and local laws regarding recruitment and hiring. All qualified applicants are considered for employment without regard to race, color, religion, age, sex, sexual orientation, gender identity, national origin, disability, protected veteran status, or any other category protected by applicable federal, state or local laws. The attached link contains further information regarding the firm\'s compliance with federal, state and local recruitment and hiring laws. No phone calls or agencies please.",[],[]\n"Systems Planning and Analysis, Inc.",Data Scientist - CWMD,"Reston, VA",,https://www.linkedin.com/jobs/view/2719087133/?eBP=CwEAAAF8A9ofOs3Q1pRDNomWkKq8WZKKrxzVFph6K2D4ymCmOH1h4zujhf7yBWfSjCtGRdbAe9Qx1ZFnDclUFpBrbo8MAanx6IoSd6oeFzDujMeur4dsRn-KObiuVvRuoE8jax4zNaj2cL0qgNswrocbKDKdYn82E7vixG1bp6oL35Xs1t4QTILoMHsFU_wTZqMgC7fCMPF3UzzYVoZ7UpLI2jutAFhJUtKKFD94vE5WkDbZOlxsnkXaN96-uctzECAJaz-JWJTbMRDHUek1yOdijC16J7HeR8V1Snd1B3f-lHcwkIyohdLJUUsi0dDpOWpoQNpv7XWOgAXT-NzCdHsRY99xfHcFFJK5r9UEJvFy__j3f60gUpWxie9aT8NO&recommendedFlavor=ACTIVELY_HIRING_COMPANY&refId=uAGrvRCfo9q5%2BNk5EGGm4Q%3D%3D&trackingId=sCAmjQEN8DY8a6u7bP7Yfg%3D%3D&trk=flagship3_search_srp_jobs,"About the job\nOverview\n\nSystems Planning and Analysis, Inc. (SPA) is a well-established and progressive defense contracting company in the DC Metro area. We are a professional services firm established in 1972 that has a long-standing reputation for unrivaled technical and analytical support to some of the top decision makers in the Federal Sector. We do state of the art work and have a cadre of outstanding professionals on our team.\n\nSPA assists the Defense Threat Reduction Agency (DTRA) in developing leading edge technologies to counter WMD in support of CCMDs and transitioning these technologies to services and SOCOM. SPA provides expertise across the full range of chemical, biological, radiological, nuclear and high-yield explosives (CBRNE) WMD, Counter Improvised Threat and Countering Threat Network technologies to support understanding, detection, identification, characterization, denial, control, disabling, defeating, disposing, safeguarding the force, managing consequences, and test and evaluation in support of military and civilian operations. #CJ #IN123\n\n\n\nProvides critical decision and analytic support to the Urgent Solutions Division in the Counter WMD Technologies Department of the Defense Threat Reduction Agency (DTRA). Conducts assessments, demonstrations, analysis, scientific codes, and other decision making in evaluating systems to counter WMD – biological and chemical threats, and counter threat networks. Develops knowledge regarding a stipulated issue through analysis of complex data sets, identifying actionable trends and problems. Uses appropriate methods to creatively explore, mine, analyze and manipulate data sets ranging in size from sparse to petabytes and type (e.g. small number of .pdf text reports, Excel spreadsheets and .csv files to repositories of image or audio data). Interprets results from multiple sources using a variety of techniques, ranging from simple data aggregation via statistical analysis to complex data mining, sensor analysis and learning techniques. Designs, develops, and implements technical solutions in support of concurrent analysis. Supports data models and defines the structure, attributes, and nomenclature of data elements. May evaluate new data sources for adherence to the organization\'s quality standards and ease of integration.",[],[]\nPerficient,Data Scientist,"St Louis, MO",,https://www.linkedin.com/jobs/view/2718055481/?eBP=CwEAAAF8A9ofOhOHpkH95U2fvN9F-goU76IrWGZ2_h1PEIqUbFxqxI6w3ypUfMSWfMRpTGEJDX9iicxg3Is1hE7MJg4ixQ2ZJfmdAFAR38WMuWQ9RdnHIEX4XrSbapYsM3nhi6Iyv6rH9MEC1PpEqmZkvr8JBlfU1asVfgP3pl3rW4IS6tIVJuzERferAoB3ycE-UB94AE92MTfUPPOUagL-zhuIsIcyQ6BMfE6eFGYpZpAHbvdti7-s852GjLAxYFovRGVyerfbSKSeZm6fVVXT2EaQfKYvMN5hBZBBVncwxNfzaaMBbKZ9moxmBg76BZ3UfB6YOntWLvvf06jI4VVqLMZ_BYq4iT8Jnp-YKt2dJxnECW-9zW66IbRoeRPT&recommendedFlavor=COMPANY_RECRUIT&refId=uAGrvRCfo9q5%2BNk5EGGm4Q%3D%3D&trackingId=UE7bblhxeqWJV52%2F9JWJew%3D%3D&trk=flagship3_search_srp_jobs,"About the job\nOverview\n\nAt Perficient you’ll deliver mission-critical technology and business solutions to Fortune 500 companies and some of the most recognized brands on the planet. And you’ll do it with cutting-edge technologies, thanks to our close partnerships with the world’s biggest vendors. Our network of offices across North America, as well as locations in India and China, will give you the opportunity to spread your wings, too.\n\nWe’re proud to be publicly recognized as a “Top Workplace” year after year. This is due, in no small part, to our entrepreneurial attitude and collaborative spirit that sets us apart and keeps our colleagues impassioned, driven, and fulfilled.\n\nPerficient currently has a career opportunity for a .\n\n\n\nThe role of the Data Scientist is for individuals passionate about identifying and delivering the right Business solution for each client using AI/ML. Our Data Scientists are keen to understand our customer needs, processes and pain points to determine the success factors and evaluation criteria that will needed to measure the effectiveness of an ML model.\n\nThe Data Scientist will be involved in the strategic planning of an engagement or helping the client make decisions about their future AI/ML roadmap and vision. Once the project as begun, the Data Scientist will be responsible for the execution of our established methodology, work with customer and/or the teams data engineer to identify data ingestion and transformation needs, exploration of the data and reporting findings, modeling and evaluation of training iterations. It is a key part of the role to be able to explain in non-technical terms the chosen modeling approach and findings from data exploration or training results.\n\nThe Data Scientist will work with Senior Project Managers to assist with daily operations exercising time management, communication and collaboration in a fast-paced environment to ensure the successful delivery of projects. The Data Scientist will interface with Perficient technical and business delivery personnel, as well as vendors and customers on a regular basis. May mentor junior data scientists.\n\n\n\n\n\n\n\nPerficient full-time employees receive complete and competitive benefits. We offer a collaborative work environment, competitive compensation, generous work/life opportunities and an outstanding benefits package that includes paid time off plus holidays. In addition, all colleagues are eligible for a number of rewards and recognition programs including billable bonus opportunities. Encouraging a healthy work/life balance and providing our colleagues great benefits are just part of what makes Perficient a great place to work.\n\n\n\nPerficient is the leading digital transformation consulting firm serving Global 2000 and enterprise customers throughout North America. With unparalleled information technology, management consulting and creative capabilities, Perficient and its Perficient Digital agency deliver vision, execution and value with outstanding digital experience, business optimization and industry solutions.\n\nOur work enables clients to improve productivity and competitiveness; grow and strengthen relationships with customers, suppliers and partners; and reduce costs. Perficient\'s professionals serve clients from a network of offices across North America and offshore locations in India and China. Traded on the Nasdaq Global Select Market, Perficient is a member of the Russell 2000 index and the S&P SmallCap 600 index.\n\nPerficient is an equal opportunity employer and all qualified applicants will receive consideration for employment without regard to race, color, religion, sex, national, origin, disability status, protected veteran status, or any other characteristic protected by law.\n\nThe above statements are not intended to be a complete statement of job content, rather to act as a guide to the essential functions performed by the employee assigned to this classification. Management retains the discretion to add or change the duties of the position at any time.\n\nSelect work authorization questions to ask when applicants apply",[],[]\nSavage X Fenty: Lingerie by Rihanna,Data Scientist,"El Segundo, CA",,https://www.linkedin.com/jobs/view/2721710042/?eBP=CwEAAAF8A9ofOhPzbWsStxaNEgpMLIbvO6Vvpf-kp8RGwvYOJKGphyyakdc_4SGsjm2VeRAGjmk-vJ6l9A5H_dap2I3Kpoi5h6gKOdZGPr43fehHk5BqkiDkbvKki_to05FvWLinOBzurpjsMFG3JoeqUJ8xRReTFcidZnHYUQE6jUxh0nf-LNmAPuQp7YZEmPEps45wTFpgh1xQa_nwnLky1x-nzte_8YwEIsmHKQ5z2VTOvDevWj_NNLxyfvp4hDKsNbBNyQC_28gSNPkqkg6iN2yFOum-URpP05X-BwoG-gN9HPsuQJs-bhqDslt8i6wwag517FTdUMMYWqa29zUtuHYFUf1ei5iEh0ffOBNdGGDafvdOB4z8Oqp3hxLnHhY&recommendedFlavor=ACTIVELY_HIRING_COMPANY&refId=uAGrvRCfo9q5%2BNk5EGGm4Q%3D%3D&trackingId=WJuu5WmPKTuvZRyUdmNdtA%3D%3D&trk=flagship3_search_srp_jobs,"About the job\nJob DescriptionSavage X Fenty is looking for a Data Scientist. Co-founded by music and fashion icon Rihanna, Savage X Fenty is the first line of lingerie that celebrates and speaks to all shades and shapes of people, and celebrates fearlessness, confidence and inclusivity.\n\nHOW DO YOU FIT IN?\n\nAs the Data Scientist, you will drive innovation in our customer shopping experience by providing the algorithms that power recommendation and personalization features across our ecommerce website. You will collaborate closely with the Data Analytics organization, the Global Technology organization, and the Savage X business to develop high-impact solutions to key optimization opportunities such as ecommerce conversion & product discovery. You will watch your work come to life by partnering with dedicated product & software engineering teams to deploy your algorithms into production.\n\nProjects you are likely to own in this role include:\n\nProduct Recommendation Algorithms (e.g., product discovery & upsell algorithms)\n\nFull Funnel Customer Segmentation (e.g., algorithmically define customer segments and stream segments to other tools such as our CRM or ad networks)\n\nInternal Optimization Algorithms (e.g., attribution models, sales propensity algorithms)\n\nAt Savage X Fenty you can expect to use Python and SQL every day. For larger projects requiring scale or automation you’ll likely be working with DataBricks and Airflow. While these are our defaults, you will have the flexibility to use tools that allow you to best fulfill your role. Additionally, we strongly believe in the need for ongoing education and so will encourage you to explore new technologies and modeling methods on a regular basis.\n\n\n\nYou’re the ideal candidate if you’re incredibly curious & see opportunities for data science applications in everything you do. Working smarter, not harder, is core to your DNA. You’re invigorated by the opportunity to learn that next tool or skill, and you come up with clever solutions to difficult problems. As much as you learned in school or at work, you’ve probably learned even more during your late-night hacking sessions. You take initiative, can work without supervision, begin projects independently, and are technically capable with a deep desire to become an expert in data science applications for ecommerce. You’re seeking a collaborative environment in which you can work alongside other technology experts to find the best answer and win as a team.\n\nThis position will report to the Director of Data Analytics on the Savage X Fenty Analytics Team. The position will also have an informal reporting line to the Sr. Director of Data Science on the TechStyleOS Architecture & Sciences team. We are a creative, ambitious, & fun-loving team who believes data products should be collaboratively designed, impactful to the business, and customized for the end user. Our analytics team acts as strategic partners to the business, making an impact by merging data with a deep understanding of the Savage customer experience.\n\nThis position will be based in El Segundo, California. For the right candidate, we will consider full-time remote work.\n\nWHY WORK IN DATA SCIENCE AT SAVAGE X?\n\nWork within a community of data scientists through our parent company TechStyle Fashion Group & our sister brand Fabletics, but be the first Data Scientist dedicated to the Savage X brand. This role will design the foundation for Savage’s future data science initiatives & experience fast paced growth\n\nDedicated resources to support you – Savage X is investing heavily in data science and has staffed dedicated engineering & product management to support your initiatives\n\nIndustry leading data technology stack – Snowflake, DataBricks, Segment Customer Data Platform, Apache Airflow, modeled reporting data warehouse, & more\n\nData-driven mindset is deeply foundational to the culture at Savage X; information flows freely throughout our organization and every key decision we make is backed by analysis\n\nBe a part of the larger Data Analytics organization at TechStyle Fashion Group (60+ team members); mentor & be mentored by our architects, scientists, analysts, & engineers\n\n\n\nLeverage our advanced tech stack, your knowledge of data science methods & models, and your partnerships with our senior engineers, scientists, and architects to determine the best approaches for algorithm development and implementation\n\nOwn algorithm development projects from start-to-end: design, develop, QA, deploy, experiment, and analyze\n\nPartner with dedicated product management & software engineering teams to implement data science algorithms onto our consumer-facing ecommerce website\n\nPartner with dedicated analysts to produce data visualizations, advanced reports, measurement and statistical models that explain and track algorithm performance against business KPIs\n\nPartner with the business to identify & understand opportunities for data science applications\n\nProvide thought leadership and data support to the business & other analytics team members around design, execution, and measurement of business KPIs\n\nCollaborate with other data scientists across our organization to share best practices, learn new techniques, and foster our organizational culture where data is central to decision making\n\n\n\nHigh degree of personal integrity, strong work ethic, & a desire to learn and grow in this role\n\n2+ years of work experience as a Data Scientist or Machine Learning Engineer\n\nFluent in R or Python (Python preferred) & SQL\n\nFamiliarity with Machine Learning techniques (e.g. classification, clustering, regularization, optimization, dimension reduction, feature engineering)\n\nStrong understanding of CS fundamentals (e.g. algorithms and data structures)\n\nExperience with attribution, causal inference, experimental design, and AB testing methods\n\nGood communication skills and ability to explain complex topics to a non-technical audience\n\n\n\nExperience partnering with product management & software engineering teams to implement algorithms into a production environment\n\nDegree or Advanced Degree in Statistics, Computer Science, or related fields\n\nExperience with Git and/or Airflow\n\nExperience with data visualization tools such as Tableau\n\nExperience in e-commerce, subscription models, and/or direct-to-consumer brands\n\nFamiliarity with web analytics tools & concepts (Google Analytics, pixel tracking, Segment Customer Data Platform or comparable tools)\n\n\n\nTechStyleOS is the globally integrated Operations and Services provider behind some of the fastest growing online fashion brands in history, including Fabletics, Savage X Fenty, JustFab, ShoeDazzle, and FabKids. With capabilities spanning technology, data science, supply chain management, fulfillment, customer service, and more, we help brands launch, scale and grow—across product categories and geographically. From predictive analytics to data-driven marketing and attribution, our unique approach is powered by our proprietary, end-to-end tech platform that enables the brands we serve to deliver a level of personalization, value, and satisfaction that are unrivaled in the fashion industry.\n\nSavage X Inc.is an equal opportunity employer. We recruit, employ, compensate, develop, and promote regardless of race, national origin, religion, sex, sexual orientation, gender identity, age, disability, genetic information, veteran status, and other protected status as required by applicable. At Savage X Inc. , we champion a vibrant workplace culture that thrives on diversity law and do not tolerate discrimination or harassment. We are one team from many backgrounds, innovating through diversity of individuals, who are driven by passion for creating an inclusive space for all. Savage X Inc. will continue to champion a workplace culture that prizes diversity and inclusivity.\n\nWe encourage you to apply regardless of meeting all qualifications and/or requirements.",[],[]\nWestern Governors University,Data Scientist-2,"St Louis, MO",,https://www.linkedin.com/jobs/view/2718750842/?eBP=CwEAAAF8A9ofOjpba68ujoLXQAaOCBXYiS4C1yUTdLuyzCZe9eu8Ol6E5B1OavyEuBokToqXvI8orCg9mTa7e7zpzyV9cy10rVkKoDvZEPBDm1du-SyxnPgFICjxXnkLuO4a476oKPYJHgNsT_wxWcVM7UPEe_A4rGFK3u5Nxocz6TO1M6QF-5VfM-4C6pvZ-cryEakyxdZm6GaHw7p9zbMvWyaV6i1CvmDXy27crdTMH0Tc23b0hvt7S-fanNHX4dGjk06Is5AS7iuF-deOP1A46W0iSZPaIhLkVkBxOTTw8Wp12qn_2fxTdloxilj5f3cSIkJJSt5CyCNX3COteQXhYjO8geRyhwPGFGyDICcz7CEBCngNc2CFZt-0BfY9piw&recommendedFlavor=COMPANY_RECRUIT&refId=uAGrvRCfo9q5%2BNk5EGGm4Q%3D%3D&trackingId=nI03Xvg4nBirIwj8TRNSAQ%3D%3D&trk=flagship3_search_srp_jobs,"About the job\nIf you’re passionate about building a better future for individuals, communities, and our country—and you’re committed to working hard to play your part in building that future—consider WGU as the next step in your career.\n\nDriven by a mission to expand access to higher education through online, competency-based degree programs, WGU is also committed to being a great place to work for a diverse workforce of student-focused professionals. The university has pioneered a new way to learn in the 21st century, one that has received praise from academic, industry, government, and media leaders. Whatever your role, working for WGU gives you a part to play in helping students graduate, creating a better tomorrow for themselves and their families.\n\n\n\n\n\n:\n\n\n\n\n\nAs an equal opportunity employer, WGU recognizes that our strength lies in our people. We are committed to diversity.",[],[]\nCarShield,Data Scientist,"St Louis, MO","50 minutes ago\nWithin the past 24 hours",https://www.linkedin.com/jobs/view/2723209281/?eBP=JOB_SEARCH_ORGANIC&recommendedFlavor=COMPANY_RECRUIT&refId=uAGrvRCfo9q5%2BNk5EGGm4Q%3D%3D&trackingId=KgTMJ%2FOU15u5GSRxFma6BA%3D%3D&trk=flagship3_search_srp_jobs,"About the job\nJob Description\nResponsible for overseeing the collection, storage and interpretation of data for businesses. Their duties include sifting through data points to create organized categories, comparing data points to current company processes and writing reports outlining business predictions or proposals.",[],[]\nAmerican Express Global Business Travel,Data Scientist,"Evansville, IN",6 days ago,https://www.linkedin.com/jobs/view/2716701280/?eBP=JOB_SEARCH_ORGANIC&recommendedFlavor=ACTIVELY_HIRING_COMPANY&refId=uAGrvRCfo9q5%2BNk5EGGm4Q%3D%3D&trackingId=%2FNnG2%2FT8eaQ5Auu0r1LwgQ%3D%3D&trk=flagship3_search_srp_jobs,"About the job\nThe Candidate Is Expected To Possess These Key Skills/technologies\n\nThe data science solutions engineer will be a member of the data analytics team and will lead efforts around building big data, data science, data quality, and BI/MI/AI solutions. An ideal candidate will be a The data science associate will have a growth-oriented, lean-startup mindset for building hands-on data science solutions. The ideal candidate will propose, experiment, execute, and operationalize advanced predictive, preemptive data solutions designed to help traveler, travel-manager, supplier, and client outcomes. The role will span full-scale product, enterprise, and operational data science. The candidate will focus and thrive in a hands-on applied role; he/she will demonstrate a strong penchant for quantitative, collaborative, outcome-oriented solutions-engineering.\n\n\n\n\n\n\n\nIndia>Virtual Location\n\nIt is our policy to provide equal employment opportunities to all individuals based on job-related qualifications and ability to perform a job, without regard to age, gender, gender identity, sexual orientation, race, color, religion, creed, national origin, disability, genetic information, veteran status, citizenship or marital status, and to maintain a non-discriminatory environment free from intimidation, harassment or bias based upon these grounds.\n\nPosted 6 Days Ago Full time J-46605\n\nAmerican Express Global Business Travel (GBT) is the world’s leading business partner for managed travel. We help companies and employees prosper by making sure travelers are present where and when it matters. We keep global business moving with the powerful backing of 16,000 travel professionals in more than 140 countries. Companies of all sizes, and in all places, rely on GBT to provide travel management services, organize meetings and events, and deliver business travel consulting.",[],[]\nKPMG US,"Associate, Data Scientist","Chicago, IL",,https://www.linkedin.com/jobs/view/2715182807/?eBP=CwEAAAF8A9ofOnXwJUuycM2gGRL1mcgrhKEvGOAPq7WvcuqVfhF3v31fFIUXMUZTB2_KdQBZae-zIVr4TaQH32qoMce5QiuRkyz35Qe4NunBDe1tO5oIPM_jRd0DRVV1Q2RE2NsRab1c65uetiOURFT5UacwF26coAIsRg_OLs_YoY_77ZEEy1w6kTyWThm4DdS0MF9eZsoLFRxcEZjVZPeHkjucUMmMlgDkGFolStofkAtovBw2_NeONzmFwJOWVe1GKQ1XqLioi_MqRW4kb3iJnvdR5E8PAb5PCjiNjJEfuIXO63QpyODR7y7X0dEhMCCkj_x1tLu5T0PQeNlCeZkpp7nWdyWZQtRzOXNNpH9yPYBeaNL_b3b8W8FSewL2XfI&recommendedFlavor=COMPANY_RECRUIT&refId=uAGrvRCfo9q5%2BNk5EGGm4Q%3D%3D&trackingId=tWMAG1KeTQs1iil6CAtrmQ%3D%3D&trk=flagship3_search_srp_jobs,"About the job\nRequisition Number: 70881 - 31\n\nDescription\n\nInnovate. Collaborate. Build. Create. Solve. The KPMG Digital Lighthouse is KPMG\'s award-winning Analytics & AI Center of Excellence recognized by clients and leading analyst firms in the US and globally. The KPMG Lighthouse is a curation of specialized technical capabilities and domain experts working across the digital landscape: applied data science, AI, data engineering and insights, software engineering, automation, and big data. Here, you\'ll work with a diverse team of professionals to explore and build solutions for clients in a multiplatform environment.\n\nYou\'ll be an important part of our high-energy, unique, fast-paced, and innovative culture that delivers with the agility of a tech startup and the backing of a leading global consulting firm. In this particular role, you\'ll work specifically in the AI Analytics & Engineering Community within the Digital Lighthouse, on a wide range of projects. From applied AI to optimization to big data platform engineering, your analytical and technical skills will drive real impact in the business world. At KPMG, our commitment to your career development helps to set us apart as an employer. We want to enhance your potential, both for yourself and as a contributor to our firm. That\'s why we provide every opportunity to expand your skills, knowledge and experiences through formal education and training programs, leadership development opportunities, and, as well as informal one-on-one coaching and mentoring from your KPMG colleagues.\n\nKPMG is currently seeking an Associate to join our KPMG Lighthouse - Center of Excellence for Advanced Analytics.\n\n\n\n\n\nKPMG LLP (the U.S. member firm of KPMG International) offers a comprehensive compensation and benefits package. KPMG is an affirmative action-equal opportunity employer. KPMG complies with all applicable federal, state and local laws regarding recruitment and hiring. All qualified applicants are considered for employment without regard to race, color, religion, age, sex, sexual orientation, gender identity, national origin, disability, protected veteran status, or any other category protected by applicable federal, state or local laws. The attached link contains further information regarding the firm\'s compliance with federal, state and local recruitment and hiring laws. No phone calls or agencies please.",[],[]\n"Systems Planning and Analysis, Inc.",Data Scientist - CWMD,"Reston, VA",,https://www.linkedin.com/jobs/view/2719087133/?eBP=CwEAAAF8A9ofOs3Q1pRDNomWkKq8WZKKrxzVFph6K2D4ymCmOH1h4zujhf7yBWfSjCtGRdbAe9Qx1ZFnDclUFpBrbo8MAanx6IoSd6oeFzDujMeur4dsRn-KObiuVvRuoE8jax4zNaj2cL0qgNswrocbKDKdYn82E7vixG1bp6oL35Xs1t4QTILoMHsFU_wTZqMgC7fCMPF3UzzYVoZ7UpLI2jutAFhJUtKKFD94vE5WkDbZOlxsnkXaN96-uctzECAJaz-JWJTbMRDHUek1yOdijC16J7HeR8V1Snd1B3f-lHcwkIyohdLJUUsi0dDpOWpoQNpv7XWOgAXT-NzCdHsRY99xfHcFFJK5r9UEJvFy__j3f60gUpWxie9aT8NO&recommendedFlavor=ACTIVELY_HIRING_COMPANY&refId=uAGrvRCfo9q5%2BNk5EGGm4Q%3D%3D&trackingId=sCAmjQEN8DY8a6u7bP7Yfg%3D%3D&trk=flagship3_search_srp_jobs,"About the job\nOverview\n\nSystems Planning and Analysis, Inc. (SPA) is a well-established and progressive defense contracting company in the DC Metro area. We are a professional services firm established in 1972 that has a long-standing reputation for unrivaled technical and analytical support to some of the top decision makers in the Federal Sector. We do state of the art work and have a cadre of outstanding professionals on our team.\n\nSPA assists the Defense Threat Reduction Agency (DTRA) in developing leading edge technologies to counter WMD in support of CCMDs and transitioning these technologies to services and SOCOM. SPA provides expertise across the full range of chemical, biological, radiological, nuclear and high-yield explosives (CBRNE) WMD, Counter Improvised Threat and Countering Threat Network technologies to support understanding, detection, identification, characterization, denial, control, disabling, defeating, disposing, safeguarding the force, managing consequences, and test and evaluation in support of military and civilian operations. #CJ #IN123\n\n\n\nProvides critical decision and analytic support to the Urgent Solutions Division in the Counter WMD Technologies Department of the Defense Threat Reduction Agency (DTRA). Conducts assessments, demonstrations, analysis, scientific codes, and other decision making in evaluating systems to counter WMD – biological and chemical threats, and counter threat networks. Develops knowledge regarding a stipulated issue through analysis of complex data sets, identifying actionable trends and problems. Uses appropriate methods to creatively explore, mine, analyze and manipulate data sets ranging in size from sparse to petabytes and type (e.g. small number of .pdf text reports, Excel spreadsheets and .csv files to repositories of image or audio data). Interprets results from multiple sources using a variety of techniques, ranging from simple data aggregation via statistical analysis to complex data mining, sensor analysis and learning techniques. Designs, develops, and implements technical solutions in support of concurrent analysis. Supports data models and defines the structure, attributes, and nomenclature of data elements. May evaluate new data sources for adherence to the organization\'s quality standards and ease of integration.",[],[]\nPerficient,Data Scientist,"St Louis, MO",,https://www.linkedin.com/jobs/view/2718055481/?eBP=CwEAAAF8A9ofOhOHpkH95U2fvN9F-goU76IrWGZ2_h1PEIqUbFxqxI6w3ypUfMSWfMRpTGEJDX9iicxg3Is1hE7MJg4ixQ2ZJfmdAFAR38WMuWQ9RdnHIEX4XrSbapYsM3nhi6Iyv6rH9MEC1PpEqmZkvr8JBlfU1asVfgP3pl3rW4IS6tIVJuzERferAoB3ycE-UB94AE92MTfUPPOUagL-zhuIsIcyQ6BMfE6eFGYpZpAHbvdti7-s852GjLAxYFovRGVyerfbSKSeZm6fVVXT2EaQfKYvMN5hBZBBVncwxNfzaaMBbKZ9moxmBg76BZ3UfB6YOntWLvvf06jI4VVqLMZ_BYq4iT8Jnp-YKt2dJxnECW-9zW66IbRoeRPT&recommendedFlavor=COMPANY_RECRUIT&refId=uAGrvRCfo9q5%2BNk5EGGm4Q%3D%3D&trackingId=UE7bblhxeqWJV52%2F9JWJew%3D%3D&trk=flagship3_search_srp_jobs,"About the job\nOverview\n\nAt Perficient you’ll deliver mission-critical technology and business solutions to Fortune 500 companies and some of the most recognized brands on the planet. And you’ll do it with cutting-edge technologies, thanks to our close partnerships with the world’s biggest vendors. Our network of offices across North America, as well as locations in India and China, will give you the opportunity to spread your wings, too.\n\nWe’re proud to be publicly recognized as a “Top Workplace” year after year. This is due, in no small part, to our entrepreneurial attitude and collaborative spirit that sets us apart and keeps our colleagues impassioned, driven, and fulfilled.\n\nPerficient currently has a career opportunity for a .\n\n\n\nThe role of the Data Scientist is for individuals passionate about identifying and delivering the right Business solution for each client using AI/ML. Our Data Scientists are keen to understand our customer needs, processes and pain points to determine the success factors and evaluation criteria that will needed to measure the effectiveness of an ML model.\n\nThe Data Scientist will be involved in the strategic planning of an engagement or helping the client make decisions about their future AI/ML roadmap and vision. Once the project as begun, the Data Scientist will be responsible for the execution of our established methodology, work with customer and/or the teams data engineer to identify data ingestion and transformation needs, exploration of the data and reporting findings, modeling and evaluation of training iterations. It is a key part of the role to be able to explain in non-technical terms the chosen modeling approach and findings from data exploration or training results.\n\nThe Data Scientist will work with Senior Project Managers to assist with daily operations exercising time management, communication and collaboration in a fast-paced environment to ensure the successful delivery of projects. The Data Scientist will interface with Perficient technical and business delivery personnel, as well as vendors and customers on a regular basis. May mentor junior data scientists.\n\n\n\n\n\n\n\nPerficient full-time employees receive complete and competitive benefits. We offer a collaborative work environment, competitive compensation, generous work/life opportunities and an outstanding benefits package that includes paid time off plus holidays. In addition, all colleagues are eligible for a number of rewards and recognition programs including billable bonus opportunities. Encouraging a healthy work/life balance and providing our colleagues great benefits are just part of what makes Perficient a great place to work.\n\n\n\nPerficient is the leading digital transformation consulting firm serving Global 2000 and enterprise customers throughout North America. With unparalleled information technology, management consulting and creative capabilities, Perficient and its Perficient Digital agency deliver vision, execution and value with outstanding digital experience, business optimization and industry solutions.\n\nOur work enables clients to improve productivity and competitiveness; grow and strengthen relationships with customers, suppliers and partners; and reduce costs. Perficient\'s professionals serve clients from a network of offices across North America and offshore locations in India and China. Traded on the Nasdaq Global Select Market, Perficient is a member of the Russell 2000 index and the S&P SmallCap 600 index.\n\nPerficient is an equal opportunity employer and all qualified applicants will receive consideration for employment without regard to race, color, religion, sex, national, origin, disability status, protected veteran status, or any other characteristic protected by law.\n\nThe above statements are not intended to be a complete statement of job content, rather to act as a guide to the essential functions performed by the employee assigned to this classification. Management retains the discretion to add or change the duties of the position at any time.\n\nSelect work authorization questions to ask when applicants apply",[],[]\nSavage X Fenty: Lingerie by Rihanna,Data Scientist,"El Segundo, CA",,https://www.linkedin.com/jobs/view/2721710042/?eBP=CwEAAAF8A9ofOhPzbWsStxaNEgpMLIbvO6Vvpf-kp8RGwvYOJKGphyyakdc_4SGsjm2VeRAGjmk-vJ6l9A5H_dap2I3Kpoi5h6gKOdZGPr43fehHk5BqkiDkbvKki_to05FvWLinOBzurpjsMFG3JoeqUJ8xRReTFcidZnHYUQE6jUxh0nf-LNmAPuQp7YZEmPEps45wTFpgh1xQa_nwnLky1x-nzte_8YwEIsmHKQ5z2VTOvDevWj_NNLxyfvp4hDKsNbBNyQC_28gSNPkqkg6iN2yFOum-URpP05X-BwoG-gN9HPsuQJs-bhqDslt8i6wwag517FTdUMMYWqa29zUtuHYFUf1ei5iEh0ffOBNdGGDafvdOB4z8Oqp3hxLnHhY&recommendedFlavor=ACTIVELY_HIRING_COMPANY&refId=uAGrvRCfo9q5%2BNk5EGGm4Q%3D%3D&trackingId=WJuu5WmPKTuvZRyUdmNdtA%3D%3D&trk=flagship3_search_srp_jobs,"About the job\nJob DescriptionSavage X Fenty is looking for a Data Scientist. Co-founded by music and fashion icon Rihanna, Savage X Fenty is the first line of lingerie that celebrates and speaks to all shades and shapes of people, and celebrates fearlessness, confidence and inclusivity.\n\nHOW DO YOU FIT IN?\n\nAs the Data Scientist, you will drive innovation in our customer shopping experience by providing the algorithms that power recommendation and personalization features across our ecommerce website. You will collaborate closely with the Data Analytics organization, the Global Technology organization, and the Savage X business to develop high-impact solutions to key optimization opportunities such as ecommerce conversion & product discovery. You will watch your work come to life by partnering with dedicated product & software engineering teams to deploy your algorithms into production.\n\nProjects you are likely to own in this role include:\n\nProduct Recommendation Algorithms (e.g., product discovery & upsell algorithms)\n\nFull Funnel Customer Segmentation (e.g., algorithmically define customer segments and stream segments to other tools such as our CRM or ad networks)\n\nInternal Optimization Algorithms (e.g., attribution models, sales propensity algorithms)\n\nAt Savage X Fenty you can expect to use Python and SQL every day. For larger projects requiring scale or automation you’ll likely be working with DataBricks and Airflow. While these are our defaults, you will have the flexibility to use tools that allow you to best fulfill your role. Additionally, we strongly believe in the need for ongoing education and so will encourage you to explore new technologies and modeling methods on a regular basis.\n\n\n\nYou’re the ideal candidate if you’re incredibly curious & see opportunities for data science applications in everything you do. Working smarter, not harder, is core to your DNA. You’re invigorated by the opportunity to learn that next tool or skill, and you come up with clever solutions to difficult problems. As much as you learned in school or at work, you’ve probably learned even more during your late-night hacking sessions. You take initiative, can work without supervision, begin projects independently, and are technically capable with a deep desire to become an expert in data science applications for ecommerce. You’re seeking a collaborative environment in which you can work alongside other technology experts to find the best answer and win as a team.\n\nThis position will report to the Director of Data Analytics on the Savage X Fenty Analytics Team. The position will also have an informal reporting line to the Sr. Director of Data Science on the TechStyleOS Architecture & Sciences team. We are a creative, ambitious, & fun-loving team who believes data products should be collaboratively designed, impactful to the business, and customized for the end user. Our analytics team acts as strategic partners to the business, making an impact by merging data with a deep understanding of the Savage customer experience.\n\nThis position will be based in El Segundo, California. For the right candidate, we will consider full-time remote work.\n\nWHY WORK IN DATA SCIENCE AT SAVAGE X?\n\nWork within a community of data scientists through our parent company TechStyle Fashion Group & our sister brand Fabletics, but be the first Data Scientist dedicated to the Savage X brand. This role will design the foundation for Savage’s future data science initiatives & experience fast paced growth\n\nDedicated resources to support you – Savage X is investing heavily in data science and has staffed dedicated engineering & product management to support your initiatives\n\nIndustry leading data technology stack – Snowflake, DataBricks, Segment Customer Data Platform, Apache Airflow, modeled reporting data warehouse, & more\n\nData-driven mindset is deeply foundational to the culture at Savage X; information flows freely throughout our organization and every key decision we make is backed by analysis\n\nBe a part of the larger Data Analytics organization at TechStyle Fashion Group (60+ team members); mentor & be mentored by our architects, scientists, analysts, & engineers\n\n\n\nLeverage our advanced tech stack, your knowledge of data science methods & models, and your partnerships with our senior engineers, scientists, and architects to determine the best approaches for algorithm development and implementation\n\nOwn algorithm development projects from start-to-end: design, develop, QA, deploy, experiment, and analyze\n\nPartner with dedicated product management & software engineering teams to implement data science algorithms onto our consumer-facing ecommerce website\n\nPartner with dedicated analysts to produce data visualizations, advanced reports, measurement and statistical models that explain and track algorithm performance against business KPIs\n\nPartner with the business to identify & understand opportunities for data science applications\n\nProvide thought leadership and data support to the business & other analytics team members around design, execution, and measurement of business KPIs\n\nCollaborate with other data scientists across our organization to share best practices, learn new techniques, and foster our organizational culture where data is central to decision making\n\n\n\nHigh degree of personal integrity, strong work ethic, & a desire to learn and grow in this role\n\n2+ years of work experience as a Data Scientist or Machine Learning Engineer\n\nFluent in R or Python (Python preferred) & SQL\n\nFamiliarity with Machine Learning techniques (e.g. classification, clustering, regularization, optimization, dimension reduction, feature engineering)\n\nStrong understanding of CS fundamentals (e.g. algorithms and data structures)\n\nExperience with attribution, causal inference, experimental design, and AB testing methods\n\nGood communication skills and ability to explain complex topics to a non-technical audience\n\n\n\nExperience partnering with product management & software engineering teams to implement algorithms into a production environment\n\nDegree or Advanced Degree in Statistics, Computer Science, or related fields\n\nExperience with Git and/or Airflow\n\nExperience with data visualization tools such as Tableau\n\nExperience in e-commerce, subscription models, and/or direct-to-consumer brands\n\nFamiliarity with web analytics tools & concepts (Google Analytics, pixel tracking, Segment Customer Data Platform or comparable tools)\n\n\n\nTechStyleOS is the globally integrated Operations and Services provider behind some of the fastest growing online fashion brands in history, including Fabletics, Savage X Fenty, JustFab, ShoeDazzle, and FabKids. With capabilities spanning technology, data science, supply chain management, fulfillment, customer service, and more, we help brands launch, scale and grow—across product categories and geographically. From predictive analytics to data-driven marketing and attribution, our unique approach is powered by our proprietary, end-to-end tech platform that enables the brands we serve to deliver a level of personalization, value, and satisfaction that are unrivaled in the fashion industry.\n\nSavage X Inc.is an equal opportunity employer. We recruit, employ, compensate, develop, and promote regardless of race, national origin, religion, sex, sexual orientation, gender identity, age, disability, genetic information, veteran status, and other protected status as required by applicable. At Savage X Inc. , we champion a vibrant workplace culture that thrives on diversity law and do not tolerate discrimination or harassment. We are one team from many backgrounds, innovating through diversity of individuals, who are driven by passion for creating an inclusive space for all. Savage X Inc. will continue to champion a workplace culture that prizes diversity and inclusivity.\n\nWe encourage you to apply regardless of meeting all qualifications and/or requirements.",[],[]\nWestern Governors University,Data Scientist-2,"St Louis, MO",,https://www.linkedin.com/jobs/view/2718750842/?eBP=CwEAAAF8A9ofOjpba68ujoLXQAaOCBXYiS4C1yUTdLuyzCZe9eu8Ol6E5B1OavyEuBokToqXvI8orCg9mTa7e7zpzyV9cy10rVkKoDvZEPBDm1du-SyxnPgFICjxXnkLuO4a476oKPYJHgNsT_wxWcVM7UPEe_A4rGFK3u5Nxocz6TO1M6QF-5VfM-4C6pvZ-cryEakyxdZm6GaHw7p9zbMvWyaV6i1CvmDXy27crdTMH0Tc23b0hvt7S-fanNHX4dGjk06Is5AS7iuF-deOP1A46W0iSZPaIhLkVkBxOTTw8Wp12qn_2fxTdloxilj5f3cSIkJJSt5CyCNX3COteQXhYjO8geRyhwPGFGyDICcz7CEBCngNc2CFZt-0BfY9piw&recommendedFlavor=COMPANY_RECRUIT&refId=uAGrvRCfo9q5%2BNk5EGGm4Q%3D%3D&trackingId=nI03Xvg4nBirIwj8TRNSAQ%3D%3D&trk=flagship3_search_srp_jobs,"About the job\nIf you’re passionate about building a better future for individuals, communities, and our country—and you’re committed to working hard to play your part in building that future—consider WGU as the next step in your career.\n\nDriven by a mission to expand access to higher education through online, competency-based degree programs, WGU is also committed to being a great place to work for a diverse workforce of student-focused professionals. The university has pioneered a new way to learn in the 21st century, one that has received praise from academic, industry, government, and media leaders. Whatever your role, working for WGU gives you a part to play in helping students graduate, creating a better tomorrow for themselves and their families.\n\n\n\n\n\n:\n\n\n\n\n\nAs an equal opportunity employer, WGU recognizes that our strength lies in our people. We are committed to diversity.",[],[]\nCarShield,Data Scientist,"St Louis, MO","50 minutes ago\nWithin the past 24 hours",https://www.linkedin.com/jobs/view/2723209281/?eBP=JOB_SEARCH_ORGANIC&recommendedFlavor=COMPANY_RECRUIT&refId=uAGrvRCfo9q5%2BNk5EGGm4Q%3D%3D&trackingId=KgTMJ%2FOU15u5GSRxFma6BA%3D%3D&trk=flagship3_search_srp_jobs,"About the job\nJob Description\nResponsible for overseeing the collection, storage and interpretation of data for businesses. Their duties include sifting through data points to create organized categories, comparing data points to current company processes and writing reports outlining business predictions or proposals.",[],[]\nAmerican Express Global Business Travel,Data Scientist,"Evansville, IN",6 days ago,https://www.linkedin.com/jobs/view/2716701280/?eBP=JOB_SEARCH_ORGANIC&recommendedFlavor=ACTIVELY_HIRING_COMPANY&refId=uAGrvRCfo9q5%2BNk5EGGm4Q%3D%3D&trackingId=%2FNnG2%2FT8eaQ5Auu0r1LwgQ%3D%3D&trk=flagship3_search_srp_jobs,"About the job\nThe Candidate Is Expected To Possess These Key Skills/technologies\n\nThe data science solutions engineer will be a member of the data analytics team and will lead efforts around building big data, data science, data quality, and BI/MI/AI solutions. An ideal candidate will be a The data science associate will have a growth-oriented, lean-startup mindset for building hands-on data science solutions. The ideal candidate will propose, experiment, execute, and operationalize advanced predictive, preemptive data solutions designed to help traveler, travel-manager, supplier, and client outcomes. The role will span full-scale product, enterprise, and operational data science. The candidate will focus and thrive in a hands-on applied role; he/she will demonstrate a strong penchant for quantitative, collaborative, outcome-oriented solutions-engineering.\n\n\n\n\n\n\n\nIndia>Virtual Location\n\nIt is our policy to provide equal employment opportunities to all individuals based on job-related qualifications and ability to perform a job, without regard to age, gender, gender identity, sexual orientation, race, color, religion, creed, national origin, disability, genetic information, veteran status, citizenship or marital status, and to maintain a non-discriminatory environment free from intimidation, harassment or bias based upon these grounds.\n\nPosted 6 Days Ago Full time J-46605\n\nAmerican Express Global Business Travel (GBT) is the world’s leading business partner for managed travel. We help companies and employees prosper by making sure travelers are present where and when it matters. We keep global business moving with the powerful backing of 16,000 travel professionals in more than 140 countries. Companies of all sizes, and in all places, rely on GBT to provide travel management services, organize meetings and events, and deliver business travel consulting.",[],[]\nKPMG US,"Associate, Data Scientist","Chicago, IL",,https://www.linkedin.com/jobs/view/2715182807/?eBP=CwEAAAF8A9ofOnXwJUuycM2gGRL1mcgrhKEvGOAPq7WvcuqVfhF3v31fFIUXMUZTB2_KdQBZae-zIVr4TaQH32qoMce5QiuRkyz35Qe4NunBDe1tO5oIPM_jRd0DRVV1Q2RE2NsRab1c65uetiOURFT5UacwF26coAIsRg_OLs_YoY_77ZEEy1w6kTyWThm4DdS0MF9eZsoLFRxcEZjVZPeHkjucUMmMlgDkGFolStofkAtovBw2_NeONzmFwJOWVe1GKQ1XqLioi_MqRW4kb3iJnvdR5E8PAb5PCjiNjJEfuIXO63QpyODR7y7X0dEhMCCkj_x1tLu5T0PQeNlCeZkpp7nWdyWZQtRzOXNNpH9yPYBeaNL_b3b8W8FSewL2XfI&recommendedFlavor=COMPANY_RECRUIT&refId=uAGrvRCfo9q5%2BNk5EGGm4Q%3D%3D&trackingId=tWMAG1KeTQs1iil6CAtrmQ%3D%3D&trk=flagship3_search_srp_jobs,"About the job\nRequisition Number: 70881 - 31\n\nDescription\n\nInnovate. Collaborate. Build. Create. Solve. The KPMG Digital Lighthouse is KPMG\'s award-winning Analytics & AI Center of Excellence recognized by clients and leading analyst firms in the US and globally. The KPMG Lighthouse is a curation of specialized technical capabilities and domain experts working across the digital landscape: applied data science, AI, data engineering and insights, software engineering, automation, and big data. Here, you\'ll work with a diverse team of professionals to explore and build solutions for clients in a multiplatform environment.\n\nYou\'ll be an important part of our high-energy, unique, fast-paced, and innovative culture that delivers with the agility of a tech startup and the backing of a leading global consulting firm. In this particular role, you\'ll work specifically in the AI Analytics & Engineering Community within the Digital Lighthouse, on a wide range of projects. From applied AI to optimization to big data platform engineering, your analytical and technical skills will drive real impact in the business world. At KPMG, our commitment to your career development helps to set us apart as an employer. We want to enhance your potential, both for yourself and as a contributor to our firm. That\'s why we provide every opportunity to expand your skills, knowledge and experiences through formal education and training programs, leadership development opportunities, and, as well as informal one-on-one coaching and mentoring from your KPMG colleagues.\n\nKPMG is currently seeking an Associate to join our KPMG Lighthouse - Center of Excellence for Advanced Analytics.\n\n\n\n\n\nKPMG LLP (the U.S. member firm of KPMG International) offers a comprehensive compensation and benefits package. KPMG is an affirmative action-equal opportunity employer. KPMG complies with all applicable federal, state and local laws regarding recruitment and hiring. All qualified applicants are considered for employment without regard to race, color, religion, age, sex, sexual orientation, gender identity, national origin, disability, protected veteran status, or any other category protected by applicable federal, state or local laws. The attached link contains further information regarding the firm\'s compliance with federal, state and local recruitment and hiring laws. No phone calls or agencies please.",[],[]\n"Systems Planning and Analysis, Inc.",Data Scientist - CWMD,"Reston, VA",,https://www.linkedin.com/jobs/view/2719087133/?eBP=CwEAAAF8A9ofOs3Q1pRDNomWkKq8WZKKrxzVFph6K2D4ymCmOH1h4zujhf7yBWfSjCtGRdbAe9Qx1ZFnDclUFpBrbo8MAanx6IoSd6oeFzDujMeur4dsRn-KObiuVvRuoE8jax4zNaj2cL0qgNswrocbKDKdYn82E7vixG1bp6oL35Xs1t4QTILoMHsFU_wTZqMgC7fCMPF3UzzYVoZ7UpLI2jutAFhJUtKKFD94vE5WkDbZOlxsnkXaN96-uctzECAJaz-JWJTbMRDHUek1yOdijC16J7HeR8V1Snd1B3f-lHcwkIyohdLJUUsi0dDpOWpoQNpv7XWOgAXT-NzCdHsRY99xfHcFFJK5r9UEJvFy__j3f60gUpWxie9aT8NO&recommendedFlavor=ACTIVELY_HIRING_COMPANY&refId=uAGrvRCfo9q5%2BNk5EGGm4Q%3D%3D&trackingId=sCAmjQEN8DY8a6u7bP7Yfg%3D%3D&trk=flagship3_search_srp_jobs,"About the job\nOverview\n\nSystems Planning and Analysis, Inc. (SPA) is a well-established and progressive defense contracting company in the DC Metro area. We are a professional services firm established in 1972 that has a long-standing reputation for unrivaled technical and analytical support to some of the top decision makers in the Federal Sector. We do state of the art work and have a cadre of outstanding professionals on our team.\n\nSPA assists the Defense Threat Reduction Agency (DTRA) in developing leading edge technologies to counter WMD in support of CCMDs and transitioning these technologies to services and SOCOM. SPA provides expertise across the full range of chemical, biological, radiological, nuclear and high-yield explosives (CBRNE) WMD, Counter Improvised Threat and Countering Threat Network technologies to support understanding, detection, identification, characterization, denial, control, disabling, defeating, disposing, safeguarding the force, managing consequences, and test and evaluation in support of military and civilian operations. #CJ #IN123\n\n\n\nProvides critical decision and analytic support to the Urgent Solutions Division in the Counter WMD Technologies Department of the Defense Threat Reduction Agency (DTRA). Conducts assessments, demonstrations, analysis, scientific codes, and other decision making in evaluating systems to counter WMD – biological and chemical threats, and counter threat networks. Develops knowledge regarding a stipulated issue through analysis of complex data sets, identifying actionable trends and problems. Uses appropriate methods to creatively explore, mine, analyze and manipulate data sets ranging in size from sparse to petabytes and type (e.g. small number of .pdf text reports, Excel spreadsheets and .csv files to repositories of image or audio data). Interprets results from multiple sources using a variety of techniques, ranging from simple data aggregation via statistical analysis to complex data mining, sensor analysis and learning techniques. Designs, develops, and implements technical solutions in support of concurrent analysis. Supports data models and defines the structure, attributes, and nomenclature of data elements. May evaluate new data sources for adherence to the organization\'s quality standards and ease of integration.",[],[]\nPerficient,Data Scientist,"St Louis, MO",,https://www.linkedin.com/jobs/view/2718055481/?eBP=CwEAAAF8A9ofOhOHpkH95U2fvN9F-goU76IrWGZ2_h1PEIqUbFxqxI6w3ypUfMSWfMRpTGEJDX9iicxg3Is1hE7MJg4ixQ2ZJfmdAFAR38WMuWQ9RdnHIEX4XrSbapYsM3nhi6Iyv6rH9MEC1PpEqmZkvr8JBlfU1asVfgP3pl3rW4IS6tIVJuzERferAoB3ycE-UB94AE92MTfUPPOUagL-zhuIsIcyQ6BMfE6eFGYpZpAHbvdti7-s852GjLAxYFovRGVyerfbSKSeZm6fVVXT2EaQfKYvMN5hBZBBVncwxNfzaaMBbKZ9moxmBg76BZ3UfB6YOntWLvvf06jI4VVqLMZ_BYq4iT8Jnp-YKt2dJxnECW-9zW66IbRoeRPT&recommendedFlavor=COMPANY_RECRUIT&refId=uAGrvRCfo9q5%2BNk5EGGm4Q%3D%3D&trackingId=UE7bblhxeqWJV52%2F9JWJew%3D%3D&trk=flagship3_search_srp_jobs,"About the job\nOverview\n\nAt Perficient you’ll deliver mission-critical technology and business solutions to Fortune 500 companies and some of the most recognized brands on the planet. And you’ll do it with cutting-edge technologies, thanks to our close partnerships with the world’s biggest vendors. Our network of offices across North America, as well as locations in India and China, will give you the opportunity to spread your wings, too.\n\nWe’re proud to be publicly recognized as a “Top Workplace” year after year. This is due, in no small part, to our entrepreneurial attitude and collaborative spirit that sets us apart and keeps our colleagues impassioned, driven, and fulfilled.\n\nPerficient currently has a career opportunity for a .\n\n\n\nThe role of the Data Scientist is for individuals passionate about identifying and delivering the right Business solution for each client using AI/ML. Our Data Scientists are keen to understand our customer needs, processes and pain points to determine the success factors and evaluation criteria that will needed to measure the effectiveness of an ML model.\n\nThe Data Scientist will be involved in the strategic planning of an engagement or helping the client make decisions about their future AI/ML roadmap and vision. Once the project as begun, the Data Scientist will be responsible for the execution of our established methodology, work with customer and/or the teams data engineer to identify data ingestion and transformation needs, exploration of the data and reporting findings, modeling and evaluation of training iterations. It is a key part of the role to be able to explain in non-technical terms the chosen modeling approach and findings from data exploration or training results.\n\nThe Data Scientist will work with Senior Project Managers to assist with daily operations exercising time management, communication and collaboration in a fast-paced environment to ensure the successful delivery of projects. The Data Scientist will interface with Perficient technical and business delivery personnel, as well as vendors and customers on a regular basis. May mentor junior data scientists.\n\n\n\n\n\n\n\nPerficient full-time employees receive complete and competitive benefits. We offer a collaborative work environment, competitive compensation, generous work/life opportunities and an outstanding benefits package that includes paid time off plus holidays. In addition, all colleagues are eligible for a number of rewards and recognition programs including billable bonus opportunities. Encouraging a healthy work/life balance and providing our colleagues great benefits are just part of what makes Perficient a great place to work.\n\n\n\nPerficient is the leading digital transformation consulting firm serving Global 2000 and enterprise customers throughout North America. With unparalleled information technology, management consulting and creative capabilities, Perficient and its Perficient Digital agency deliver vision, execution and value with outstanding digital experience, business optimization and industry solutions.\n\nOur work enables clients to improve productivity and competitiveness; grow and strengthen relationships with customers, suppliers and partners; and reduce costs. Perficient\'s professionals serve clients from a network of offices across North America and offshore locations in India and China. Traded on the Nasdaq Global Select Market, Perficient is a member of the Russell 2000 index and the S&P SmallCap 600 index.\n\nPerficient is an equal opportunity employer and all qualified applicants will receive consideration for employment without regard to race, color, religion, sex, national, origin, disability status, protected veteran status, or any other characteristic protected by law.\n\nThe above statements are not intended to be a complete statement of job content, rather to act as a guide to the essential functions performed by the employee assigned to this classification. Management retains the discretion to add or change the duties of the position at any time.\n\nSelect work authorization questions to ask when applicants apply",[],[]\nSavage X Fenty: Lingerie by Rihanna,Data Scientist,"El Segundo, CA",,https://www.linkedin.com/jobs/view/2721710042/?eBP=CwEAAAF8A9ofOhPzbWsStxaNEgpMLIbvO6Vvpf-kp8RGwvYOJKGphyyakdc_4SGsjm2VeRAGjmk-vJ6l9A5H_dap2I3Kpoi5h6gKOdZGPr43fehHk5BqkiDkbvKki_to05FvWLinOBzurpjsMFG3JoeqUJ8xRReTFcidZnHYUQE6jUxh0nf-LNmAPuQp7YZEmPEps45wTFpgh1xQa_nwnLky1x-nzte_8YwEIsmHKQ5z2VTOvDevWj_NNLxyfvp4hDKsNbBNyQC_28gSNPkqkg6iN2yFOum-URpP05X-BwoG-gN9HPsuQJs-bhqDslt8i6wwag517FTdUMMYWqa29zUtuHYFUf1ei5iEh0ffOBNdGGDafvdOB4z8Oqp3hxLnHhY&recommendedFlavor=ACTIVELY_HIRING_COMPANY&refId=uAGrvRCfo9q5%2BNk5EGGm4Q%3D%3D&trackingId=WJuu5WmPKTuvZRyUdmNdtA%3D%3D&trk=flagship3_search_srp_jobs,"About the job\nJob DescriptionSavage X Fenty is looking for a Data Scientist. Co-founded by music and fashion icon Rihanna, Savage X Fenty is the first line of lingerie that celebrates and speaks to all shades and shapes of people, and celebrates fearlessness, confidence and inclusivity.\n\nHOW DO YOU FIT IN?\n\nAs the Data Scientist, you will drive innovation in our customer shopping experience by providing the algorithms that power recommendation and personalization features across our ecommerce website. You will collaborate closely with the Data Analytics organization, the Global Technology organization, and the Savage X business to develop high-impact solutions to key optimization opportunities such as ecommerce conversion & product discovery. You will watch your work come to life by partnering with dedicated product & software engineering teams to deploy your algorithms into production.\n\nProjects you are likely to own in this role include:\n\nProduct Recommendation Algorithms (e.g., product discovery & upsell algorithms)\n\nFull Funnel Customer Segmentation (e.g., algorithmically define customer segments and stream segments to other tools such as our CRM or ad networks)\n\nInternal Optimization Algorithms (e.g., attribution models, sales propensity algorithms)\n\nAt Savage X Fenty you can expect to use Python and SQL every day. For larger projects requiring scale or automation you’ll likely be working with DataBricks and Airflow. While these are our defaults, you will have the flexibility to use tools that allow you to best fulfill your role. Additionally, we strongly believe in the need for ongoing education and so will encourage you to explore new technologies and modeling methods on a regular basis.\n\n\n\nYou’re the ideal candidate if you’re incredibly curious & see opportunities for data science applications in everything you do. Working smarter, not harder, is core to your DNA. You’re invigorated by the opportunity to learn that next tool or skill, and you come up with clever solutions to difficult problems. As much as you learned in school or at work, you’ve probably learned even more during your late-night hacking sessions. You take initiative, can work without supervision, begin projects independently, and are technically capable with a deep desire to become an expert in data science applications for ecommerce. You’re seeking a collaborative environment in which you can work alongside other technology experts to find the best answer and win as a team.\n\nThis position will report to the Director of Data Analytics on the Savage X Fenty Analytics Team. The position will also have an informal reporting line to the Sr. Director of Data Science on the TechStyleOS Architecture & Sciences team. We are a creative, ambitious, & fun-loving team who believes data products should be collaboratively designed, impactful to the business, and customized for the end user. Our analytics team acts as strategic partners to the business, making an impact by merging data with a deep understanding of the Savage customer experience.\n\nThis position will be based in El Segundo, California. For the right candidate, we will consider full-time remote work.\n\nWHY WORK IN DATA SCIENCE AT SAVAGE X?\n\nWork within a community of data scientists through our parent company TechStyle Fashion Group & our sister brand Fabletics, but be the first Data Scientist dedicated to the Savage X brand. This role will design the foundation for Savage’s future data science initiatives & experience fast paced growth\n\nDedicated resources to support you – Savage X is investing heavily in data science and has staffed dedicated engineering & product management to support your initiatives\n\nIndustry leading data technology stack – Snowflake, DataBricks, Segment Customer Data Platform, Apache Airflow, modeled reporting data warehouse, & more\n\nData-driven mindset is deeply foundational to the culture at Savage X; information flows freely throughout our organization and every key decision we make is backed by analysis\n\nBe a part of the larger Data Analytics organization at TechStyle Fashion Group (60+ team members); mentor & be mentored by our architects, scientists, analysts, & engineers\n\n\n\nLeverage our advanced tech stack, your knowledge of data science methods & models, and your partnerships with our senior engineers, scientists, and architects to determine the best approaches for algorithm development and implementation\n\nOwn algorithm development projects from start-to-end: design, develop, QA, deploy, experiment, and analyze\n\nPartner with dedicated product management & software engineering teams to implement data science algorithms onto our consumer-facing ecommerce website\n\nPartner with dedicated analysts to produce data visualizations, advanced reports, measurement and statistical models that explain and track algorithm performance against business KPIs\n\nPartner with the business to identify & understand opportunities for data science applications\n\nProvide thought leadership and data support to the business & other analytics team members around design, execution, and measurement of business KPIs\n\nCollaborate with other data scientists across our organization to share best practices, learn new techniques, and foster our organizational culture where data is central to decision making\n\n\n\nHigh degree of personal integrity, strong work ethic, & a desire to learn and grow in this role\n\n2+ years of work experience as a Data Scientist or Machine Learning Engineer\n\nFluent in R or Python (Python preferred) & SQL\n\nFamiliarity with Machine Learning techniques (e.g. classification, clustering, regularization, optimization, dimension reduction, feature engineering)\n\nStrong understanding of CS fundamentals (e.g. algorithms and data structures)\n\nExperience with attribution, causal inference, experimental design, and AB testing methods\n\nGood communication skills and ability to explain complex topics to a non-technical audience\n\n\n\nExperience partnering with product management & software engineering teams to implement algorithms into a production environment\n\nDegree or Advanced Degree in Statistics, Computer Science, or related fields\n\nExperience with Git and/or Airflow\n\nExperience with data visualization tools such as Tableau\n\nExperience in e-commerce, subscription models, and/or direct-to-consumer brands\n\nFamiliarity with web analytics tools & concepts (Google Analytics, pixel tracking, Segment Customer Data Platform or comparable tools)\n\n\n\nTechStyleOS is the globally integrated Operations and Services provider behind some of the fastest growing online fashion brands in history, including Fabletics, Savage X Fenty, JustFab, ShoeDazzle, and FabKids. With capabilities spanning technology, data science, supply chain management, fulfillment, customer service, and more, we help brands launch, scale and grow—across product categories and geographically. From predictive analytics to data-driven marketing and attribution, our unique approach is powered by our proprietary, end-to-end tech platform that enables the brands we serve to deliver a level of personalization, value, and satisfaction that are unrivaled in the fashion industry.\n\nSavage X Inc.is an equal opportunity employer. We recruit, employ, compensate, develop, and promote regardless of race, national origin, religion, sex, sexual orientation, gender identity, age, disability, genetic information, veteran status, and other protected status as required by applicable. At Savage X Inc. , we champion a vibrant workplace culture that thrives on diversity law and do not tolerate discrimination or harassment. We are one team from many backgrounds, innovating through diversity of individuals, who are driven by passion for creating an inclusive space for all. Savage X Inc. will continue to champion a workplace culture that prizes diversity and inclusivity.\n\nWe encourage you to apply regardless of meeting all qualifications and/or requirements.",[],[]\nWestern Governors University,Data Scientist-2,"St Louis, MO",,https://www.linkedin.com/jobs/view/2718750842/?eBP=CwEAAAF8A9ofOjpba68ujoLXQAaOCBXYiS4C1yUTdLuyzCZe9eu8Ol6E5B1OavyEuBokToqXvI8orCg9mTa7e7zpzyV9cy10rVkKoDvZEPBDm1du-SyxnPgFICjxXnkLuO4a476oKPYJHgNsT_wxWcVM7UPEe_A4rGFK3u5Nxocz6TO1M6QF-5VfM-4C6pvZ-cryEakyxdZm6GaHw7p9zbMvWyaV6i1CvmDXy27crdTMH0Tc23b0hvt7S-fanNHX4dGjk06Is5AS7iuF-deOP1A46W0iSZPaIhLkVkBxOTTw8Wp12qn_2fxTdloxilj5f3cSIkJJSt5CyCNX3COteQXhYjO8geRyhwPGFGyDICcz7CEBCngNc2CFZt-0BfY9piw&recommendedFlavor=COMPANY_RECRUIT&refId=uAGrvRCfo9q5%2BNk5EGGm4Q%3D%3D&trackingId=nI03Xvg4nBirIwj8TRNSAQ%3D%3D&trk=flagship3_search_srp_jobs,"About the job\nIf you’re passionate about building a better future for individuals, communities, and our country—and you’re committed to working hard to play your part in building that future—consider WGU as the next step in your career.\n\nDriven by a mission to expand access to higher education through online, competency-based degree programs, WGU is also committed to being a great place to work for a diverse workforce of student-focused professionals. The university has pioneered a new way to learn in the 21st century, one that has received praise from academic, industry, government, and media leaders. Whatever your role, working for WGU gives you a part to play in helping students graduate, creating a better tomorrow for themselves and their families.\n\n\n\n\n\n:\n\n\n\n\n\nAs an equal opportunity employer, WGU recognizes that our strength lies in our people. We are committed to diversity.",[],[]\nCarShield,Data Scientist,"St Louis, MO","50 minutes ago\nWithin the past 24 hours",https://www.linkedin.com/jobs/view/2723209281/?eBP=JOB_SEARCH_ORGANIC&recommendedFlavor=COMPANY_RECRUIT&refId=uAGrvRCfo9q5%2BNk5EGGm4Q%3D%3D&trackingId=KgTMJ%2FOU15u5GSRxFma6BA%3D%3D&trk=flagship3_search_srp_jobs,"About the job\nJob Description\nResponsible for overseeing the collection, storage and interpretation of data for businesses. Their duties include sifting through data points to create organized categories, comparing data points to current company processes and writing reports outlining business predictions or proposals.",[],[]\nAmerican Express Global Business Travel,Data Scientist,"Evansville, IN",6 days ago,https://www.linkedin.com/jobs/view/2716701280/?eBP=JOB_SEARCH_ORGANIC&recommendedFlavor=ACTIVELY_HIRING_COMPANY&refId=uAGrvRCfo9q5%2BNk5EGGm4Q%3D%3D&trackingId=%2FNnG2%2FT8eaQ5Auu0r1LwgQ%3D%3D&trk=flagship3_search_srp_jobs,"About the job\nThe Candidate Is Expected To Possess These Key Skills/technologies\n\nThe data science solutions engineer will be a member of the data analytics team and will lead efforts around building big data, data science, data quality, and BI/MI/AI solutions. An ideal candidate will be a The data science associate will have a growth-oriented, lean-startup mindset for building hands-on data science solutions. The ideal candidate will propose, experiment, execute, and operationalize advanced predictive, preemptive data solutions designed to help traveler, travel-manager, supplier, and client outcomes. The role will span full-scale product, enterprise, and operational data science. The candidate will focus and thrive in a hands-on applied role; he/she will demonstrate a strong penchant for quantitative, collaborative, outcome-oriented solutions-engineering.\n\n\n\n\n\n\n\nIndia>Virtual Location\n\nIt is our policy to provide equal employment opportunities to all individuals based on job-related qualifications and ability to perform a job, without regard to age, gender, gender identity, sexual orientation, race, color, religion, creed, national origin, disability, genetic information, veteran status, citizenship or marital status, and to maintain a non-discriminatory environment free from intimidation, harassment or bias based upon these grounds.\n\nPosted 6 Days Ago Full time J-46605\n\nAmerican Express Global Business Travel (GBT) is the world’s leading business partner for managed travel. We help companies and employees prosper by making sure travelers are present where and when it matters. We keep global business moving with the powerful backing of 16,000 travel professionals in more than 140 countries. Companies of all sizes, and in all places, rely on GBT to provide travel management services, organize meetings and events, and deliver business travel consulting.",[],[]\nKPMG US,"Associate, Data Scientist","Chicago, IL",,https://www.linkedin.com/jobs/view/2715182807/?eBP=CwEAAAF8A9ofOnXwJUuycM2gGRL1mcgrhKEvGOAPq7WvcuqVfhF3v31fFIUXMUZTB2_KdQBZae-zIVr4TaQH32qoMce5QiuRkyz35Qe4NunBDe1tO5oIPM_jRd0DRVV1Q2RE2NsRab1c65uetiOURFT5UacwF26coAIsRg_OLs_YoY_77ZEEy1w6kTyWThm4DdS0MF9eZsoLFRxcEZjVZPeHkjucUMmMlgDkGFolStofkAtovBw2_NeONzmFwJOWVe1GKQ1XqLioi_MqRW4kb3iJnvdR5E8PAb5PCjiNjJEfuIXO63QpyODR7y7X0dEhMCCkj_x1tLu5T0PQeNlCeZkpp7nWdyWZQtRzOXNNpH9yPYBeaNL_b3b8W8FSewL2XfI&recommendedFlavor=COMPANY_RECRUIT&refId=uAGrvRCfo9q5%2BNk5EGGm4Q%3D%3D&trackingId=tWMAG1KeTQs1iil6CAtrmQ%3D%3D&trk=flagship3_search_srp_jobs,"About the job\nRequisition Number: 70881 - 31\n\nDescription\n\nInnovate. Collaborate. Build. Create. Solve. The KPMG Digital Lighthouse is KPMG\'s award-winning Analytics & AI Center of Excellence recognized by clients and leading analyst firms in the US and globally. The KPMG Lighthouse is a curation of specialized technical capabilities and domain experts working across the digital landscape: applied data science, AI, data engineering and insights, software engineering, automation, and big data. Here, you\'ll work with a diverse team of professionals to explore and build solutions for clients in a multiplatform environment.\n\nYou\'ll be an important part of our high-energy, unique, fast-paced, and innovative culture that delivers with the agility of a tech startup and the backing of a leading global consulting firm. In this particular role, you\'ll work specifically in the AI Analytics & Engineering Community within the Digital Lighthouse, on a wide range of projects. From applied AI to optimization to big data platform engineering, your analytical and technical skills will drive real impact in the business world. At KPMG, our commitment to your career development helps to set us apart as an employer. We want to enhance your potential, both for yourself and as a contributor to our firm. That\'s why we provide every opportunity to expand your skills, knowledge and experiences through formal education and training programs, leadership development opportunities, and, as well as informal one-on-one coaching and mentoring from your KPMG colleagues.\n\nKPMG is currently seeking an Associate to join our KPMG Lighthouse - Center of Excellence for Advanced Analytics.\n\n\n\n\n\nKPMG LLP (the U.S. member firm of KPMG International) offers a comprehensive compensation and benefits package. KPMG is an affirmative action-equal opportunity employer. KPMG complies with all applicable federal, state and local laws regarding recruitment and hiring. All qualified applicants are considered for employment without regard to race, color, religion, age, sex, sexual orientation, gender identity, national origin, disability, protected veteran status, or any other category protected by applicable federal, state or local laws. The attached link contains further information regarding the firm\'s compliance with federal, state and local recruitment and hiring laws. No phone calls or agencies please.",[],[]\n"Systems Planning and Analysis, Inc.",Data Scientist - CWMD,"Reston, VA",,https://www.linkedin.com/jobs/view/2719087133/?eBP=CwEAAAF8A9ofOs3Q1pRDNomWkKq8WZKKrxzVFph6K2D4ymCmOH1h4zujhf7yBWfSjCtGRdbAe9Qx1ZFnDclUFpBrbo8MAanx6IoSd6oeFzDujMeur4dsRn-KObiuVvRuoE8jax4zNaj2cL0qgNswrocbKDKdYn82E7vixG1bp6oL35Xs1t4QTILoMHsFU_wTZqMgC7fCMPF3UzzYVoZ7UpLI2jutAFhJUtKKFD94vE5WkDbZOlxsnkXaN96-uctzECAJaz-JWJTbMRDHUek1yOdijC16J7HeR8V1Snd1B3f-lHcwkIyohdLJUUsi0dDpOWpoQNpv7XWOgAXT-NzCdHsRY99xfHcFFJK5r9UEJvFy__j3f60gUpWxie9aT8NO&recommendedFlavor=ACTIVELY_HIRING_COMPANY&refId=uAGrvRCfo9q5%2BNk5EGGm4Q%3D%3D&trackingId=sCAmjQEN8DY8a6u7bP7Yfg%3D%3D&trk=flagship3_search_srp_jobs,"About the job\nOverview\n\nSystems Planning and Analysis, Inc. (SPA) is a well-established and progressive defense contracting company in the DC Metro area. We are a professional services firm established in 1972 that has a long-standing reputation for unrivaled technical and analytical support to some of the top decision makers in the Federal Sector. We do state of the art work and have a cadre of outstanding professionals on our team.\n\nSPA assists the Defense Threat Reduction Agency (DTRA) in developing leading edge technologies to counter WMD in support of CCMDs and transitioning these technologies to services and SOCOM. SPA provides expertise across the full range of chemical, biological, radiological, nuclear and high-yield explosives (CBRNE) WMD, Counter Improvised Threat and Countering Threat Network technologies to support understanding, detection, identification, characterization, denial, control, disabling, defeating, disposing, safeguarding the force, managing consequences, and test and evaluation in support of military and civilian operations. #CJ #IN123\n\n\n\nProvides critical decision and analytic support to the Urgent Solutions Division in the Counter WMD Technologies Department of the Defense Threat Reduction Agency (DTRA). Conducts assessments, demonstrations, analysis, scientific codes, and other decision making in evaluating systems to counter WMD – biological and chemical threats, and counter threat networks. Develops knowledge regarding a stipulated issue through analysis of complex data sets, identifying actionable trends and problems. Uses appropriate methods to creatively explore, mine, analyze and manipulate data sets ranging in size from sparse to petabytes and type (e.g. small number of .pdf text reports, Excel spreadsheets and .csv files to repositories of image or audio data). Interprets results from multiple sources using a variety of techniques, ranging from simple data aggregation via statistical analysis to complex data mining, sensor analysis and learning techniques. Designs, develops, and implements technical solutions in support of concurrent analysis. Supports data models and defines the structure, attributes, and nomenclature of data elements. May evaluate new data sources for adherence to the organization\'s quality standards and ease of integration.",[],[]\nPerficient,Data Scientist,"St Louis, MO",,https://www.linkedin.com/jobs/view/2718055481/?eBP=CwEAAAF8A9ofOhOHpkH95U2fvN9F-goU76IrWGZ2_h1PEIqUbFxqxI6w3ypUfMSWfMRpTGEJDX9iicxg3Is1hE7MJg4ixQ2ZJfmdAFAR38WMuWQ9RdnHIEX4XrSbapYsM3nhi6Iyv6rH9MEC1PpEqmZkvr8JBlfU1asVfgP3pl3rW4IS6tIVJuzERferAoB3ycE-UB94AE92MTfUPPOUagL-zhuIsIcyQ6BMfE6eFGYpZpAHbvdti7-s852GjLAxYFovRGVyerfbSKSeZm6fVVXT2EaQfKYvMN5hBZBBVncwxNfzaaMBbKZ9moxmBg76BZ3UfB6YOntWLvvf06jI4VVqLMZ_BYq4iT8Jnp-YKt2dJxnECW-9zW66IbRoeRPT&recommendedFlavor=COMPANY_RECRUIT&refId=uAGrvRCfo9q5%2BNk5EGGm4Q%3D%3D&trackingId=UE7bblhxeqWJV52%2F9JWJew%3D%3D&trk=flagship3_search_srp_jobs,"About the job\nOverview\n\nAt Perficient you’ll deliver mission-critical technology and business solutions to Fortune 500 companies and some of the most recognized brands on the planet. And you’ll do it with cutting-edge technologies, thanks to our close partnerships with the world’s biggest vendors. Our network of offices across North America, as well as locations in India and China, will give you the opportunity to spread your wings, too.\n\nWe’re proud to be publicly recognized as a “Top Workplace” year after year. This is due, in no small part, to our entrepreneurial attitude and collaborative spirit that sets us apart and keeps our colleagues impassioned, driven, and fulfilled.\n\nPerficient currently has a career opportunity for a .\n\n\n\nThe role of the Data Scientist is for individuals passionate about identifying and delivering the right Business solution for each client using AI/ML. Our Data Scientists are keen to understand our customer needs, processes and pain points to determine the success factors and evaluation criteria that will needed to measure the effectiveness of an ML model.\n\nThe Data Scientist will be involved in the strategic planning of an engagement or helping the client make decisions about their future AI/ML roadmap and vision. Once the project as begun, the Data Scientist will be responsible for the execution of our established methodology, work with customer and/or the teams data engineer to identify data ingestion and transformation needs, exploration of the data and reporting findings, modeling and evaluation of training iterations. It is a key part of the role to be able to explain in non-technical terms the chosen modeling approach and findings from data exploration or training results.\n\nThe Data Scientist will work with Senior Project Managers to assist with daily operations exercising time management, communication and collaboration in a fast-paced environment to ensure the successful delivery of projects. The Data Scientist will interface with Perficient technical and business delivery personnel, as well as vendors and customers on a regular basis. May mentor junior data scientists.\n\n\n\n\n\n\n\nPerficient full-time employees receive complete and competitive benefits. We offer a collaborative work environment, competitive compensation, generous work/life opportunities and an outstanding benefits package that includes paid time off plus holidays. In addition, all colleagues are eligible for a number of rewards and recognition programs including billable bonus opportunities. Encouraging a healthy work/life balance and providing our colleagues great benefits are just part of what makes Perficient a great place to work.\n\n\n\nPerficient is the leading digital transformation consulting firm serving Global 2000 and enterprise customers throughout North America. With unparalleled information technology, management consulting and creative capabilities, Perficient and its Perficient Digital agency deliver vision, execution and value with outstanding digital experience, business optimization and industry solutions.\n\nOur work enables clients to improve productivity and competitiveness; grow and strengthen relationships with customers, suppliers and partners; and reduce costs. Perficient\'s professionals serve clients from a network of offices across North America and offshore locations in India and China. Traded on the Nasdaq Global Select Market, Perficient is a member of the Russell 2000 index and the S&P SmallCap 600 index.\n\nPerficient is an equal opportunity employer and all qualified applicants will receive consideration for employment without regard to race, color, religion, sex, national, origin, disability status, protected veteran status, or any other characteristic protected by law.\n\nThe above statements are not intended to be a complete statement of job content, rather to act as a guide to the essential functions performed by the employee assigned to this classification. Management retains the discretion to add or change the duties of the position at any time.\n\nSelect work authorization questions to ask when applicants apply",[],[]\nSavage X Fenty: Lingerie by Rihanna,Data Scientist,"El Segundo, CA",,https://www.linkedin.com/jobs/view/2721710042/?eBP=CwEAAAF8A9ofOhPzbWsStxaNEgpMLIbvO6Vvpf-kp8RGwvYOJKGphyyakdc_4SGsjm2VeRAGjmk-vJ6l9A5H_dap2I3Kpoi5h6gKOdZGPr43fehHk5BqkiDkbvKki_to05FvWLinOBzurpjsMFG3JoeqUJ8xRReTFcidZnHYUQE6jUxh0nf-LNmAPuQp7YZEmPEps45wTFpgh1xQa_nwnLky1x-nzte_8YwEIsmHKQ5z2VTOvDevWj_NNLxyfvp4hDKsNbBNyQC_28gSNPkqkg6iN2yFOum-URpP05X-BwoG-gN9HPsuQJs-bhqDslt8i6wwag517FTdUMMYWqa29zUtuHYFUf1ei5iEh0ffOBNdGGDafvdOB4z8Oqp3hxLnHhY&recommendedFlavor=ACTIVELY_HIRING_COMPANY&refId=uAGrvRCfo9q5%2BNk5EGGm4Q%3D%3D&trackingId=WJuu5WmPKTuvZRyUdmNdtA%3D%3D&trk=flagship3_search_srp_jobs,"About the job\nJob DescriptionSavage X Fenty is looking for a Data Scientist. Co-founded by music and fashion icon Rihanna, Savage X Fenty is the first line of lingerie that celebrates and speaks to all shades and shapes of people, and celebrates fearlessness, confidence and inclusivity.\n\nHOW DO YOU FIT IN?\n\nAs the Data Scientist, you will drive innovation in our customer shopping experience by providing the algorithms that power recommendation and personalization features across our ecommerce website. You will collaborate closely with the Data Analytics organization, the Global Technology organization, and the Savage X business to develop high-impact solutions to key optimization opportunities such as ecommerce conversion & product discovery. You will watch your work come to life by partnering with dedicated product & software engineering teams to deploy your algorithms into production.\n\nProjects you are likely to own in this role include:\n\nProduct Recommendation Algorithms (e.g., product discovery & upsell algorithms)\n\nFull Funnel Customer Segmentation (e.g., algorithmically define customer segments and stream segments to other tools such as our CRM or ad networks)\n\nInternal Optimization Algorithms (e.g., attribution models, sales propensity algorithms)\n\nAt Savage X Fenty you can expect to use Python and SQL every day. For larger projects requiring scale or automation you’ll likely be working with DataBricks and Airflow. While these are our defaults, you will have the flexibility to use tools that allow you to best fulfill your role. Additionally, we strongly believe in the need for ongoing education and so will encourage you to explore new technologies and modeling methods on a regular basis.\n\n\n\nYou’re the ideal candidate if you’re incredibly curious & see opportunities for data science applications in everything you do. Working smarter, not harder, is core to your DNA. You’re invigorated by the opportunity to learn that next tool or skill, and you come up with clever solutions to difficult problems. As much as you learned in school or at work, you’ve probably learned even more during your late-night hacking sessions. You take initiative, can work without supervision, begin projects independently, and are technically capable with a deep desire to become an expert in data science applications for ecommerce. You’re seeking a collaborative environment in which you can work alongside other technology experts to find the best answer and win as a team.\n\nThis position will report to the Director of Data Analytics on the Savage X Fenty Analytics Team. The position will also have an informal reporting line to the Sr. Director of Data Science on the TechStyleOS Architecture & Sciences team. We are a creative, ambitious, & fun-loving team who believes data products should be collaboratively designed, impactful to the business, and customized for the end user. Our analytics team acts as strategic partners to the business, making an impact by merging data with a deep understanding of the Savage customer experience.\n\nThis position will be based in El Segundo, California. For the right candidate, we will consider full-time remote work.\n\nWHY WORK IN DATA SCIENCE AT SAVAGE X?\n\nWork within a community of data scientists through our parent company TechStyle Fashion Group & our sister brand Fabletics, but be the first Data Scientist dedicated to the Savage X brand. This role will design the foundation for Savage’s future data science initiatives & experience fast paced growth\n\nDedicated resources to support you – Savage X is investing heavily in data science and has staffed dedicated engineering & product management to support your initiatives\n\nIndustry leading data technology stack – Snowflake, DataBricks, Segment Customer Data Platform, Apache Airflow, modeled reporting data warehouse, & more\n\nData-driven mindset is deeply foundational to the culture at Savage X; information flows freely throughout our organization and every key decision we make is backed by analysis\n\nBe a part of the larger Data Analytics organization at TechStyle Fashion Group (60+ team members); mentor & be mentored by our architects, scientists, analysts, & engineers\n\n\n\nLeverage our advanced tech stack, your knowledge of data science methods & models, and your partnerships with our senior engineers, scientists, and architects to determine the best approaches for algorithm development and implementation\n\nOwn algorithm development projects from start-to-end: design, develop, QA, deploy, experiment, and analyze\n\nPartner with dedicated product management & software engineering teams to implement data science algorithms onto our consumer-facing ecommerce website\n\nPartner with dedicated analysts to produce data visualizations, advanced reports, measurement and statistical models that explain and track algorithm performance against business KPIs\n\nPartner with the business to identify & understand opportunities for data science applications\n\nProvide thought leadership and data support to the business & other analytics team members around design, execution, and measurement of business KPIs\n\nCollaborate with other data scientists across our organization to share best practices, learn new techniques, and foster our organizational culture where data is central to decision making\n\n\n\nHigh degree of personal integrity, strong work ethic, & a desire to learn and grow in this role\n\n2+ years of work experience as a Data Scientist or Machine Learning Engineer\n\nFluent in R or Python (Python preferred) & SQL\n\nFamiliarity with Machine Learning techniques (e.g. classification, clustering, regularization, optimization, dimension reduction, feature engineering)\n\nStrong understanding of CS fundamentals (e.g. algorithms and data structures)\n\nExperience with attribution, causal inference, experimental design, and AB testing methods\n\nGood communication skills and ability to explain complex topics to a non-technical audience\n\n\n\nExperience partnering with product management & software engineering teams to implement algorithms into a production environment\n\nDegree or Advanced Degree in Statistics, Computer Science, or related fields\n\nExperience with Git and/or Airflow\n\nExperience with data visualization tools such as Tableau\n\nExperience in e-commerce, subscription models, and/or direct-to-consumer brands\n\nFamiliarity with web analytics tools & concepts (Google Analytics, pixel tracking, Segment Customer Data Platform or comparable tools)\n\n\n\nTechStyleOS is the globally integrated Operations and Services provider behind some of the fastest growing online fashion brands in history, including Fabletics, Savage X Fenty, JustFab, ShoeDazzle, and FabKids. With capabilities spanning technology, data science, supply chain management, fulfillment, customer service, and more, we help brands launch, scale and grow—across product categories and geographically. From predictive analytics to data-driven marketing and attribution, our unique approach is powered by our proprietary, end-to-end tech platform that enables the brands we serve to deliver a level of personalization, value, and satisfaction that are unrivaled in the fashion industry.\n\nSavage X Inc.is an equal opportunity employer. We recruit, employ, compensate, develop, and promote regardless of race, national origin, religion, sex, sexual orientation, gender identity, age, disability, genetic information, veteran status, and other protected status as required by applicable. At Savage X Inc. , we champion a vibrant workplace culture that thrives on diversity law and do not tolerate discrimination or harassment. We are one team from many backgrounds, innovating through diversity of individuals, who are driven by passion for creating an inclusive space for all. Savage X Inc. will continue to champion a workplace culture that prizes diversity and inclusivity.\n\nWe encourage you to apply regardless of meeting all qualifications and/or requirements.",[],[]\nWestern Governors University,Data Scientist-2,"St Louis, MO",,https://www.linkedin.com/jobs/view/2718750842/?eBP=CwEAAAF8A9ofOjpba68ujoLXQAaOCBXYiS4C1yUTdLuyzCZe9eu8Ol6E5B1OavyEuBokToqXvI8orCg9mTa7e7zpzyV9cy10rVkKoDvZEPBDm1du-SyxnPgFICjxXnkLuO4a476oKPYJHgNsT_wxWcVM7UPEe_A4rGFK3u5Nxocz6TO1M6QF-5VfM-4C6pvZ-cryEakyxdZm6GaHw7p9zbMvWyaV6i1CvmDXy27crdTMH0Tc23b0hvt7S-fanNHX4dGjk06Is5AS7iuF-deOP1A46W0iSZPaIhLkVkBxOTTw8Wp12qn_2fxTdloxilj5f3cSIkJJSt5CyCNX3COteQXhYjO8geRyhwPGFGyDICcz7CEBCngNc2CFZt-0BfY9piw&recommendedFlavor=COMPANY_RECRUIT&refId=uAGrvRCfo9q5%2BNk5EGGm4Q%3D%3D&trackingId=nI03Xvg4nBirIwj8TRNSAQ%3D%3D&trk=flagship3_search_srp_jobs,"About the job\nIf you’re passionate about building a better future for individuals, communities, and our country—and you’re committed to working hard to play your part in building that future—consider WGU as the next step in your career.\n\nDriven by a mission to expand access to higher education through online, competency-based degree programs, WGU is also committed to being a great place to work for a diverse workforce of student-focused professionals. The university has pioneered a new way to learn in the 21st century, one that has received praise from academic, industry, government, and media leaders. Whatever your role, working for WGU gives you a part to play in helping students graduate, creating a better tomorrow for themselves and their families.\n\n\n\n\n\n:\n\n\n\n\n\nAs an equal opportunity employer, WGU recognizes that our strength lies in our people. We are committed to diversity.",[],[]\nCarShield,Data Scientist,"St Louis, MO","50 minutes ago\nWithin the past 24 hours",https://www.linkedin.com/jobs/view/2723209281/?eBP=JOB_SEARCH_ORGANIC&recommendedFlavor=COMPANY_RECRUIT&refId=uAGrvRCfo9q5%2BNk5EGGm4Q%3D%3D&trackingId=KgTMJ%2FOU15u5GSRxFma6BA%3D%3D&trk=flagship3_search_srp_jobs,"About the job\nJob Description\nResponsible for overseeing the collection, storage and interpretation of data for businesses. Their duties include sifting through data points to create organized categories, comparing data points to current company processes and writing reports outlining business predictions or proposals.",[],[]\nAmerican Express Global Business Travel,Data Scientist,"Evansville, IN",6 days ago,https://www.linkedin.com/jobs/view/2716701280/?eBP=JOB_SEARCH_ORGANIC&recommendedFlavor=ACTIVELY_HIRING_COMPANY&refId=uAGrvRCfo9q5%2BNk5EGGm4Q%3D%3D&trackingId=%2FNnG2%2FT8eaQ5Auu0r1LwgQ%3D%3D&trk=flagship3_search_srp_jobs,"About the job\nThe Candidate Is Expected To Possess These Key Skills/technologies\n\nThe data science solutions engineer will be a member of the data analytics team and will lead efforts around building big data, data science, data quality, and BI/MI/AI solutions. An ideal candidate will be a The data science associate will have a growth-oriented, lean-startup mindset for building hands-on data science solutions. The ideal candidate will propose, experiment, execute, and operationalize advanced predictive, preemptive data solutions designed to help traveler, travel-manager, supplier, and client outcomes. The role will span full-scale product, enterprise, and operational data science. The candidate will focus and thrive in a hands-on applied role; he/she will demonstrate a strong penchant for quantitative, collaborative, outcome-oriented solutions-engineering.\n\n\n\n\n\n\n\nIndia>Virtual Location\n\nIt is our policy to provide equal employment opportunities to all individuals based on job-related qualifications and ability to perform a job, without regard to age, gender, gender identity, sexual orientation, race, color, religion, creed, national origin, disability, genetic information, veteran status, citizenship or marital status, and to maintain a non-discriminatory environment free from intimidation, harassment or bias based upon these grounds.\n\nPosted 6 Days Ago Full time J-46605\n\nAmerican Express Global Business Travel (GBT) is the world’s leading business partner for managed travel. We help companies and employees prosper by making sure travelers are present where and when it matters. We keep global business moving with the powerful backing of 16,000 travel professionals in more than 140 countries. Companies of all sizes, and in all places, rely on GBT to provide travel management services, organize meetings and events, and deliver business travel consulting.",[],[]\nKPMG US,"Associate, Data Scientist","Chicago, IL",,https://www.linkedin.com/jobs/view/2715182807/?eBP=CwEAAAF8A9ofOnXwJUuycM2gGRL1mcgrhKEvGOAPq7WvcuqVfhF3v31fFIUXMUZTB2_KdQBZae-zIVr4TaQH32qoMce5QiuRkyz35Qe4NunBDe1tO5oIPM_jRd0DRVV1Q2RE2NsRab1c65uetiOURFT5UacwF26coAIsRg_OLs_YoY_77ZEEy1w6kTyWThm4DdS0MF9eZsoLFRxcEZjVZPeHkjucUMmMlgDkGFolStofkAtovBw2_NeONzmFwJOWVe1GKQ1XqLioi_MqRW4kb3iJnvdR5E8PAb5PCjiNjJEfuIXO63QpyODR7y7X0dEhMCCkj_x1tLu5T0PQeNlCeZkpp7nWdyWZQtRzOXNNpH9yPYBeaNL_b3b8W8FSewL2XfI&recommendedFlavor=COMPANY_RECRUIT&refId=uAGrvRCfo9q5%2BNk5EGGm4Q%3D%3D&trackingId=tWMAG1KeTQs1iil6CAtrmQ%3D%3D&trk=flagship3_search_srp_jobs,"About the job\nRequisition Number: 70881 - 31\n\nDescription\n\nInnovate. Collaborate. Build. Create. Solve. The KPMG Digital Lighthouse is KPMG\'s award-winning Analytics & AI Center of Excellence recognized by clients and leading analyst firms in the US and globally. The KPMG Lighthouse is a curation of specialized technical capabilities and domain experts working across the digital landscape: applied data science, AI, data engineering and insights, software engineering, automation, and big data. Here, you\'ll work with a diverse team of professionals to explore and build solutions for clients in a multiplatform environment.\n\nYou\'ll be an important part of our high-energy, unique, fast-paced, and innovative culture that delivers with the agility of a tech startup and the backing of a leading global consulting firm. In this particular role, you\'ll work specifically in the AI Analytics & Engineering Community within the Digital Lighthouse, on a wide range of projects. From applied AI to optimization to big data platform engineering, your analytical and technical skills will drive real impact in the business world. At KPMG, our commitment to your career development helps to set us apart as an employer. We want to enhance your potential, both for yourself and as a contributor to our firm. That\'s why we provide every opportunity to expand your skills, knowledge and experiences through formal education and training programs, leadership development opportunities, and, as well as informal one-on-one coaching and mentoring from your KPMG colleagues.\n\nKPMG is currently seeking an Associate to join our KPMG Lighthouse - Center of Excellence for Advanced Analytics.\n\n\n\n\n\nKPMG LLP (the U.S. member firm of KPMG International) offers a comprehensive compensation and benefits package. KPMG is an affirmative action-equal opportunity employer. KPMG complies with all applicable federal, state and local laws regarding recruitment and hiring. All qualified applicants are considered for employment without regard to race, color, religion, age, sex, sexual orientation, gender identity, national origin, disability, protected veteran status, or any other category protected by applicable federal, state or local laws. The attached link contains further information regarding the firm\'s compliance with federal, state and local recruitment and hiring laws. No phone calls or agencies please.",[],[]\n"Systems Planning and Analysis, Inc.",Data Scientist - CWMD,"Reston, VA",,https://www.linkedin.com/jobs/view/2719087133/?eBP=CwEAAAF8A9ofOs3Q1pRDNomWkKq8WZKKrxzVFph6K2D4ymCmOH1h4zujhf7yBWfSjCtGRdbAe9Qx1ZFnDclUFpBrbo8MAanx6IoSd6oeFzDujMeur4dsRn-KObiuVvRuoE8jax4zNaj2cL0qgNswrocbKDKdYn82E7vixG1bp6oL35Xs1t4QTILoMHsFU_wTZqMgC7fCMPF3UzzYVoZ7UpLI2jutAFhJUtKKFD94vE5WkDbZOlxsnkXaN96-uctzECAJaz-JWJTbMRDHUek1yOdijC16J7HeR8V1Snd1B3f-lHcwkIyohdLJUUsi0dDpOWpoQNpv7XWOgAXT-NzCdHsRY99xfHcFFJK5r9UEJvFy__j3f60gUpWxie9aT8NO&recommendedFlavor=ACTIVELY_HIRING_COMPANY&refId=uAGrvRCfo9q5%2BNk5EGGm4Q%3D%3D&trackingId=sCAmjQEN8DY8a6u7bP7Yfg%3D%3D&trk=flagship3_search_srp_jobs,"About the job\nOverview\n\nSystems Planning and Analysis, Inc. (SPA) is a well-established and progressive defense contracting company in the DC Metro area. We are a professional services firm established in 1972 that has a long-standing reputation for unrivaled technical and analytical support to some of the top decision makers in the Federal Sector. We do state of the art work and have a cadre of outstanding professionals on our team.\n\nSPA assists the Defense Threat Reduction Agency (DTRA) in developing leading edge technologies to counter WMD in support of CCMDs and transitioning these technologies to services and SOCOM. SPA provides expertise across the full range of chemical, biological, radiological, nuclear and high-yield explosives (CBRNE) WMD, Counter Improvised Threat and Countering Threat Network technologies to support understanding, detection, identification, characterization, denial, control, disabling, defeating, disposing, safeguarding the force, managing consequences, and test and evaluation in support of military and civilian operations. #CJ #IN123\n\n\n\nProvides critical decision and analytic support to the Urgent Solutions Division in the Counter WMD Technologies Department of the Defense Threat Reduction Agency (DTRA). Conducts assessments, demonstrations, analysis, scientific codes, and other decision making in evaluating systems to counter WMD – biological and chemical threats, and counter threat networks. Develops knowledge regarding a stipulated issue through analysis of complex data sets, identifying actionable trends and problems. Uses appropriate methods to creatively explore, mine, analyze and manipulate data sets ranging in size from sparse to petabytes and type (e.g. small number of .pdf text reports, Excel spreadsheets and .csv files to repositories of image or audio data). Interprets results from multiple sources using a variety of techniques, ranging from simple data aggregation via statistical analysis to complex data mining, sensor analysis and learning techniques. Designs, develops, and implements technical solutions in support of concurrent analysis. Supports data models and defines the structure, attributes, and nomenclature of data elements. May evaluate new data sources for adherence to the organization\'s quality standards and ease of integration.",[],[]\nPerficient,Data Scientist,"St Louis, MO",,https://www.linkedin.com/jobs/view/2718055481/?eBP=CwEAAAF8A9ofOhOHpkH95U2fvN9F-goU76IrWGZ2_h1PEIqUbFxqxI6w3ypUfMSWfMRpTGEJDX9iicxg3Is1hE7MJg4ixQ2ZJfmdAFAR38WMuWQ9RdnHIEX4XrSbapYsM3nhi6Iyv6rH9MEC1PpEqmZkvr8JBlfU1asVfgP3pl3rW4IS6tIVJuzERferAoB3ycE-UB94AE92MTfUPPOUagL-zhuIsIcyQ6BMfE6eFGYpZpAHbvdti7-s852GjLAxYFovRGVyerfbSKSeZm6fVVXT2EaQfKYvMN5hBZBBVncwxNfzaaMBbKZ9moxmBg76BZ3UfB6YOntWLvvf06jI4VVqLMZ_BYq4iT8Jnp-YKt2dJxnECW-9zW66IbRoeRPT&recommendedFlavor=COMPANY_RECRUIT&refId=uAGrvRCfo9q5%2BNk5EGGm4Q%3D%3D&trackingId=UE7bblhxeqWJV52%2F9JWJew%3D%3D&trk=flagship3_search_srp_jobs,"About the job\nOverview\n\nAt Perficient you’ll deliver mission-critical technology and business solutions to Fortune 500 companies and some of the most recognized brands on the planet. And you’ll do it with cutting-edge technologies, thanks to our close partnerships with the world’s biggest vendors. Our network of offices across North America, as well as locations in India and China, will give you the opportunity to spread your wings, too.\n\nWe’re proud to be publicly recognized as a “Top Workplace” year after year. This is due, in no small part, to our entrepreneurial attitude and collaborative spirit that sets us apart and keeps our colleagues impassioned, driven, and fulfilled.\n\nPerficient currently has a career opportunity for a .\n\n\n\nThe role of the Data Scientist is for individuals passionate about identifying and delivering the right Business solution for each client using AI/ML. Our Data Scientists are keen to understand our customer needs, processes and pain points to determine the success factors and evaluation criteria that will needed to measure the effectiveness of an ML model.\n\nThe Data Scientist will be involved in the strategic planning of an engagement or helping the client make decisions about their future AI/ML roadmap and vision. Once the project as begun, the Data Scientist will be responsible for the execution of our established methodology, work with customer and/or the teams data engineer to identify data ingestion and transformation needs, exploration of the data and reporting findings, modeling and evaluation of training iterations. It is a key part of the role to be able to explain in non-technical terms the chosen modeling approach and findings from data exploration or training results.\n\nThe Data Scientist will work with Senior Project Managers to assist with daily operations exercising time management, communication and collaboration in a fast-paced environment to ensure the successful delivery of projects. The Data Scientist will interface with Perficient technical and business delivery personnel, as well as vendors and customers on a regular basis. May mentor junior data scientists.\n\n\n\n\n\n\n\nPerficient full-time employees receive complete and competitive benefits. We offer a collaborative work environment, competitive compensation, generous work/life opportunities and an outstanding benefits package that includes paid time off plus holidays. In addition, all colleagues are eligible for a number of rewards and recognition programs including billable bonus opportunities. Encouraging a healthy work/life balance and providing our colleagues great benefits are just part of what makes Perficient a great place to work.\n\n\n\nPerficient is the leading digital transformation consulting firm serving Global 2000 and enterprise customers throughout North America. With unparalleled information technology, management consulting and creative capabilities, Perficient and its Perficient Digital agency deliver vision, execution and value with outstanding digital experience, business optimization and industry solutions.\n\nOur work enables clients to improve productivity and competitiveness; grow and strengthen relationships with customers, suppliers and partners; and reduce costs. Perficient\'s professionals serve clients from a network of offices across North America and offshore locations in India and China. Traded on the Nasdaq Global Select Market, Perficient is a member of the Russell 2000 index and the S&P SmallCap 600 index.\n\nPerficient is an equal opportunity employer and all qualified applicants will receive consideration for employment without regard to race, color, religion, sex, national, origin, disability status, protected veteran status, or any other characteristic protected by law.\n\nThe above statements are not intended to be a complete statement of job content, rather to act as a guide to the essential functions performed by the employee assigned to this classification. Management retains the discretion to add or change the duties of the position at any time.\n\nSelect work authorization questions to ask when applicants apply",[],[]\nSavage X Fenty: Lingerie by Rihanna,Data Scientist,"El Segundo, CA",,https://www.linkedin.com/jobs/view/2721710042/?eBP=CwEAAAF8A9ofOhPzbWsStxaNEgpMLIbvO6Vvpf-kp8RGwvYOJKGphyyakdc_4SGsjm2VeRAGjmk-vJ6l9A5H_dap2I3Kpoi5h6gKOdZGPr43fehHk5BqkiDkbvKki_to05FvWLinOBzurpjsMFG3JoeqUJ8xRReTFcidZnHYUQE6jUxh0nf-LNmAPuQp7YZEmPEps45wTFpgh1xQa_nwnLky1x-nzte_8YwEIsmHKQ5z2VTOvDevWj_NNLxyfvp4hDKsNbBNyQC_28gSNPkqkg6iN2yFOum-URpP05X-BwoG-gN9HPsuQJs-bhqDslt8i6wwag517FTdUMMYWqa29zUtuHYFUf1ei5iEh0ffOBNdGGDafvdOB4z8Oqp3hxLnHhY&recommendedFlavor=ACTIVELY_HIRING_COMPANY&refId=uAGrvRCfo9q5%2BNk5EGGm4Q%3D%3D&trackingId=WJuu5WmPKTuvZRyUdmNdtA%3D%3D&trk=flagship3_search_srp_jobs,"About the job\nJob DescriptionSavage X Fenty is looking for a Data Scientist. Co-founded by music and fashion icon Rihanna, Savage X Fenty is the first line of lingerie that celebrates and speaks to all shades and shapes of people, and celebrates fearlessness, confidence and inclusivity.\n\nHOW DO YOU FIT IN?\n\nAs the Data Scientist, you will drive innovation in our customer shopping experience by providing the algorithms that power recommendation and personalization features across our ecommerce website. You will collaborate closely with the Data Analytics organization, the Global Technology organization, and the Savage X business to develop high-impact solutions to key optimization opportunities such as ecommerce conversion & product discovery. You will watch your work come to life by partnering with dedicated product & software engineering teams to deploy your algorithms into production.\n\nProjects you are likely to own in this role include:\n\nProduct Recommendation Algorithms (e.g., product discovery & upsell algorithms)\n\nFull Funnel Customer Segmentation (e.g., algorithmically define customer segments and stream segments to other tools such as our CRM or ad networks)\n\nInternal Optimization Algorithms (e.g., attribution models, sales propensity algorithms)\n\nAt Savage X Fenty you can expect to use Python and SQL every day. For larger projects requiring scale or automation you’ll likely be working with DataBricks and Airflow. While these are our defaults, you will have the flexibility to use tools that allow you to best fulfill your role. Additionally, we strongly believe in the need for ongoing education and so will encourage you to explore new technologies and modeling methods on a regular basis.\n\n\n\nYou’re the ideal candidate if you’re incredibly curious & see opportunities for data science applications in everything you do. Working smarter, not harder, is core to your DNA. You’re invigorated by the opportunity to learn that next tool or skill, and you come up with clever solutions to difficult problems. As much as you learned in school or at work, you’ve probably learned even more during your late-night hacking sessions. You take initiative, can work without supervision, begin projects independently, and are technically capable with a deep desire to become an expert in data science applications for ecommerce. You’re seeking a collaborative environment in which you can work alongside other technology experts to find the best answer and win as a team.\n\nThis position will report to the Director of Data Analytics on the Savage X Fenty Analytics Team. The position will also have an informal reporting line to the Sr. Director of Data Science on the TechStyleOS Architecture & Sciences team. We are a creative, ambitious, & fun-loving team who believes data products should be collaboratively designed, impactful to the business, and customized for the end user. Our analytics team acts as strategic partners to the business, making an impact by merging data with a deep understanding of the Savage customer experience.\n\nThis position will be based in El Segundo, California. For the right candidate, we will consider full-time remote work.\n\nWHY WORK IN DATA SCIENCE AT SAVAGE X?\n\nWork within a community of data scientists through our parent company TechStyle Fashion Group & our sister brand Fabletics, but be the first Data Scientist dedicated to the Savage X brand. This role will design the foundation for Savage’s future data science initiatives & experience fast paced growth\n\nDedicated resources to support you – Savage X is investing heavily in data science and has staffed dedicated engineering & product management to support your initiatives\n\nIndustry leading data technology stack – Snowflake, DataBricks, Segment Customer Data Platform, Apache Airflow, modeled reporting data warehouse, & more\n\nData-driven mindset is deeply foundational to the culture at Savage X; information flows freely throughout our organization and every key decision we make is backed by analysis\n\nBe a part of the larger Data Analytics organization at TechStyle Fashion Group (60+ team members); mentor & be mentored by our architects, scientists, analysts, & engineers\n\n\n\nLeverage our advanced tech stack, your knowledge of data science methods & models, and your partnerships with our senior engineers, scientists, and architects to determine the best approaches for algorithm development and implementation\n\nOwn algorithm development projects from start-to-end: design, develop, QA, deploy, experiment, and analyze\n\nPartner with dedicated product management & software engineering teams to implement data science algorithms onto our consumer-facing ecommerce website\n\nPartner with dedicated analysts to produce data visualizations, advanced reports, measurement and statistical models that explain and track algorithm performance against business KPIs\n\nPartner with the business to identify & understand opportunities for data science applications\n\nProvide thought leadership and data support to the business & other analytics team members around design, execution, and measurement of business KPIs\n\nCollaborate with other data scientists across our organization to share best practices, learn new techniques, and foster our organizational culture where data is central to decision making\n\n\n\nHigh degree of personal integrity, strong work ethic, & a desire to learn and grow in this role\n\n2+ years of work experience as a Data Scientist or Machine Learning Engineer\n\nFluent in R or Python (Python preferred) & SQL\n\nFamiliarity with Machine Learning techniques (e.g. classification, clustering, regularization, optimization, dimension reduction, feature engineering)\n\nStrong understanding of CS fundamentals (e.g. algorithms and data structures)\n\nExperience with attribution, causal inference, experimental design, and AB testing methods\n\nGood communication skills and ability to explain complex topics to a non-technical audience\n\n\n\nExperience partnering with product management & software engineering teams to implement algorithms into a production environment\n\nDegree or Advanced Degree in Statistics, Computer Science, or related fields\n\nExperience with Git and/or Airflow\n\nExperience with data visualization tools such as Tableau\n\nExperience in e-commerce, subscription models, and/or direct-to-consumer brands\n\nFamiliarity with web analytics tools & concepts (Google Analytics, pixel tracking, Segment Customer Data Platform or comparable tools)\n\n\n\nTechStyleOS is the globally integrated Operations and Services provider behind some of the fastest growing online fashion brands in history, including Fabletics, Savage X Fenty, JustFab, ShoeDazzle, and FabKids. With capabilities spanning technology, data science, supply chain management, fulfillment, customer service, and more, we help brands launch, scale and grow—across product categories and geographically. From predictive analytics to data-driven marketing and attribution, our unique approach is powered by our proprietary, end-to-end tech platform that enables the brands we serve to deliver a level of personalization, value, and satisfaction that are unrivaled in the fashion industry.\n\nSavage X Inc.is an equal opportunity employer. We recruit, employ, compensate, develop, and promote regardless of race, national origin, religion, sex, sexual orientation, gender identity, age, disability, genetic information, veteran status, and other protected status as required by applicable. At Savage X Inc. , we champion a vibrant workplace culture that thrives on diversity law and do not tolerate discrimination or harassment. We are one team from many backgrounds, innovating through diversity of individuals, who are driven by passion for creating an inclusive space for all. Savage X Inc. will continue to champion a workplace culture that prizes diversity and inclusivity.\n\nWe encourage you to apply regardless of meeting all qualifications and/or requirements.",[],[]\nWestern Governors University,Data Scientist-2,"St Louis, MO",,https://www.linkedin.com/jobs/view/2718750842/?eBP=CwEAAAF8A9ofOjpba68ujoLXQAaOCBXYiS4C1yUTdLuyzCZe9eu8Ol6E5B1OavyEuBokToqXvI8orCg9mTa7e7zpzyV9cy10rVkKoDvZEPBDm1du-SyxnPgFICjxXnkLuO4a476oKPYJHgNsT_wxWcVM7UPEe_A4rGFK3u5Nxocz6TO1M6QF-5VfM-4C6pvZ-cryEakyxdZm6GaHw7p9zbMvWyaV6i1CvmDXy27crdTMH0Tc23b0hvt7S-fanNHX4dGjk06Is5AS7iuF-deOP1A46W0iSZPaIhLkVkBxOTTw8Wp12qn_2fxTdloxilj5f3cSIkJJSt5CyCNX3COteQXhYjO8geRyhwPGFGyDICcz7CEBCngNc2CFZt-0BfY9piw&recommendedFlavor=COMPANY_RECRUIT&refId=uAGrvRCfo9q5%2BNk5EGGm4Q%3D%3D&trackingId=nI03Xvg4nBirIwj8TRNSAQ%3D%3D&trk=flagship3_search_srp_jobs,"About the job\nIf you’re passionate about building a better future for individuals, communities, and our country—and you’re committed to working hard to play your part in building that future—consider WGU as the next step in your career.\n\nDriven by a mission to expand access to higher education through online, competency-based degree programs, WGU is also committed to being a great place to work for a diverse workforce of student-focused professionals. The university has pioneered a new way to learn in the 21st century, one that has received praise from academic, industry, government, and media leaders. Whatever your role, working for WGU gives you a part to play in helping students graduate, creating a better tomorrow for themselves and their families.\n\n\n\n\n\n:\n\n\n\n\n\nAs an equal opportunity employer, WGU recognizes that our strength lies in our people. We are committed to diversity.",[],[]\nCarShield,Data Scientist,"St Louis, MO","50 minutes ago\nWithin the past 24 hours",https://www.linkedin.com/jobs/view/2723209281/?eBP=JOB_SEARCH_ORGANIC&recommendedFlavor=COMPANY_RECRUIT&refId=uAGrvRCfo9q5%2BNk5EGGm4Q%3D%3D&trackingId=KgTMJ%2FOU15u5GSRxFma6BA%3D%3D&trk=flagship3_search_srp_jobs,"About the job\nJob Description\nResponsible for overseeing the collection, storage and interpretation of data for businesses. Their duties include sifting through data points to create organized categories, comparing data points to current company processes and writing reports outlining business predictions or proposals.",[],[]\nAmerican Express Global Business Travel,Data Scientist,"Evansville, IN",6 days ago,https://www.linkedin.com/jobs/view/2716701280/?eBP=JOB_SEARCH_ORGANIC&recommendedFlavor=ACTIVELY_HIRING_COMPANY&refId=uAGrvRCfo9q5%2BNk5EGGm4Q%3D%3D&trackingId=%2FNnG2%2FT8eaQ5Auu0r1LwgQ%3D%3D&trk=flagship3_search_srp_jobs,"About the job\nThe Candidate Is Expected To Possess These Key Skills/technologies\n\nThe data science solutions engineer will be a member of the data analytics team and will lead efforts around building big data, data science, data quality, and BI/MI/AI solutions. An ideal candidate will be a The data science associate will have a growth-oriented, lean-startup mindset for building hands-on data science solutions. The ideal candidate will propose, experiment, execute, and operationalize advanced predictive, preemptive data solutions designed to help traveler, travel-manager, supplier, and client outcomes. The role will span full-scale product, enterprise, and operational data science. The candidate will focus and thrive in a hands-on applied role; he/she will demonstrate a strong penchant for quantitative, collaborative, outcome-oriented solutions-engineering.\n\n\n\n\n\n\n\nIndia>Virtual Location\n\nIt is our policy to provide equal employment opportunities to all individuals based on job-related qualifications and ability to perform a job, without regard to age, gender, gender identity, sexual orientation, race, color, religion, creed, national origin, disability, genetic information, veteran status, citizenship or marital status, and to maintain a non-discriminatory environment free from intimidation, harassment or bias based upon these grounds.\n\nPosted 6 Days Ago Full time J-46605\n\nAmerican Express Global Business Travel (GBT) is the world’s leading business partner for managed travel. We help companies and employees prosper by making sure travelers are present where and when it matters. We keep global business moving with the powerful backing of 16,000 travel professionals in more than 140 countries. Companies of all sizes, and in all places, rely on GBT to provide travel management services, organize meetings and events, and deliver business travel consulting.",[],[]\nKPMG US,"Associate, Data Scientist","Chicago, IL",,https://www.linkedin.com/jobs/view/2715182807/?eBP=CwEAAAF8A9ofOnXwJUuycM2gGRL1mcgrhKEvGOAPq7WvcuqVfhF3v31fFIUXMUZTB2_KdQBZae-zIVr4TaQH32qoMce5QiuRkyz35Qe4NunBDe1tO5oIPM_jRd0DRVV1Q2RE2NsRab1c65uetiOURFT5UacwF26coAIsRg_OLs_YoY_77ZEEy1w6kTyWThm4DdS0MF9eZsoLFRxcEZjVZPeHkjucUMmMlgDkGFolStofkAtovBw2_NeONzmFwJOWVe1GKQ1XqLioi_MqRW4kb3iJnvdR5E8PAb5PCjiNjJEfuIXO63QpyODR7y7X0dEhMCCkj_x1tLu5T0PQeNlCeZkpp7nWdyWZQtRzOXNNpH9yPYBeaNL_b3b8W8FSewL2XfI&recommendedFlavor=COMPANY_RECRUIT&refId=uAGrvRCfo9q5%2BNk5EGGm4Q%3D%3D&trackingId=tWMAG1KeTQs1iil6CAtrmQ%3D%3D&trk=flagship3_search_srp_jobs,"About the job\nRequisition Number: 70881 - 31\n\nDescription\n\nInnovate. Collaborate. Build. Create. Solve. The KPMG Digital Lighthouse is KPMG\'s award-winning Analytics & AI Center of Excellence recognized by clients and leading analyst firms in the US and globally. The KPMG Lighthouse is a curation of specialized technical capabilities and domain experts working across the digital landscape: applied data science, AI, data engineering and insights, software engineering, automation, and big data. Here, you\'ll work with a diverse team of professionals to explore and build solutions for clients in a multiplatform environment.\n\nYou\'ll be an important part of our high-energy, unique, fast-paced, and innovative culture that delivers with the agility of a tech startup and the backing of a leading global consulting firm. In this particular role, you\'ll work specifically in the AI Analytics & Engineering Community within the Digital Lighthouse, on a wide range of projects. From applied AI to optimization to big data platform engineering, your analytical and technical skills will drive real impact in the business world. At KPMG, our commitment to your career development helps to set us apart as an employer. We want to enhance your potential, both for yourself and as a contributor to our firm. That\'s why we provide every opportunity to expand your skills, knowledge and experiences through formal education and training programs, leadership development opportunities, and, as well as informal one-on-one coaching and mentoring from your KPMG colleagues.\n\nKPMG is currently seeking an Associate to join our KPMG Lighthouse - Center of Excellence for Advanced Analytics.\n\n\n\n\n\nKPMG LLP (the U.S. member firm of KPMG International) offers a comprehensive compensation and benefits package. KPMG is an affirmative action-equal opportunity employer. KPMG complies with all applicable federal, state and local laws regarding recruitment and hiring. All qualified applicants are considered for employment without regard to race, color, religion, age, sex, sexual orientation, gender identity, national origin, disability, protected veteran status, or any other category protected by applicable federal, state or local laws. The attached link contains further information regarding the firm\'s compliance with federal, state and local recruitment and hiring laws. No phone calls or agencies please.",[],[]\n"Systems Planning and Analysis, Inc.",Data Scientist - CWMD,"Reston, VA",,https://www.linkedin.com/jobs/view/2719087133/?eBP=CwEAAAF8A9ofOs3Q1pRDNomWkKq8WZKKrxzVFph6K2D4ymCmOH1h4zujhf7yBWfSjCtGRdbAe9Qx1ZFnDclUFpBrbo8MAanx6IoSd6oeFzDujMeur4dsRn-KObiuVvRuoE8jax4zNaj2cL0qgNswrocbKDKdYn82E7vixG1bp6oL35Xs1t4QTILoMHsFU_wTZqMgC7fCMPF3UzzYVoZ7UpLI2jutAFhJUtKKFD94vE5WkDbZOlxsnkXaN96-uctzECAJaz-JWJTbMRDHUek1yOdijC16J7HeR8V1Snd1B3f-lHcwkIyohdLJUUsi0dDpOWpoQNpv7XWOgAXT-NzCdHsRY99xfHcFFJK5r9UEJvFy__j3f60gUpWxie9aT8NO&recommendedFlavor=ACTIVELY_HIRING_COMPANY&refId=uAGrvRCfo9q5%2BNk5EGGm4Q%3D%3D&trackingId=sCAmjQEN8DY8a6u7bP7Yfg%3D%3D&trk=flagship3_search_srp_jobs,"About the job\nOverview\n\nSystems Planning and Analysis, Inc. (SPA) is a well-established and progressive defense contracting company in the DC Metro area. We are a professional services firm established in 1972 that has a long-standing reputation for unrivaled technical and analytical support to some of the top decision makers in the Federal Sector. We do state of the art work and have a cadre of outstanding professionals on our team.\n\nSPA assists the Defense Threat Reduction Agency (DTRA) in developing leading edge technologies to counter WMD in support of CCMDs and transitioning these technologies to services and SOCOM. SPA provides expertise across the full range of chemical, biological, radiological, nuclear and high-yield explosives (CBRNE) WMD, Counter Improvised Threat and Countering Threat Network technologies to support understanding, detection, identification, characterization, denial, control, disabling, defeating, disposing, safeguarding the force, managing consequences, and test and evaluation in support of military and civilian operations. #CJ #IN123\n\n\n\nProvides critical decision and analytic support to the Urgent Solutions Division in the Counter WMD Technologies Department of the Defense Threat Reduction Agency (DTRA). Conducts assessments, demonstrations, analysis, scientific codes, and other decision making in evaluating systems to counter WMD – biological and chemical threats, and counter threat networks. Develops knowledge regarding a stipulated issue through analysis of complex data sets, identifying actionable trends and problems. Uses appropriate methods to creatively explore, mine, analyze and manipulate data sets ranging in size from sparse to petabytes and type (e.g. small number of .pdf text reports, Excel spreadsheets and .csv files to repositories of image or audio data). Interprets results from multiple sources using a variety of techniques, ranging from simple data aggregation via statistical analysis to complex data mining, sensor analysis and learning techniques. Designs, develops, and implements technical solutions in support of concurrent analysis. Supports data models and defines the structure, attributes, and nomenclature of data elements. May evaluate new data sources for adherence to the organization\'s quality standards and ease of integration.",[],[]\nPerficient,Data Scientist,"St Louis, MO",,https://www.linkedin.com/jobs/view/2718055481/?eBP=CwEAAAF8A9ofOhOHpkH95U2fvN9F-goU76IrWGZ2_h1PEIqUbFxqxI6w3ypUfMSWfMRpTGEJDX9iicxg3Is1hE7MJg4ixQ2ZJfmdAFAR38WMuWQ9RdnHIEX4XrSbapYsM3nhi6Iyv6rH9MEC1PpEqmZkvr8JBlfU1asVfgP3pl3rW4IS6tIVJuzERferAoB3ycE-UB94AE92MTfUPPOUagL-zhuIsIcyQ6BMfE6eFGYpZpAHbvdti7-s852GjLAxYFovRGVyerfbSKSeZm6fVVXT2EaQfKYvMN5hBZBBVncwxNfzaaMBbKZ9moxmBg76BZ3UfB6YOntWLvvf06jI4VVqLMZ_BYq4iT8Jnp-YKt2dJxnECW-9zW66IbRoeRPT&recommendedFlavor=COMPANY_RECRUIT&refId=uAGrvRCfo9q5%2BNk5EGGm4Q%3D%3D&trackingId=UE7bblhxeqWJV52%2F9JWJew%3D%3D&trk=flagship3_search_srp_jobs,"About the job\nOverview\n\nAt Perficient you’ll deliver mission-critical technology and business solutions to Fortune 500 companies and some of the most recognized brands on the planet. And you’ll do it with cutting-edge technologies, thanks to our close partnerships with the world’s biggest vendors. Our network of offices across North America, as well as locations in India and China, will give you the opportunity to spread your wings, too.\n\nWe’re proud to be publicly recognized as a “Top Workplace” year after year. This is due, in no small part, to our entrepreneurial attitude and collaborative spirit that sets us apart and keeps our colleagues impassioned, driven, and fulfilled.\n\nPerficient currently has a career opportunity for a .\n\n\n\nThe role of the Data Scientist is for individuals passionate about identifying and delivering the right Business solution for each client using AI/ML. Our Data Scientists are keen to understand our customer needs, processes and pain points to determine the success factors and evaluation criteria that will needed to measure the effectiveness of an ML model.\n\nThe Data Scientist will be involved in the strategic planning of an engagement or helping the client make decisions about their future AI/ML roadmap and vision. Once the project as begun, the Data Scientist will be responsible for the execution of our established methodology, work with customer and/or the teams data engineer to identify data ingestion and transformation needs, exploration of the data and reporting findings, modeling and evaluation of training iterations. It is a key part of the role to be able to explain in non-technical terms the chosen modeling approach and findings from data exploration or training results.\n\nThe Data Scientist will work with Senior Project Managers to assist with daily operations exercising time management, communication and collaboration in a fast-paced environment to ensure the successful delivery of projects. The Data Scientist will interface with Perficient technical and business delivery personnel, as well as vendors and customers on a regular basis. May mentor junior data scientists.\n\n\n\n\n\n\n\nPerficient full-time employees receive complete and competitive benefits. We offer a collaborative work environment, competitive compensation, generous work/life opportunities and an outstanding benefits package that includes paid time off plus holidays. In addition, all colleagues are eligible for a number of rewards and recognition programs including billable bonus opportunities. Encouraging a healthy work/life balance and providing our colleagues great benefits are just part of what makes Perficient a great place to work.\n\n\n\nPerficient is the leading digital transformation consulting firm serving Global 2000 and enterprise customers throughout North America. With unparalleled information technology, management consulting and creative capabilities, Perficient and its Perficient Digital agency deliver vision, execution and value with outstanding digital experience, business optimization and industry solutions.\n\nOur work enables clients to improve productivity and competitiveness; grow and strengthen relationships with customers, suppliers and partners; and reduce costs. Perficient\'s professionals serve clients from a network of offices across North America and offshore locations in India and China. Traded on the Nasdaq Global Select Market, Perficient is a member of the Russell 2000 index and the S&P SmallCap 600 index.\n\nPerficient is an equal opportunity employer and all qualified applicants will receive consideration for employment without regard to race, color, religion, sex, national, origin, disability status, protected veteran status, or any other characteristic protected by law.\n\nThe above statements are not intended to be a complete statement of job content, rather to act as a guide to the essential functions performed by the employee assigned to this classification. Management retains the discretion to add or change the duties of the position at any time.\n\nSelect work authorization questions to ask when applicants apply",[],[]\nSavage X Fenty: Lingerie by Rihanna,Data Scientist,"El Segundo, CA",,https://www.linkedin.com/jobs/view/2721710042/?eBP=CwEAAAF8A9ofOhPzbWsStxaNEgpMLIbvO6Vvpf-kp8RGwvYOJKGphyyakdc_4SGsjm2VeRAGjmk-vJ6l9A5H_dap2I3Kpoi5h6gKOdZGPr43fehHk5BqkiDkbvKki_to05FvWLinOBzurpjsMFG3JoeqUJ8xRReTFcidZnHYUQE6jUxh0nf-LNmAPuQp7YZEmPEps45wTFpgh1xQa_nwnLky1x-nzte_8YwEIsmHKQ5z2VTOvDevWj_NNLxyfvp4hDKsNbBNyQC_28gSNPkqkg6iN2yFOum-URpP05X-BwoG-gN9HPsuQJs-bhqDslt8i6wwag517FTdUMMYWqa29zUtuHYFUf1ei5iEh0ffOBNdGGDafvdOB4z8Oqp3hxLnHhY&recommendedFlavor=ACTIVELY_HIRING_COMPANY&refId=uAGrvRCfo9q5%2BNk5EGGm4Q%3D%3D&trackingId=WJuu5WmPKTuvZRyUdmNdtA%3D%3D&trk=flagship3_search_srp_jobs,"About the job\nJob DescriptionSavage X Fenty is looking for a Data Scientist. Co-founded by music and fashion icon Rihanna, Savage X Fenty is the first line of lingerie that celebrates and speaks to all shades and shapes of people, and celebrates fearlessness, confidence and inclusivity.\n\nHOW DO YOU FIT IN?\n\nAs the Data Scientist, you will drive innovation in our customer shopping experience by providing the algorithms that power recommendation and personalization features across our ecommerce website. You will collaborate closely with the Data Analytics organization, the Global Technology organization, and the Savage X business to develop high-impact solutions to key optimization opportunities such as ecommerce conversion & product discovery. You will watch your work come to life by partnering with dedicated product & software engineering teams to deploy your algorithms into production.\n\nProjects you are likely to own in this role include:\n\nProduct Recommendation Algorithms (e.g., product discovery & upsell algorithms)\n\nFull Funnel Customer Segmentation (e.g., algorithmically define customer segments and stream segments to other tools such as our CRM or ad networks)\n\nInternal Optimization Algorithms (e.g., attribution models, sales propensity algorithms)\n\nAt Savage X Fenty you can expect to use Python and SQL every day. For larger projects requiring scale or automation you’ll likely be working with DataBricks and Airflow. While these are our defaults, you will have the flexibility to use tools that allow you to best fulfill your role. Additionally, we strongly believe in the need for ongoing education and so will encourage you to explore new technologies and modeling methods on a regular basis.\n\n\n\nYou’re the ideal candidate if you’re incredibly curious & see opportunities for data science applications in everything you do. Working smarter, not harder, is core to your DNA. You’re invigorated by the opportunity to learn that next tool or skill, and you come up with clever solutions to difficult problems. As much as you learned in school or at work, you’ve probably learned even more during your late-night hacking sessions. You take initiative, can work without supervision, begin projects independently, and are technically capable with a deep desire to become an expert in data science applications for ecommerce. You’re seeking a collaborative environment in which you can work alongside other technology experts to find the best answer and win as a team.\n\nThis position will report to the Director of Data Analytics on the Savage X Fenty Analytics Team. The position will also have an informal reporting line to the Sr. Director of Data Science on the TechStyleOS Architecture & Sciences team. We are a creative, ambitious, & fun-loving team who believes data products should be collaboratively designed, impactful to the business, and customized for the end user. Our analytics team acts as strategic partners to the business, making an impact by merging data with a deep understanding of the Savage customer experience.\n\nThis position will be based in El Segundo, California. For the right candidate, we will consider full-time remote work.\n\nWHY WORK IN DATA SCIENCE AT SAVAGE X?\n\nWork within a community of data scientists through our parent company TechStyle Fashion Group & our sister brand Fabletics, but be the first Data Scientist dedicated to the Savage X brand. This role will design the foundation for Savage’s future data science initiatives & experience fast paced growth\n\nDedicated resources to support you – Savage X is investing heavily in data science and has staffed dedicated engineering & product management to support your initiatives\n\nIndustry leading data technology stack – Snowflake, DataBricks, Segment Customer Data Platform, Apache Airflow, modeled reporting data warehouse, & more\n\nData-driven mindset is deeply foundational to the culture at Savage X; information flows freely throughout our organization and every key decision we make is backed by analysis\n\nBe a part of the larger Data Analytics organization at TechStyle Fashion Group (60+ team members); mentor & be mentored by our architects, scientists, analysts, & engineers\n\n\n\nLeverage our advanced tech stack, your knowledge of data science methods & models, and your partnerships with our senior engineers, scientists, and architects to determine the best approaches for algorithm development and implementation\n\nOwn algorithm development projects from start-to-end: design, develop, QA, deploy, experiment, and analyze\n\nPartner with dedicated product management & software engineering teams to implement data science algorithms onto our consumer-facing ecommerce website\n\nPartner with dedicated analysts to produce data visualizations, advanced reports, measurement and statistical models that explain and track algorithm performance against business KPIs\n\nPartner with the business to identify & understand opportunities for data science applications\n\nProvide thought leadership and data support to the business & other analytics team members around design, execution, and measurement of business KPIs\n\nCollaborate with other data scientists across our organization to share best practices, learn new techniques, and foster our organizational culture where data is central to decision making\n\n\n\nHigh degree of personal integrity, strong work ethic, & a desire to learn and grow in this role\n\n2+ years of work experience as a Data Scientist or Machine Learning Engineer\n\nFluent in R or Python (Python preferred) & SQL\n\nFamiliarity with Machine Learning techniques (e.g. classification, clustering, regularization, optimization, dimension reduction, feature engineering)\n\nStrong understanding of CS fundamentals (e.g. algorithms and data structures)\n\nExperience with attribution, causal inference, experimental design, and AB testing methods\n\nGood communication skills and ability to explain complex topics to a non-technical audience\n\n\n\nExperience partnering with product management & software engineering teams to implement algorithms into a production environment\n\nDegree or Advanced Degree in Statistics, Computer Science, or related fields\n\nExperience with Git and/or Airflow\n\nExperience with data visualization tools such as Tableau\n\nExperience in e-commerce, subscription models, and/or direct-to-consumer brands\n\nFamiliarity with web analytics tools & concepts (Google Analytics, pixel tracking, Segment Customer Data Platform or comparable tools)\n\n\n\nTechStyleOS is the globally integrated Operations and Services provider behind some of the fastest growing online fashion brands in history, including Fabletics, Savage X Fenty, JustFab, ShoeDazzle, and FabKids. With capabilities spanning technology, data science, supply chain management, fulfillment, customer service, and more, we help brands launch, scale and grow—across product categories and geographically. From predictive analytics to data-driven marketing and attribution, our unique approach is powered by our proprietary, end-to-end tech platform that enables the brands we serve to deliver a level of personalization, value, and satisfaction that are unrivaled in the fashion industry.\n\nSavage X Inc.is an equal opportunity employer. We recruit, employ, compensate, develop, and promote regardless of race, national origin, religion, sex, sexual orientation, gender identity, age, disability, genetic information, veteran status, and other protected status as required by applicable. At Savage X Inc. , we champion a vibrant workplace culture that thrives on diversity law and do not tolerate discrimination or harassment. We are one team from many backgrounds, innovating through diversity of individuals, who are driven by passion for creating an inclusive space for all. Savage X Inc. will continue to champion a workplace culture that prizes diversity and inclusivity.\n\nWe encourage you to apply regardless of meeting all qualifications and/or requirements.",[],[]\nWestern Governors University,Data Scientist-2,"St Louis, MO",,https://www.linkedin.com/jobs/view/2718750842/?eBP=CwEAAAF8A9ofOjpba68ujoLXQAaOCBXYiS4C1yUTdLuyzCZe9eu8Ol6E5B1OavyEuBokToqXvI8orCg9mTa7e7zpzyV9cy10rVkKoDvZEPBDm1du-SyxnPgFICjxXnkLuO4a476oKPYJHgNsT_wxWcVM7UPEe_A4rGFK3u5Nxocz6TO1M6QF-5VfM-4C6pvZ-cryEakyxdZm6GaHw7p9zbMvWyaV6i1CvmDXy27crdTMH0Tc23b0hvt7S-fanNHX4dGjk06Is5AS7iuF-deOP1A46W0iSZPaIhLkVkBxOTTw8Wp12qn_2fxTdloxilj5f3cSIkJJSt5CyCNX3COteQXhYjO8geRyhwPGFGyDICcz7CEBCngNc2CFZt-0BfY9piw&recommendedFlavor=COMPANY_RECRUIT&refId=uAGrvRCfo9q5%2BNk5EGGm4Q%3D%3D&trackingId=nI03Xvg4nBirIwj8TRNSAQ%3D%3D&trk=flagship3_search_srp_jobs,"About the job\nIf you’re passionate about building a better future for individuals, communities, and our country—and you’re committed to working hard to play your part in building that future—consider WGU as the next step in your career.\n\nDriven by a mission to expand access to higher education through online, competency-based degree programs, WGU is also committed to being a great place to work for a diverse workforce of student-focused professionals. The university has pioneered a new way to learn in the 21st century, one that has received praise from academic, industry, government, and media leaders. Whatever your role, working for WGU gives you a part to play in helping students graduate, creating a better tomorrow for themselves and their families.\n\n\n\n\n\n:\n\n\n\n\n\nAs an equal opportunity employer, WGU recognizes that our strength lies in our people. We are committed to diversity.",[],[]\nCarShield,Data Scientist,"St Louis, MO","50 minutes ago\nWithin the past 24 hours",https://www.linkedin.com/jobs/view/2723209281/?eBP=JOB_SEARCH_ORGANIC&recommendedFlavor=COMPANY_RECRUIT&refId=uAGrvRCfo9q5%2BNk5EGGm4Q%3D%3D&trackingId=KgTMJ%2FOU15u5GSRxFma6BA%3D%3D&trk=flagship3_search_srp_jobs,"About the job\nJob Description\nResponsible for overseeing the collection, storage and interpretation of data for businesses. Their duties include sifting through data points to create organized categories, comparing data points to current company processes and writing reports outlining business predictions or proposals.",[],[]\nAmerican Express Global Business Travel,Data Scientist,"Evansville, IN",6 days ago,https://www.linkedin.com/jobs/view/2716701280/?eBP=JOB_SEARCH_ORGANIC&recommendedFlavor=ACTIVELY_HIRING_COMPANY&refId=uAGrvRCfo9q5%2BNk5EGGm4Q%3D%3D&trackingId=%2FNnG2%2FT8eaQ5Auu0r1LwgQ%3D%3D&trk=flagship3_search_srp_jobs,"About the job\nThe Candidate Is Expected To Possess These Key Skills/technologies\n\nThe data science solutions engineer will be a member of the data analytics team and will lead efforts around building big data, data science, data quality, and BI/MI/AI solutions. An ideal candidate will be a The data science associate will have a growth-oriented, lean-startup mindset for building hands-on data science solutions. The ideal candidate will propose, experiment, execute, and operationalize advanced predictive, preemptive data solutions designed to help traveler, travel-manager, supplier, and client outcomes. The role will span full-scale product, enterprise, and operational data science. The candidate will focus and thrive in a hands-on applied role; he/she will demonstrate a strong penchant for quantitative, collaborative, outcome-oriented solutions-engineering.\n\n\n\n\n\n\n\nIndia>Virtual Location\n\nIt is our policy to provide equal employment opportunities to all individuals based on job-related qualifications and ability to perform a job, without regard to age, gender, gender identity, sexual orientation, race, color, religion, creed, national origin, disability, genetic information, veteran status, citizenship or marital status, and to maintain a non-discriminatory environment free from intimidation, harassment or bias based upon these grounds.\n\nPosted 6 Days Ago Full time J-46605\n\nAmerican Express Global Business Travel (GBT) is the world’s leading business partner for managed travel. We help companies and employees prosper by making sure travelers are present where and when it matters. We keep global business moving with the powerful backing of 16,000 travel professionals in more than 140 countries. Companies of all sizes, and in all places, rely on GBT to provide travel management services, organize meetings and events, and deliver business travel consulting.",[],[]\nKPMG US,"Associate, Data Scientist","Chicago, IL",,https://www.linkedin.com/jobs/view/2715182807/?eBP=CwEAAAF8A9ofOnXwJUuycM2gGRL1mcgrhKEvGOAPq7WvcuqVfhF3v31fFIUXMUZTB2_KdQBZae-zIVr4TaQH32qoMce5QiuRkyz35Qe4NunBDe1tO5oIPM_jRd0DRVV1Q2RE2NsRab1c65uetiOURFT5UacwF26coAIsRg_OLs_YoY_77ZEEy1w6kTyWThm4DdS0MF9eZsoLFRxcEZjVZPeHkjucUMmMlgDkGFolStofkAtovBw2_NeONzmFwJOWVe1GKQ1XqLioi_MqRW4kb3iJnvdR5E8PAb5PCjiNjJEfuIXO63QpyODR7y7X0dEhMCCkj_x1tLu5T0PQeNlCeZkpp7nWdyWZQtRzOXNNpH9yPYBeaNL_b3b8W8FSewL2XfI&recommendedFlavor=COMPANY_RECRUIT&refId=uAGrvRCfo9q5%2BNk5EGGm4Q%3D%3D&trackingId=tWMAG1KeTQs1iil6CAtrmQ%3D%3D&trk=flagship3_search_srp_jobs,"About the job\nRequisition Number: 70881 - 31\n\nDescription\n\nInnovate. Collaborate. Build. Create. Solve. The KPMG Digital Lighthouse is KPMG\'s award-winning Analytics & AI Center of Excellence recognized by clients and leading analyst firms in the US and globally. The KPMG Lighthouse is a curation of specialized technical capabilities and domain experts working across the digital landscape: applied data science, AI, data engineering and insights, software engineering, automation, and big data. Here, you\'ll work with a diverse team of professionals to explore and build solutions for clients in a multiplatform environment.\n\nYou\'ll be an important part of our high-energy, unique, fast-paced, and innovative culture that delivers with the agility of a tech startup and the backing of a leading global consulting firm. In this particular role, you\'ll work specifically in the AI Analytics & Engineering Community within the Digital Lighthouse, on a wide range of projects. From applied AI to optimization to big data platform engineering, your analytical and technical skills will drive real impact in the business world. At KPMG, our commitment to your career development helps to set us apart as an employer. We want to enhance your potential, both for yourself and as a contributor to our firm. That\'s why we provide every opportunity to expand your skills, knowledge and experiences through formal education and training programs, leadership development opportunities, and, as well as informal one-on-one coaching and mentoring from your KPMG colleagues.\n\nKPMG is currently seeking an Associate to join our KPMG Lighthouse - Center of Excellence for Advanced Analytics.\n\n\n\n\n\nKPMG LLP (the U.S. member firm of KPMG International) offers a comprehensive compensation and benefits package. KPMG is an affirmative action-equal opportunity employer. KPMG complies with all applicable federal, state and local laws regarding recruitment and hiring. All qualified applicants are considered for employment without regard to race, color, religion, age, sex, sexual orientation, gender identity, national origin, disability, protected veteran status, or any other category protected by applicable federal, state or local laws. The attached link contains further information regarding the firm
'''

r.extract_keywords_from_text(mtext)

r.get_ranked_phrases()[:10]
# Out:
# ['past 24 hours ", https :// www',
#  'past 24 hours ", https :// www',
#  'past 24 hours ", https :// www',
#  'past 24 hours ", https :// www',
#  'past 24 hours ", https :// www',
#  'past 24 hours ", https :// www',
#  'past 24 hours ", https :// www',
#  'past 24 hours ", https :// www',
#  'past 24 hours ", https :// www',
#  'past 24 hours ", https :// www']

# %%
keywords = r.extract_keywords_from_text(mtext)
print("keywords:", keywords)
#r.get_ranked_phrases()
# Out:
# keywords: None

# %%
#nltk.data.path.append('./nltk_data/')  # set the path
tokens = nltk.word_tokenize(mtext)
text = nltk.Text(tokens)

# %%
from nltk.tokenize import RegexpTokenizer

tokenizer = RegexpTokenizer(r'\w+')
tokenizer.tokenize('text')
keywords = r.extract_keywords_from_text(mtext)
print("keywords:", keywords)
# Out:
# keywords: None

# %%
filtered_text =  [word for word in text if word.isalpha()]
filtered_text[:5]
# Out:
# ['company', 'title', 'location', 'posted', 'href']

# %%
import nltk
from nltk.corpus import stopwords
english_stops_words = stopwords.words('english')
filtered_english_stop = [w for w in filtered_text if not w in english_stops_words]
filtered_english_stop[:5]
# Out:
# ['company', 'title', 'location', 'posted', 'href']

# %%
stopwords_1 = r.stopwords
filtered2 = [w for w in filtered_english_stop if not w in stopwords_1]
filtered2[:5]
# Out:
# ['company', 'title', 'location', 'posted', 'href']

# %%
stopwords2 = ['long', 'descriptive', 'text', 'contains', 'technical', 'skills', 'keywords', 'things', 'see', 'rake', 'need', 'many', 'lists', 'let', 'extract', 'https :// www',
                                              'past', '24', 'hours', 'https', ':','//', 'www','[]','[]','mo','savage', 'serving','initiatives', 'posted', '6', 'days', 'ago', 'full', 'time', 'domain', 'experts',
                                              'working', 'across', 'freely', 'x', 'fenty', 'employment', 'without', 'regard', 'industry', '46605', 'american', 'express', 'global', 'business', 'travel', 'recognition',
                                              'programs', 'including','billage', 'bonus', 'opportunities', 'lead', 'efforts', 'around', 'building', 'may','evaluate','new', 'mentor','junior', 'simple', 'via','g','.',
                                              'define', 'customer', 'segments', 'technology', 'st', 'louis', '2', 'p','smallcap', '600', 'index', 'thought', 'leadrship','provide', 'good','communication', 'methods',
                                              'experience', 'fast','paced', 'growth', 'dedicated', 'resources', 'parent', 'company', 'techstyle', 'fashion','group', 'top', 'workplace', 'year', 'implement', 'onto',
                                              'el','segundo', 'defense', 'threat', 'agency', 'enterprise','customers', 'throughout', 'north', 'america', 'fluent', 'consulting', 'firm','reporting','decision', 'making',
                                              'high', 'degree','associate',',','[]',',','[]', 'kpmg',' us','select', 'work', 'authorization', 'questions', 'chicago', 'larger', 'projects', 'requiring', 'scale',
                                              'western', 'governors', 'university','manipulate', 'sets' 'ranging', 'preemptive', 'designed', 'facing', 'partner', 'counter', 'technologies', 'department',
                                              'local', 'laws', 'regarding', 'recruitment', 'evansville', 'job', 'job', 'description', 'responsible', 'inc', '.', 'solutions', 'engineer', 'future', '—', 'consider', 'wgu',
                                              'platform', 'engineering', 'big', 'night', 'hacking', 'sessions', 'essential', 'functions', 'performed','dc', 'metro', 'area', '2723209281', '/', '?', 'ebp',',',  '50',' minutes',
                                              'daily', 'operations', 'exercising', 'multiple', 'sources', 'using', 'track', 'performance', 'believes', 'data', 'products', 'complex', ',', 'scientists', 'compensate', 'comparing', 'come',
                                              'identifying', 'actionable', 'trends','helping', 'students', 'graduate', 'trk', 'descriptionsavage', 'within', 'prizes', 'diversity', 'powerful', 'backing', 'colleagues',
                                              'impassioned', 'use', 'currently', 'seeking','collaborative', 'spirit', 'characteristic', 'protected', 'makers', 'maintain','law','late', 'structures', 'thanks', 'thrive', 
                                              'traded', 'twmag1ketqs1iil6catrmq',':', '//', '9zw66ibroerpt', '3d','2f0jwjew', 'technically', 'capable', 'every', 'opportunity', 'senior', 'engineers', 'take', 'initiative', 'team',
                                              'yield', 'explosives','learning', 'techniques', 'transformation', 'needs', 'tolerate', 'discrimination', 'successful', 'delivery','power', 'recommendation', 'success',
                                              'factors','complete', 'statement','qualified', 'applicants', 'recognized', 'brands', 'received', 'praise', 'promote', 'regardless', 'brand', 'biological', '3d', 'work', 'view',
                'uagrvrcfo9q5', 'recommendedflavor', 'race', 'complies', 'applicable', 'federal', 'hiring', 'all', 'color', 'religion', 'VA', 'About', 'Overview', 'systems', 'progressive', 'contracting', 'DC', 'We', 'Metro',
              'Reston', 'title', 'Systems', 'location', 'href', 'Planning', 'analysis', 'Scientist', 'Analysis', 'Data', 'SPA', 'CWMD', 'professional', 'services', 'established', 'reputation', 'unrivaled', 'analytical',
              'support', 'Federal', 'Sector', 'state', 'art', 'cadre', 'outstanding', 'professionals', 'assists', 'Defense', 'Threat', 'Reduction', 'Agency', 'developing', 'leading', 'edge', 'transitioning', 'provides', 'expertise',
              'denial', 'control', 'disabling', 'defeating', 'disposing', 'safeguarding', 'force', 'managing', 'consequences', 'test', 'range', 'chemical', 'radiological', 'nuclear', 'CBRNE', 'Requisition', 'Number', 'Description',
              'Innovate', 'Collaborate', 'Build', 'Create', 'Solve', 'The', 'Counter', 'Improvised', 'Countering', 'Network', 'understanding', 'detection', 'identification', 'characterization', 'evaluation', 'military', 'civilian', 
              'Provides', 'critical', 'analytic', 'Urgent', 'Solutions', 'Division', 'Technologies', 'Department', 'Conducts', 'assessments', 'demonstrations', 'scientific', 'codes', 'evaluating', 'incredibly', 'curious', 'science',
              'applications', 'everything', 'Working', 'smarter', 'harder', 'core', 'DNA', 'You', 'invigorated', 'learn', 'next', 'tool', 'skill', 'clever', 'difficult', 'problems', 'As', 'much', 'learned', 'school', 'probably',
              'learned', 'even', 'You', 'Associate', 'Chicago', 'IL', 'Digital', 'Lighthouse', 'Analytics', 'AI', 'Center', 'Excellence', 'clients', 'analyst', 'firms', 'US', 'globally', 'threats', 'networks', 'Develops', 'knowledge',
              'stipulated', 'issue', 'sets', 'Uses', 'appropriate', 'creatively', 'explore', 'mine', 'analyze', 'sets', 'ranging', 'size', 'sparse', 'petabytes', 'type', 'small', 'number', 'reports', 'also', 'committed', 'great',
              'place', 'diverse', 'workforce', 'pioneered', 'way', 'century', 'one', 'academic', 'government', 'continue', 'champion', 'culture', 'inclusivity', 'encourage', 'apply', 'meeting', 'qualifications', 'requirements', 'Western',
              'Governors', 'career', 'role', 'individuals', 'passionate', 'delivering', 'right', 'Business', 'solution', 'client', 'Our', 'Scientists', 'keen', 'understand', 'processes', 'pain', 'points', 'determine', 'icon', 'Rihanna', 
              'Savage', 'X', 'Fenty', 'first', 'line', 'lingerie', 'celebrates', 'speaks', 'shades', 'people', 'celebrates', 'files', 'repositories', 'image', 'audio', 'Interprets', 'results', 'variety', 'aggregation', 'growing', 'online', 'history',
              'Fabletics', 'JustFab', 'ShoeDazzle', 'FabKids', 'With', 'capabilities', 'spanning', 'supply', 'chain', 'management', 'fulfillment', 'service', 'help', 'launch', 'product', 'categories', 'geographically', 'required', 'At', 'vibrant',
              'thrives', 'harassment', 'backgrounds', 'innovating', 'driven', 'passion', 'creating', 'inclusive', 'space', 'Select', 'ask', 'Lingerie', 'El', 'Segundo', 'CA', 'Job', 'DescriptionSavage', 'looking', 'music', 'shapes', 'fearlessness',
              'confidence', 'HOW', 'DO', 'YOU', 'FIT', 'IN', 'drive', 'innovation', 'shopping', 'providing', 'algorithms', 'personalization', 'features', 'ecommerce', 'website', 'spreadsheets', 'statistical', 'mining', 'sensor', 'Designs', 'develops', 
              'implements', 'concurrent', 'Supports', 'models', 'defines', 'structure', 'attributes', 'nomenclature', 'elements', 'May', 'adherence', 'organization', 'quality', 'standards', 'ease', 'integration', 'Perficient', 'St', 'Louis']
clean_text =  [w for w in filtered2 if not w in stopwords2]
print(clean_text)
# Out:
# ['DTRA', 'WMD', 'CCMDs', 'SOCOM', 'WMD', 'CJ', 'WMD', 'DTRA', 'WMD', 'Excel', 'nomenclature', 'elements', 'May', 'adherence', 'organization', 'quality', 'standards', 'ease', 'integration', 'Perficient', 'St', 'Louis', 'MO', 'Perficient', 'deliver', 'Fortune', 'companies', 'planet', 'And', 'close', 'partnerships', 'world', 'biggest', 'vendors', 'network', 'offices', 'North', 'America', 'well', 'locations', 'India', 'China', 'give', 'spread', 'wings', 'proud', 'publicly', 'Top', 'Workplace', 'This', 'due', 'part', 'entrepreneurial', 'attitude', 'us', 'apart', 'keeps', 'fulfilled', 'Perficient', 'criteria', 'needed', 'measure', 'effectiveness', 'ML', 'model', 'involved', 'strategic', 'planning', 'engagement', 'make', 'decisions', 'roadmap', 'vision', 'Once', 'project', 'begun', 'execution', 'methodology', 'teams', 'identify', 'ingestion', 'exploration', 'findings', 'modeling', 'training', 'iterations', 'It', 'key', 'part', 'able', 'explain', 'terms', 'chosen', 'modeling', 'approach', 'f
# ...

# %%
unique = [w for i, w in enumerate(clean_text) if i == clean_text.index(w)]
unique
# Out:
# ['DTRA',
#  'WMD',
#  'CCMDs',
#  'SOCOM',
#  'CJ',
#  'Excel',
#  'nomenclature',
#  'elements',
#  'May',
#  'adherence',
#  'organization',
#  'quality',
#  'standards',
#  'ease',
#  'integration',
#  'Perficient',
#  'St',
#  'Louis',
#  'MO',
#  'deliver',
#  'Fortune',
#  'companies',
#  'planet',
#  'And',
#  'close',
#  'partnerships',
#  'world',
#  'biggest',
#  'vendors',
#  'network',
#  'offices',
#  'North',
#  'America',
#  'well',
#  'locations',
#  'India',
#  'China',
#  'give',
#  'spread',
#  'wings',
#  'proud',
#  'publicly',
#  'Top',
#  'Workplace',
#  'This',
#  'due',
#  'part',
#  'entrepreneurial',
#  'attitude',
#  'us',
#  'apart',
#  'keeps',
#  'fulfilled',
#  'criteria',
#  'needed',
#  'measure',
#  'effectiveness',
#  'ML',
#  'model',
#  'involved',
#  'strategic',
#  'planning',
#  'engagement',
#  'make',
#  'decisions',
#  'roadmap',
#  'vision',
#  'Once',
#  'project',
#  'begun',
#  'execution',
#  'methodology',
#  'teams',
#  'identify',
# ...

# %%
words = [w for w in words if not w in stop_words]
# Out:
#   File "<ipython-input-15-899b2f4565c6>", line 3
#     + ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're", "you've", "you'll", "you'd", 'your', 'yours',
#     ^
# IndentationError: unexpected indent

# %% [markdown]
# As you can see, Rake was able to extract keywords using the default NLTK stopwords list. However, it is not perfect and we are getting a lot of garbage keywords as well.
#
# You can set a custom list of stopwords to eliminate them from the analysis.

# %%
r = Rake(
    stopwords = ['this', 'is', 'a', 'long', 'descriptive','such', 'as', 'and', 'of', 'that', 'you', 'these', 'if', 'can', 'from', 'the', 'some', 's', 'many', 'are', 'text', 'contains', 'technical', 'skills', 'keywords', 'things', 'see', 'rake', 'need', 'lists', 'let', 'extract']
)

r.extract_keywords_from_text(mtext)
r.get_ranked_phrases()
# Out:
# ['fortune 100 best companies to work for (# 69 ), fortune best workplaces for diversity (# 38 ), fortune best workplaces for parents (# 31 ), fortune best workplaces for women (# 20 ), fatherly',
#  'best workplaces for new dads (# 37 ), just capital 100 company (# 69 ), bloomberg gender equality index constituent',
#  'statisticsspecialized in forecasting modellinggood in pythonmust have customer management skillscommunication must be excellent descriptionat least 3 years relevant experience required',
#  'analyses outilizems excel to perform analyses to produce reports outilizems powerpoint to produce reports outilizems word to produce reports outilizer',
#  'maintaining data sets • experience with incorporating data science capability into stakeholder strategy • experience bridging data science strategy between leadership',
#  'qualified individuals with disabilities who require reasonable accommodations in order to apply or compete for positions at nelnet may request',
# ...

# %% [markdown]
# This is exactly what we want.
#
# It will be unreasonable to enter all of those stopwords in by hand. Luckily you can download dictionaries of stopwords to help you out. To get started with the standard NLTK corpus, you can import it as follows

# %%
import nltk
from nltk.corpus import stopwords
print(stopwords.words('english'))
# Out:
# ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're", "you've", "you'll", "you'd", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', "she's", 'her', 'hers', 'herself', 'it', "it's", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', "that'll", 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than',
# ...

# %%
r = Rake(
    stopwords = stopwords.words('english') + ['long', 'descriptive', 'text', 'contains', 'technical', 'skills', 'keywords', 'things', 'see', 'rake', 'need', 'many', 'lists', 'let', 'extract']
)

r.extract_keywords_from_text(mtext)
r.get_ranked_phrases()
# Out:
# ['jazzhr job title data scientistwork location redmond watype contractduration 12 monthsjob descriptionwe',
#  'capital 100 company (# 69 ), bloomberg gender equality index constituent',
#  'data analyst3 data analyst data analystrequired experiencestrong communication skills3',
#  'ensemble modeling • present information using data visualization techniques • processing',
#  'position data scientist locationca azwaut comnmoilny matxilpa dcva',
#  'data scientistlog inshare thisfind similar career opportunitiesdata scientistarchitecturefairfax',
#  'solve challenging analytics problems influencing farmer decisions using scalable models2',
#  'fuse multiple data sources using time series signal processing techniques',
#  '3 years • spark ml – domain knowledge • visualization tools',
#  'fortune ® 50 home improvement company serving approximately 18 million customers',
#  'w engineering teams )• professional experience building machine learning models',
# ...

# %% [markdown]
# Many sites such as [Ranks NL](https://www.ranks.nl/stopwords) produce a curated list of stopwords. They might have what you need.
#
# You might encounter the following example if you are trying to match a set of companies to another set with industry data.

# %%
companylist = ['HBO Max', 'AWS Inc.', 'Some Company LLC', 'The Last Resort, Ltd.']

for company in companylist:
  r.extract_keywords_from_text(company)
  print(r.get_ranked_phrases())
# Out:
# ['hbo max']
# ['aws inc']
# ['company llc']
# ['last resort', 'ltd']

# %% [markdown]
# You can add the stopwords to your list to filter out things like "inc" or "ltd"

# %%
r = Rake(
    stopwords = stopwords.words('english') + ['inc', 'ltd', 'llc']
)

for company in companylist:
  r.extract_keywords_from_text(company)
  print(r.get_ranked_phrases())
# Out:
# ['hbo max']
# ['aws']
# ['company']
# ['last resort']

# %% [markdown]
# **HINT:**
# When creating your histogram, you might have trouble filtering out all of the stopwords. You can sort all of the keywords by the top ranked and then eliminate those keywords that are clearly stopwords. Once you have about 10 or so technology related keywords you can ignore the rest.
